# %%
import pickle
import json
import codecs
import nltk
from nltk.corpus import stopwords
from pywsd.utils import lemmatize_sentence

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

stopWords = set(stopwords.words('english'))

# nltk.download('averaged_perceptron_tagger')
# nltk.download('punkt')
# nltk.download('stopwords')

# %%
data = json.load(codecs.open('raw_modules_data.json', 'r', 'utf-8-sig'))
d = {}
for datum in data:
    try:
        d[datum['ModuleCode']] = datum['ModuleDescription']
    except:
        pass
d
# Out:
# {'ACC1002': "The course provides an introduction to financial accounting. It examines accounting from an external user's perspective: an external user being an investor or a creditor. Such users would need to understand financial accounting in order to make investing or lending decisions. However, to attain a good understanding, it is also necessary to be familiar with how the information is derived. Therefore, students would learn how to prepare the reports or statements resulting from financial accounting and how to use them for decision-making.",
#  'ACC1002X': "The course provides an introduction to financial accounting. It examines accounting from an external user's perspective: an external user being an investor or a creditor. Such users would need to understand financial accounting in order to make investing or lending decisions. However, to attain a good understanding, it is also necessary to be familiar with how the information are derived. Therefore, students would learn how to prepare the reports or statements resulting from financial accounting and how to use them for decision-making.",
#  'ACC1006': 'This course aims to help students understand the role of information systems in accounting and other areas of business. In particular, it examines the innovative applications of information systems to streamline business operations and enhance competitive advantage. Students will understand various accounting/business cycles and learn about how information systems are used in different functional areas such as finance/accounting, marketing, operations and supply chain, and HR/management.',
#  'ACC1701': 'The course provides an introduction to accounting from a user perspective. Financial reporting is covered from the viewpoint of an external investor. The focus is on how accounting can help investors make better decisions. Book-keeping and preparation of financial statements are also covered at an introductory level, as investors need to be aware of how the financial statements are derived.',
#  'ACC1701X': 'The course provides an introduction to accounting from a user perspective. Financial reporting is covered from the viewpoint of an external investor. The focus is on how accounting can help investors make better decisions. Book-keeping and preparation of financial statements are also covered at an introductory level, as investors need to be aware of how the financial statements are derived.',
#  'ACC2002': 'This course covers major concepts, tools and techniques in managerial accounting. It provides students with an appreciation of how managerial accounting evolves with changes in the business environment and why the usefulness of managerial accounting systems depends on the organisational context. The emphasis is on the use of managerial accounting information for decision-making, planning, and controlling activities. Students are introduced to both traditional and contemporary managerial accounting concepts and techniques.',
#  'ACC2706': 'This course covers major concepts, tools and techniques in managerial accounting. It provides students with an appreciation of how managerial accounting evolves with changes in the business environment and why the usefulness of managerial accounting systems depends on the organisational context. The emphasis is on the use of managerial accounting information for decision-making, planning, and controlling activities. Students are introduced to both traditional and contemporary managerial accounting concepts and techniques.',
#  'ACC2707': 'The module covers financial accounting at an intermediate level, with special reference to accounting for property, plant & equipment, investment properties, assets held for sale, intangible assets, asset impairment, changes in accounting policies and estimates, post-balance-sheet events, revenue accounting, segment reporting and interim reporting.',
#  'ACC2708': 'The module covers financial accounting at an intermediate level, with special reference to accounting for financial instruments, deferred tax, leases, provisions, employee benefits, and share-based compensation.',
#  'ACC2709': 'This course aims to help students understand the role of information systems in accounting and other areas of business. In particular, it examines the innovative applications of information systems to streamline business operations and enhance competitive advantage. Students will understand various accounting/business cycles and learn about how information systems are used in different functional areas such as finance/accounting, marketing, operations and supply chain, and HR/management.',
#  'ACC3603': 'This module provides the knowledge and understanding of the audit process required by assurance and attestation engagements. It aims to ensure students acquire the necessary attitude, skills, and knowledge for a career in auditing, in the accounting profession or in business management.',
#  'ACC3601': 'This course examines the conceptual and theoretical issues underlying the corporate accounting and reporting requirements under the US, International and Singapore Accounting Standards. This allows the students to understand the economic rationales behind the accounting treatment of major financial statement items. It also equips the students with skills in using financial information for decision-making. Topics to be covered include conceptual framework in financial reporting, accounting for foreign currency translation, leasing, preparation of consolidated financial statements, earnings quality management and off-balance sheet financing.',
#  'ACC3604': 'The primary aim of this course is to develop a solid understanding of the legal framework required in the operations of business entities especially companies. It covers the entire life-span of a business entity, namely from the formation of the entity to its liquidation. It also includes the various legal obligations and implications in operating the business entity. A secondary objective is to introduce the pertinent provisions of securities legislation such as the Securities &amp; Futures Act and the Takeover Code.',
#  'ACC3605': "This module introduces students to the basic concepts of income taxation in Singapore. Since a large portion of a business organisation's profits goes towards the payment of income tax, it is absolutely crucial for students to have an understanding of how tax works and how to legally minimize it. This module is relevant to those who wish to work in the fields of accounting, consulting or financial management.",
#  'ACC3606': "This course explores in greater depth complex financial reporting topics introduced in ACC1002 Financial Accounting and ACC3601 Corporate Accounting and Reporting, and it also examines issues relating to fair value accounting. The viewpoint is that of the preparer of financial statements. The discussion centres on the financial reporting issues affecting a firm's profitability and risk. This course is for students who expect to become CPAs.",
#  'ACC3614': 'This module equips students with an understanding of the various valuation issues and methodologies available to accountants and managers. It specifically discusses valuation issues pertaining to the enterprise, assets for use, and liabilities. After taking this course, the students should be able to value certain classes of assets and liabilities which are of significant interest and importance to the modern business. Coverage includes fair value and value-in-use concepts, earnings multiple analysis, discounted cash flow analysis and real option analysis.',
#  'ACC3616': 'The module covers corporate governance from a multidisciplinary\nperspective including law, finance, accounting\nand economics. The module covers enterprise risk\nmanagement in terms of the Integrated Framework issued\nby the Committee of Sponsoring Organizations of the\nTreadway Commission (COSO).',
#  'ACC3619': 'This is a capstone module that to some extent mirrors the\naims of the Integrated Business Systems module in the\nSingapore Qualifying Programme. The module gives\nstudents a chance to apply their technical knowledge in\ndifferent areas to a set of multi-disciplinary cases that\ncapture complex real problems faced by accountants\nparticularly in Singapore and the neighbouring region.',
#  'ACC3701': 'This module provides the knowledge and understanding of the audit process required by assurance and attestation engagements. It aims to ensure students acquire the necessary attitude, skills, and knowledge for a career in auditing, in the accounting profession or in business management.',
#  'ACC3703': "This module introduces students to the basic concepts of income taxation in Singapore. Since a large portion of a business organisation's profits goes towards the payment of income tax, it is absolutely crucial for students to have an understanding of how tax works and how to legally minimize it. This module is relevant to those who wish to work in the fields of accounting, consulting or financial management.",
#  'ACC4611': 'This module provides students with a foundation in tax planning. Part 1 discusses tax planning opportunities for the business entity in a local (Singapore) context, by making use of available tax incentives, different business structures, etc. Part 2 covers tax planning in an international business context, and will deal with double tax agreements, choice of foreign investment vehicles, repatriation of income and capital, tax havens, tax arbitrage, etc. Part 3 deals with tax planning for the individual operating across international boundaries.',
#  'ACC3702': 'The primary aim of this course is to develop a solid understanding of the legal framework required in the operations of business entities especially companies. It covers the entire life-span of a business entity, namely from the formation of the entity to its liquidation. It also includes the various legal obligations and implications in operating the business entity. A secondary objective is to introduce the pertinent provisions of securities legislation such as the Securities & Futures Act and the Takeover Code.',
#  'ACC4615': 'To equip students with a good understanding of the theoretical and practical knowledge/techniques for a variety of assurance and attestation work other than the statutory audit. Such work is often more complex and requires advanced methodologies.',
#  'ACC4619': 'Advanced Independent Study Modules (ISMs) are for senior students who are in the BBA(Acc) honors programs with the requisite background to work closely with an instructor on a well-defined project in the accounting area. (The modules may also be made available to students who are eligible for admission into the honors programs but choose to pursue the non-honors course of study.) Students will hone their research and report-writing skills while tackling an accounting related issue under the guidance of the instructor.',
#  'ACC3704': 'The module covers financial accounting at an advanced level, with a focus on business combination accounting, group accounting (subsidiaries, associates and joint arrangements), foreign currency accounting (transactions and translation) and related party disclosures.',
#  'AH2101': 'This module introduces students to art history both as a field of academic knowledge concerned with works of art (including painting, sculpture and architecture) and as a discipline with a distinctive methodology, vocabulary and theoretical foundations. The module surveys the main trends in the artistic traditions of Europe and Asia paying special attention to cross-cultural comparative analysis (i.e. how the human body and landscape are represented in different artistic traditions).',
#  'ACC3705': 'This module equips students with an understanding of the various valuation issues and methodologies available to accountants and managers. It specifically discusses valuation issues pertaining to the enterprise, assets for use, and liabilities. After taking this course, the students should be able to value certain classes of assets and liabilities which are of significant interest and importance to the modern business. Coverage includes fair value and value-in-use concepts, earnings multiple analysis, discounted cash flow analysis and real option analysis.',
#  'AH2201': 'This is an introductory-level course, providing students a historical survey of three thousand years of Chinese visual arts with emphasis on painting. Through the course, students will gain a basic understanding of the historical transformation of Chinese art from the classical towards the modern and contemporary, as well as key aesthetic and philosophical conceptions underpinning the production of visual arts in the Chinese culture. In addition, the course provides some comparative studies of Chinese and Western visual arts. There will also be a component introducing the special linkages between the history of Singapore art and the Chinese context.',
#  'ACC3706': 'The module covers corporate governance from a multidisciplinary perspective including law, finance, accounting and economics. The module covers enterprise risk management in terms of the Integrated Framework issued by the Committee of Sponsoring Organizations of the Treadway Commission (COSO).',
#  'AH2202': 'What is modern art? How has it been understood and interpreted by artists, critics and art historians? What is the relationship between modern art, modernism and modernity? Is the history of modern art “multiple”? The course will explore these questions through a chronological introduction to modern art, from the 19th century to the 1950s. Students will be encouraged to critically-analyse visual and textual primary-source material to develop a nuanced understanding of different developments in modern art. Case studies on modern art in Asia will also be included to encourage students to appreciate the multiplicity and global diffusion of modern art.',
#  'ACC3707': 'This is a capstone module that to some extent mirrors the aims of the Integrated Business Systems module in the Singapore Qualifying Programme. The module gives students a chance to apply their technical knowledge in different areas to a set of multi-disciplinary cases that capture complex real problems faced by accountants particularly in Singapore and the neighbouring region.',
#  'AH3203': 'This module examines the development of a wide range of private and institutional collecting practices in Europe and Asia, from the late medieval period to the present day. It draws on diverse theoretical approaches to collection studies. The course seeks to understand the contributions of collectors to art-production, display and taste-making and value-arbitration, and, consequently to the overall contours of art history and its canons. It adopts an inter-disciplinary approach to demonstrate how collectors have actively shaped other histories of modernities, nationalisms and cosmopolitanisms.',
#  'AH3204': 'This module examines the history of art history as a discipline looking at its origins, evolution and shifts across time. It seeks to understand how genres in art history are sequenced, compared and analysed in the European tradition. The module also examines how art history evolves differently in Asian texts and Asian contemporary writing. These differences in the methods and approaches to art history provide diverse frameworks to appreciate art-production and consumption globally.',
#  'ACC4614': 'This module equips students with internal audit, risk and compliance knowledge and skills. With a slant towards internal auditing, students will learn the key risks and controls in the major banking products such as global markets, credit and lending, wealth management, as well as the major banking regulations such as anti-money laundering/countering of terrorist financing rules. Students will learn how to design internal audit programmes to assess the adequacy and effectiveness of internal controls in these areas. Topics covered include data analytics, common modus operandi of banking frauds and control lapses, internal auditing standards, and internal audit report writing.',
#  'ALS1010': 'This module considers evidence-based techniques for\nlearning derived from the fundamental science and\nunderstanding of how we learn. It reveals steps on the\npath to more effective learning by using a set of simple,\npragmatic rules: rules to build motivation and to speed up\nthe learning process over both the short and long term.\nLearners will appreciate learning rules and the scientific\nevidence behind them. They will also understand why,\ndespite sometimes being counterintuitive, they work so\nwell. This understanding will lead to individualised\napplication of techniques to improve learning.',
#  'ACC4616': 'Accounting theory is a body of rules and theories which governs the practice of financial accounting. Many of the rules and theories are well reasoned economic rationales and tested over time. On the other hand, the state of accounting theory also changes as new accounting and financial transactions are created in the new economy. This module seeks to examine some of the core theories that underpin financial accounting. This is essential to a proper theoretical understanding of the discipline of financial accounting.',
#  'ALS1010CP': 'This module considers evidence-based techniques for\nlearning derived from the fundamental science and\nunderstanding of how we learn. It reveals steps on the\npath to more effective learning by using a set of simple,\npragmatic rules: rules to build motivation and to speed up\nthe learning process over both the short and long term.\nLearners will appreciate learning rules and the scientific\nevidence behind them. They will also understand why,\ndespite sometimes being counterintuitive, they work so\nwell. This understanding will lead to individualised\napplication of techniques to improve learning.',
#  'ALS1020': 'Have you ever regretted a choice you made? Every day, we make many decisions. However, are you aware that we all possess cognitive biases that influence our choices without us knowing? These natural biases can lead us into making seemingly prudent decisions that are illogical. In this module, we will explore some of the biases that we are naturally programmed. You will understand why we don’t even realize that we behave irrationally and make choices that are unintended. With a better knowledge of these inherent natural biases, we can think more clearly and make better decisions in our lives.',
#  'ACC4711': 'This module provides students with a foundation in tax planning. Part 1 discusses tax planning opportunities for the business entity in a local (Singapore) context, by making use of available tax incentives, different business structures, etc. Part 2 covers tax planning in an international business context, and will deal with double tax agreements, choice of foreign investment vehicles, repatriation of income and capital, tax havens, tax arbitrage, etc. Part 3 deals with tax planning for the individual operating across international boundaries.',
#  'AR1101': 'This is a foundation module that serves to introduce basic communication techniques, the fundamental principles of design and design methods. Topics ? The module will deal with the subject of human perception in the reading and understanding of design. Issues related to space, form, order will serve as essential design generators. The module will also provide the requisite grounding in visual language, design thinking and graphic communication. Graphic communication will include basic drawing skills and the use of common rendering media for two and three-dimensional representation.',
#  'ACC4713': 'This module equips students with internal audit, risk and compliance knowledge and skills. With a slant towards internal auditing, students will learn the key risks and controls in the major banking products such as global markets, credit and lending, wealth management, as well as the major banking regulations such as anti-money laundering/countering of terrorist financing rules. Students will learn how to design internal audit programmes to assess the adequacy and effectiveness of internal controls in these areas. Topics covered include data analytics, common modus operandi of banking frauds and control lapses, internal auditing standards, and internal audit report writing.',
#  'AR1327': 'This module for architecture students introduces the students to structural principles in architectural design. It covers the effects and properties of structural forces, structural systems and their interfaces with building functions in served and servant spaces. It also examines issues of construction and assemblage, in relation to special building types and building systems',
#  'ACC5001': 'Analysis of financial statements to determine the fundamentals of a business for investment or managerial decisions.',
#  'AR2101': 'This module will emphasize design in response to environment and site. It will enable students to learn to design small-scale buildings within the context of hot humid tropical environments. Topics - The module will deal with issues related to climate, the tropical environment and sustainability as generators of design. It will also focus on design with an understanding of spatial and functional relationships of spaces such as small and big spaces, private and public spaces.',
#  'AR2221': 'This module introduces students to architecture and the built environment in Southeast Asia: their variety, the material, historical and cultural contexts of their production, and the theories and debates. Unit I explores the pre-modern, pre-colonial, and colonial architectural legacies of Southeast Asia and introduces the terms and categories that are used to discuss them. Unit II looks at the theories, debates, and arguments on contextual response in modern and contemporary architecture in Southeast Asia since the early 20th century (coinciding with late colonial rule) through the post-independence period to contemporary times.',
#  'AH2203': 'This module surveys art and architectural genres produced in British colonies, chiefly India, Singapore and Malaya through diverse visual forms such as painting, calendar art, photography, craft objects and buildings. Visual analysis is accompanied by an investigation into the shifts in materials, technologies and contexts of display and consumption, which often expressed British control, native resistance and a desire for self-rule. The module also considers the role of British institutions, namely, art schools, archaeological surveys, museums and exhibitions in grooming art production and tastes; native projects and responses are unravelled simultaneously to understand East-West interactions.',
#  'AR2224': 'This module provides and introduction to some of the basic concepts in and approaches to architecture as a practice and as an academic discipline. It also highlights the nature and historical development of architecture especially with respect to "vocabulary" and "ideas", and introduces their use in the analysis of the works of architecture. Topics ? The module will (1) imbue the knowledge of architecture as a special category of man-made objects, replete with ideas, social contexts and intellectual processes; (2) introduce architecture through some of its basic concepts such as "periods", "styles", "language", etc.; (3) encourage an active and a critical approach to analyzing the works of architecture; (4) show the relevance of architecture in contemporary and immediate real-life problem sets like sustainability, subjectivity, identity, meanings, etc.',
#  'AH3201': 'This module provides an introduction to key movements and tendencies in late modern and contemporary art, primarily in Europe and North America, but also extending to related developments around the world. Through a close analysis of significant artists, exhibitions and texts, the course will encourage a historical understanding of the emergence of Western contemporary art and its role within the globalised art world of today. The influences of social, political and cultural forces will also be discussed, providing a wider framework for students to interpret artworks and to examine their context and reception.',
#  'AR2225': 'The module introduces students to ways of looking at and discussing works of art. The focus is chiefly on painting and sculpture; the emphasis is on analyzing the composition or design of art works and in constructing meanings for them. The study of this module enables students to acquire critical skills for interpreting and connecting with works of art. The module encourages students to read art works in relation to a range of interests, intentions and issues; the aim here is to suggest or propose contexts or environments in which art works are made and received. There are three sections. In the first, three (3) topics from Asian art traditions are discussed. The are : 1. Indian sculpture 2. Chinese landscape painting 3. Islamic calligraphy In the second section, ideas and movements from the Renaissance in Italy to the end of the 20th century in Europe, are surveyed.',
#  'AH3202': 'The module aims to equip students with curatorial methodologies and theories drawn from the history of exhibitions in Southeast Asia. Students will be introduced to postcolonial theories, approaches and methodologies with an inter-disciplinary focus that can be used to frame the art histories of the region. This module will provide opportunities for students to gain hands-on experience of curatorial practices through workshops with curators, conservators, educators and public programmers by drawing resources from the NUS Museum and the National Gallery Singapore.',
#  'AR2327': 'Architectural form is a result of its construction, structure and materiality. Architecture emerges in a symbiosis of historical understanding of structural theory, construction, engineering and automation.\nThe Module focuses on materials and construction techniques within different environmental and climatic conditions. The fundamentals, rules of systems and principles in Construction Architecture explain constructed form. Using additive manufacturing new possibilities in prefabrication and modular elements will be explored. Lectures on Structural and Design Logic accompany seminar assignments and cover in greater depth, important aspects of Architectural Construction and Systems of Prefabrication, whereby 3D printing is used to generate new structural typologies, applicable and necessary for the integration into the Architectural Design Studio.',
#  'AR2522': 'In architectural practice, computation has grown in importance and is fundamentally changing the nature of the design process itself. Performance Based Design is a computational design approach in which design options are iteratively explored based on feedback from performance simulations. This module will introduce the overall design approach and will teach both theoretical and practical aspects of building performance simulation. Simulations will include shadowcasting, daylighting, and solar radiation.',
#  'AR3101': 'This module will emphasize the integrative nature of architectural design. It will enable students to understand how technology should be applied to building design and construction. Topics: The module will focus on projects that require consideration for realism imposed by functional, technical and statutory constraints. Buildings will be of medium complexity set within less intensively developed urban sites. Design projects will demand a holistic awareness of the issues related to the environment, climate, context, technology and building regulations',
#  'AR1102': 'This module will build upon the module AR1101 by focusing on the development of basic design skills as an interface for activities between people, furniture, fittings and the use of space within the built environment. Topics - The module will focus on issues related to the measure of man to serve as essential design generators. The module will also deal with the use of materials and methods for making and constructing. The module will also deal with context. Graphic communication and the use of technical drawings to illustrate design will form part of this module. The module will expand on the development of media in graphic communication.',
#  'AR3101A': 'This studio-based module develops basic skills in landscape design and marks the ‘first-time experience’ of architecture students in the field of landscape architectural studio work. It leads the students into urban and suburban contexts, where landscape ‘meets’ city and city ‘eats’ landscape.',
#  'AR1328': 'The module examines both the constructional and environmental design strategies that shape the architectural envelope in the tropical climate. It discusses the inter-relationship between passive environmental design performances and construction with its choice of materials and methods. It also emphasizes the interdependence of design and technique/technology.',
#  'AR2102': 'This module will emphasize the integrative nature of architectural design. Students are to focus on the integration of architectural design with materials, structure and construction. Topics ? The module will deal with appropriate materials, structure and construction for the architectural design intent through the design of a small-scale building. Responses to program, climate and site context of urban fringe sites are also to be considered in the design.',
#  'AR3223': 'The module introduces the foundational and holistic knowledge and understanding of urbanism¿the study of relationships between people in urban areas with the built environment. It provides a comprehensive inquiry of urban history, key theories, topics, design principles and practices related to urban design, urban planning and landscape design. The emphasis is on developing critical and analytical skills of reading, documenting, analysing and synthesising complex information regarding contemporary urban issues and conditions.',
#  'AR2222': 'This core introductory module looks at the production and development of architectural ideas in the Western European and Northern American historical context, from the Antiquities, the pre-modern to early modern, and the modern to postmodern/contemporary periods. The rich and complex historical trajectory underpins the constructedness of architectural knowledge. While by no means exhaustive, the specific thematic focus adopted for each lecture allows students to grasp the connections between epochal periods of architectural innovations and equally, their counter-movements.',
#  'AR3411': 'The internship programme aims to provide opportunities\nfor third year undergraduates to work in architectural or\nallied firms or organisations with design centric focus to\ngain the exposure and experience and apply the\nknowledge learnt in school in the professional setting\nStudents are required to perform a structured and\nsupervised internship in a company/organization for a\nminimum of 8 weeks during Special Terms. Weekly\nlogbook as well as internship reports will be used a part\nof the evaluation of their internship experience.',
#  'AR3412': 'This internship module is open to full-time undergraduate students who have completed at least 60MCs and plan to proceed on an approved internship of at least 10 weeks in duration in the vacation period. This module recognizes work experiences in fields that could lead to viable career pathways that may be remotely and not directly to the student’s major. It is accessible to students for academic credit even if they had previously completed internship stints for academic credit not exceeding 12MC, and if the new workscope is substantially differentiated from previously completed ones.',
#  'AR2524': 'Spatial Computational Thinking is increasingly being\nrecognised as a fundamental method for various spatial\ndisciplines. It involves idea formulation, algorithm\ndevelopment, solution exploration, with a focus on the\nmanipulation of geometric and semantic datasets.\nStudents will use parametric modelling tools for generating\nand analysing building elements at varying scales. Such\ntools use visual programming interfaces to allow complex\nalgorithms to be developed and tested. Students will learn\nhow to structure their ideas as algorithmic procedures that\nintegrate data-structures, functions, and control flow.\nThrough this process, students will also become familiar\nwith higher-level computational concepts, such as\ndecomposition, encapsulation and abstraction.',
#  'AR3421': 'In this module, students will gain knowledge of how buildings are designed and built in the context of architectural and professional practice and the framework of the construction industry within which it operates',
#  'AR2723': 'This module deals with topics in ecological and sustainable architecture, focusing on environmental issues as they apply to design. Basic technical knowledge on energy, water, materials, etc are covered in the context of how buildings operate. The module enables students to operationalize the principles when generating design solutions.',
#  'AR3721': 'This course introduces fundamental building physics (thermal, lighting, acoustics), building materials, and systems to achieve environmental performance-targets and sustainability. Technology integration is emphasized via understanding how materials and systems are related, detailed, and assembled. Students will learn quantitative means to evaluate environmental requirements, and develop familiarity with system strategies and construction details to integrate the various building systems (such as structure, mechanical and electric services, architecture exteriors and interiors). Additionally, codes of practice (such as fire safety) and considerations on sustainable environment will be addressed. The goal is to integrate those technologies in a symbiotic manner to achieve human well-being.',
#  'AR3102': 'The objective of the program is to develop a level of competence in design skills and thinking. It involves the integration of technology with the natural environment, and urban context. Students address a generic brief by building upon it with emphasis in Urban, Environment, and/or Technological issues in a given site to demonstrate the acquisition of a level of competence in research, design thinking, operational skills and communication.',
#  'AR4001': 'This module will involve critical analyses and thorough discussions of specific topics in History, Theory and in Architecture, Architecture & Urban Heritage and Design Computing.',
#  'AR3102A': 'This studio-based module develops basic skills in landscape design and marks the ‘second-time experience’ of architecture students in the field of landscape architectural studio work. It leads the students into central urban contexts, where architecture ‘meets’ landscape architecture and built city ‘defines’ public open space.',
#  'AR4103': 'The studio aims to provide the students with an opportunity to learn design detailing, technological development and resolution of architectural schemes up to a stage where the design information in the project submission may be understood as being equivalent to pre-tender drawings or drawings for construction. The scope of learning comprises of i) Understanding the conceptual intentions of design scheme. ii) Translating aesthetic intention into technological design issues. iii) Identifying separate technical design activities, eg lighting iv) Communicating resolved design solutions as technical specification, architectural/construction drawing.',
#  'AR4421': 'The internship programme aims to provide opportunities for fourth year undergraduates to work in architectural or allied firms or organisations with design centric focus to gain the exposure and experience and apply the knowledge learnt in school in the professional setting. Students are required to perform a structured and supervised internship in a company/organization for a minimum of 6 months. Weekly logbook as well as internship reports will be used a part of the evaluation of their internship experience.',
#  'AR5011': 'This course examines parameters that are set and/or claimed for undertaking research leading to the writing and presentation of a dissertation for a degree in a university. It begins by sketching a brief history of research and then proceeds to highlight changing definitions, premises and approaches. The principal interest and task of the instructor is to lead & develop discussions of definitions, premises and approaches. In dealing with them, aspects of methods, structure and language will gain focus.',
#  'AR5121': 'This module aims to introduce relevant topics in total building performance, fire management, specification writing and buildability and their application to design management and development. This module is conducted through two intensive one-week workshops. The first workshop starts right after submission of the Dissertation and deals with Total Building Performance and Fire Management relevant to the early design phase of the Final Design Project. The second workshop is conducted in the first week of S2 and deals with Specification Writing and Buildability, issues more relevant for the advanced stage of the Final Design Project. Through this module, students will become aware of the individual requirements of the above topics and codes. Selected examples will be introduced and students learn how these topics can be applied and that their successful consideration does not compromise on the design.',
#  'AR4002': 'The course is intended to evaluate the students’ ability to carry out independent research under the supervision of a faculty member. Students will identify subject in the area of Architecture Theory/History, Architecture & Urban Heritage, Urban Studies and Design Computing.',
#  'AR5321': 'The module provides learning experiences on multi-disciplinary collaboration and problem-solving between architects and engineers to prepare students for contemporary architectural practice. It commences with case studies to understand overviews and foundations for interdisciplinary collaboration. A series of roundtables on advanced architectural technologies illustrates how innovative architecture could be emerged from multidisciplinary collaborations. Students are to participate design charrette to create innovative proposals for optimization, performance, and aesthetic goals, in collaboration with the lecturers and consultants who are architects and engineers.',
#  'AR5322': 'The module intends to provide students with a general understanding about the interrelationship between natural resources and architecture including building materials and energy sources. The need to shift from present fuel-based energy use and construction practices toward the application of renewable resources strategies is highlighted. Different renewable energy strategies as well as the use of renewable resources and sustainable design practices are going to be discussed both at single-house, building and city scales.',
#  'AR4955': 'This module will involve a critical and thorough discussion of specific topics in architectural design. Examples of topics that may be discussed are Universal Design, Participating Design, Elderly Housing, Post Occupancy Evaluation, Community Architecture, Architectural Practices, Places of Learning, Healthcare Design and Design Methodology.',
#  'AR5422': 'This module will provide students with the knowledge and understanding to enter into architectural practice. It will enable students to understand the legal roles and responsibilities of the architect, the branches of laws applicable to the construction industry, the Singapore Institute of Architects and Public Sector contracts. Major topics covered are the law of contracts, tort, property land law and copyright, duties of architects, the Singapore Institute of Architects and Public Sector form of contracts.',
#  'AR5423': 'This module provides students fundamental knowledge and understanding of the architectural practice in Singapore. Lectures are structured under 3 categories\nnamely:\nA. Context of Architecture Practice – topics include state of construction industry, changing landscape in construction industry and emergent technologies, future trajectory\nB. Law & Architect – topics include ethics, professional duties and responsibilities, codes and practices, planning and building control agencies\nC. Contract & Architect – Legal system and forms of building contract',
#  'AR5601': 'This module will provide a comprehensive and in-depth examination of the theories, methodologies and praxis of urban design, introducing ideas that are instrumental in establishing the foundations of urban design, examining\nrationales and strategies for creating vital and lively urban spaces, exploring key issues and myriad challenges facing urban design today and in future.\nSpecifically, viewing urban design from a place-making perspective, ranging from physical to social, tangible to intangible, global to local, the primary focus of this module are topics about urban form, density, diversity, identity, public space, community, sustainability etc.',
#  'AR5801': 'The Design module builds on the foundational curriculum established in the first undergraduate three years. The module allow the faculty research clusters to integrate research knowledge with design investigations. It provides the students with an opportunity to select from a variety of studio topics; to choose the themes which are aligned with their own interest and intellectual drive.',
#  'AR5802': 'The Design module builds on the foundational curriculum established in the first undergraduate three years. The module allow the faculty research clusters to integrate research knowledge with design investigations. It provides the students with an opportunity to select from a variety of studio topics; to choose the themes which are aligned with their own interest and intellectual drive.',
#  'AR5803': 'The studio aims to provide the students with an opportunity to learn design detailing, technological development and resolution of architectural schemes up to a stage where the design information in the project submission may be understood as being equivalent to pre-tender drawings or drawings for construction. The scope of learning comprises of i) Understanding the conceptual intentions of design scheme. ii) Translating aesthetic intention into technological design issues. iii) Identifying separate technical design activities, eg lighting iv) Communicating resolved design solutions as technical specification, architectural/construction drawing.',
#  'AR5806': 'The module supports design thesis by critically exploring significant issues to architecture involving social, political, cultural, environmental, economic and technological consideration. Key activities include: (a) Research embodying the acquisition of knowledge through precedent studies and literature. (b) Critique and evaluation of acquired knowledge. (c) Problem Statement mapping the fundamental aspects of the issues. (d) Hypothesis delineated in terms of a small set of no more than 3 key issues that can be addressed through architectural intervention. (e) Programme Formulation. (f) Site Selection. (g) Preliminary Design Studies.',
#  'AR5804': 'This module allows the students to employ digital design processes eg. Revit, CFD to simulate building performance impact on building form and configuration as an interactive design process in the development and study of optimal solutions.',
#  'AR5807': 'Students are assigned a Thesis supervisor who will assist the student in identifying and developing the Thesis topic. Students spend the early part of the thesis researching the topic and identifying key issues and design agenda. Students will then proceed to formulate an architectural project to explore the Thesis. In the later stages of the studio, each student will develop a comprehensive architectural design solution in response to the issues and brief identified earlier. In this later stage of the Thesis project students are required to develop technological and material responses to the thesis issue(s) developed earlier. The thesis submission comprises of a report, drawings, and models.',
#  'AR5808': 'The final Design Project for the M (Arch) with a specialization in Design Technology and Management is the culmination of the technical and design learning predicated on the instrumental value of technical design as a means of to a wider agenda of sustainable building, resource conservation and creating positive environmental impacts. Students are expected to demonstrate research in design technology as a basis for addressing emergent and perceived need in the aesthetic, cultural and social field. The use of design as a form of research applied to building infrastructure or the environment relevant to practical design issues in industry. Students are required to produce drawings and models illustrating technical exploration and resolution with digitally aided or lab based experimentation. Projects will be supervised by tutors of students choice assisted by a panel of technical specialists.',
#  'AR5951': 'This module will involve critical analyses and thorough discussions of specific topics in History, Theory and Criticism in Architecture.',
#  'AR5952A': 'This module will involve a critical and thorough discussion of specific topics in Urban Studies, including Urban Design and Planning. Examples of topics that may be studied are: Tropical Urban Design, Sustainable Urban Design, Ecourbanism, Urban Design methodologies and practice',
#  'AR5951A': 'This module will involve critical analyses and thorough discussions of specific topics in History, Theory and Criticism in Architecture.',
#  'AR5952B': 'This module will involve a critical and thorough discussion of specific topics in Urban Studies, including Urban Design and Planning. Examples of topics that may be studied are: Tropical Urban Design, Sustainable Urban Design, Ecourbanism, Urban Design methodologies and practice',
#  'AR5951B': 'This module will involve critical analyses and thorough discussions of specific topics in History, Theory and Criticism in Architecture.',
#  'AR5952E': 'This module will provide a comprehensive understanding of the complexity and distinctive characters of emerging urbanism in Asia, through examination of emergent urban issues related to community & participation, conservation & regeneration, ageing & healthcare, built form, modelling & big data, and resilience & informality. These topics are offered from multiple perspectives and inter- and transdisciplinary approaches to question conventional norms and conceptions and establish new visions for a sustainable urban future. Students are exposed to sustainable models and innovative urban strategies to cope with various environmental, social, economic and technological challenges that Asian cities face today and in future.',
#  'AR5951C': 'This module will involve critical analyses and thorough discussions of specific topics in History, Theory and Criticism in Architecture.',
#  'AR5954A': 'This module will involve a critical and thorough discussion of specific topics in Urban Landscape Architecture. Examples of topics that may be discussed are: Tropical Urban Landscape Design, Urban Landscape Architecture in Megacities, Sustainable Urban Landscape Architecture, Landscape Architecture in the Informal City, Landscape Visualisation.',
# ...
#  'DSC3224': 'Dynamic Pricing and Revenue Management is the state-of-art tool to improve the operational management of the demand for goods or services to more effectively align it with the supply and extract the maximum value. The course is designed to provide you: (1) a bundle of multidisciplinary knowledge and tactical tools that are readily applicable to real life business applications to deliver price recommendations; (2) conceptual frameworks that synthesize strategic principles, underlying logics, and high-level managerial insights needed by general managers and management consultants.',
#  'DSC3229': 'Independent Study Modules (ISMs) are for students with the requisite background to work closely with an instructor on a well-defined project in the respective specialization areas. Students will be exposed to individual-based research and report-writing while tackling a business issue under the guidance of the instructor.',
#  'DBA4811': 'Business analysts / consultants hold strategic positions within the knowledge-based firm. They support the Supply Chain, Marketing, Finance and HR departments in refining their processes, making them more efficient, profitable and customer-centric. A 2006 Money magazine survey ranks the business analyst position among the top jobs with regards to salary, advancement prospects, satisfaction and stress level. The objective of this capstone course is to prepare participants for the work environment and the diverse challenges faced by business analysts and consultants. Through the pedagogical medium of cases, participants will polish their skills in analytics and the written and oral communications of their results to a Management audience. The course will cover topics such as Decision & Risk Analysis, Optimization, Simulation, Data Mining and Forecasting. Participants will gain extensive experience in analytical software such as Precision Tree, Solver and Evolutionary Solver, @Risk and StatTools. Cases will highlight timely problems e.g. cash flow / revenue management, supply chain optimization, reverse auctions, staff right-sizing, outsourcing, benchmarking, CRM (e.g. customer segmentation, clustering), seasonal demand forecasting etc.',
#  'DSC4213': 'Business analysts / consultants hold strategic positions within the knowledge-based firm. They support the Supply Chain, Marketing, Finance and HR departments in refining their processes, making them more efficient, profitable and customer-centric. A 2006 Money magazine survey ranks the business analyst position among the top jobs with regards to salary, advancement prospects, satisfaction and stress level. The objective of this capstone course is to prepare participants for the work environment and the diverse challenges faced by business analysts and consultants. Through the pedagogical medium of cases, participants will polish their skills in analytics and the written and oral communications of their results to a Management audience. The course will cover topics such as Decision & Risk Analysis, Optimization, Simulation, Data Mining and Forecasting. Participants will gain extensive experience in analytical software such as Precision Tree, Solver and Evolutionary Solver, @Risk and StatTools. Cases will highlight timely problems e.g. cash flow / revenue management, supply chain optimization, reverse auctions, staff right-sizing, outsourcing, benchmarking, CRM (e.g. customer segmentation, clustering), seasonal demand forecasting etc.',
#  'DE5107': 'Objective - The module will introduce students to the multi-disciplinary nature of environmental planning, by exploring the basic principles of sustainable development and the physical planning instruments that can be employed to achieve it. The course will include an introduction to urban and regional planning theory as the framework for the discussion of environmental planning procedures. The decision environment involving the policy framework and resources, the use of strategic, sectoral, master and local plans, regulatory instruments, economic measures, participatory processes and public investment projects will be covered. Processes of identifying desired developments and intensities, site selection, planning, design and construction management, mitigation and augmentation of environmental impacts would be discussed. The course will include a master planning project, that will demonstrate the technical, decision-making and plan formulation, site planning and design procedures involved. Targeted Students - For students on the M.Sc. (Environmental Management) program. Research students and students from graduate programs in architecture and urban design may apply subject to suitability of candidate and availability of places.',
#  'DSC4216': 'The information age has brought with it a host of new technologies - and an overabundance of choices. Businesses are faced with myriad ways of identifying, developing or acquiring and deploying technologies. Organisations of different sizes in different clusters will have different technology needs at various stages of their growth. Different types of technology bring about different types of organizational change, and managers should tailor their own roles accordingly. Technology for organisational productivity and technology to enable the organisation to create new revenue streams need to be differentiated and tackled with different methodologies. Categorizing technologies in this manner can help leaders determine which technologies and when to invest in and how they can assist organizations in making the most of them.',
#  'DSC4219': 'Advanced Independent Study Modules (ISMs) are for senior students who are in the BBA and BBA(Acc) honors programs with the requisite background to work closely with an instructor on a well-defined project in the respective specialization areas. (The modules may also be made available to students who are eligible for admission into the honors programs but choose to pursue the non-honors course of study.) Students will hone their research and report-writing skills while tackling a business issue under the guidance of the instructor.',
#  'DSC5101': 'We analyze price formation and economic performance in imperfectly competitive markets by using optimization, statistical and stochastic methods. Strategic interactions between the participants in these markets are emphasized and a theoretical framework is laid out. Theoretical models are analyzed with industry examples and datasets.',
#  'DSC5102': 'This module provides an opportunity for teams of students to work with organizations throughout the world to identify important organizational issues, engage in data collection and analysis, and recommend insightful solutions. Through action-based learning that spans over one year, it aims to develop personal capabilities, professional competencies, and academic knowledge in a real business setting.',
#  'DEP5103A': 'Working with quantitative data is common in the planning profession. This module provides planning students with an introduction to the quantitative methods and techniques used in planning practice and urban research. It will prepare students to conduct basic statistical analysis of data themselves as well as to critically review analyses prepared by others. The emphasis is on how to develop sound arguments and research design, such that students appreciate both the power and limitation of quantitative analysis in planning discussions.',
#  'DSC5211A': 'This course aims to expose students to the techniques for the design, control and operation of a robust and efficient supply chain. We will focus on two of the important topics in supply chain management: supply chain coordination and supply chain risk management. Our objective is to provide our students further understanding on these two selected topics by discussing a variety of related issues and modeling/analysis tools. We will not only introduce the students a variety of recent developments and business insights in these two topics but also teach the students how to conduct analysis to gain these insights.',
#  'DTS5701': 'LARGE SCALE SYSTEMS ENGINEERING',
#  'DTS5702': 'This module provides the key underlying principles and concepts of C3 engineering and their application in the design, development and integration of C3 systems in modern armed forces. Using a systems engineering approach, the module will also enable participants to have a good appreciation of the key\nconsiderations and challenges as well as good engineering practices associated with C3 design and integration with sensor and weapon systems. Topics related to emerging trends, concepts and technologies will also be covered.',
#  'DEP5109': 'DEP5109 is the last studio project of the MUP programme.\nIn coordination with the supervising tutor(s), students can\nchoose topic and content of an individual final project\n(master project) in the field of urban planning. The aims of\nthe module are twofold: On the one hand students should\nprove their ability to undertake complex urban planning\nand research projects on an individual basis. On the other\nhand students have the opportunity to specialise\nthemselves with a project in a specific field of urban\nplanning that align their individual interest and their\nintended professional perspective.',
#  'DTS5734': 'The module covers the principles, technologies and\noperational aspects of smart weapon systems e.g. guided\nweapons, precision munitions and unmanned vehicles\n(UxVs). The interplay of various sub-systems for target\nidentification & tracking, guidance/navigation, command\nand control and their impact on mission effectiveness will\nbe examined with consideration of counter-measures and\ncounter-counter-measures. Additional topics include\nadvanced concepts for autonomy, interoperability and\nteaming and cooperation. The course will include case\nstudies of these weapon systems in actual combat.',
#  'DOS3702': 'The primary aim of this course is to get students interested in and acquainted with the fundamental concepts, models and instruments in purchasing and materials management. Key areas like buying supplies, logistics, contracts, stock and inventory control, distribution and warehouse management will be covered. Some insights into the current developments and biggest problem areas in this field are provided. A combination of informative and interactive lectures and application-oriented case assignments will be used for the pedagogy and considerable attention is devoted to the discussion of practical / managerial issues.',
#  'DTS5735': 'This module introduces cybersecurity concepts and their\napplications. It aims to illustrate how systems can fail\nunder malicious activities, and how the threats can be\nmitigated and managed. Topics include cryptography,\ncommunication channel security, system security, trusted\ncomputing, policy making, human factors, etc. Applications\nsuch as cloud security, IOT security, security operations\ncentres, AI in cybersecurity, and case studies on wellknown\nattacks will be used to reinforce the learning of\nvarious foundational concepts.',
#  'DOS3703': 'The objective of this course is to provide a comprehensive and systematic coverage of managing operations in service or service-oriented organisations such as banks, hospitals, airlines, retail outlets, restaurants and consultant agencies. Specifically, students will focus on the problems and analysis relating to the design, planning, control and improvements of service operations. Topics covered include service strategy, system design, location and layout of service systems, resource allocation, workshift scheduling, vehicular scheduling and routing, and service quality. This course is essential for students wishing to work in service or service-oriented environments.',
#  'DTS5736': 'The purpose of this module is to allow students to integrate\nmulti-dimensional defence technology that include C3,\nSensors and Intelligence, Artificial Intelligence, Guided\nWeapons, Unmanned Systems, Cyber, Operations\nResearch, Systems Engineering, etc, to study, formulate\nand analyse an actual military problem with the goal of\nrecommending a design solution with the principles of\nsystems engineering and design that involve complex\nsystems.',
#  'DSA2102': 'This module aims at introducing basic concepts and wellestablished\nnumerical methods that are very related to the\ncomputing foundation of data science and analytics. The\nemphasis is on the tight integration of numerical\nalgorithms, implementation in industrial programming\nlanguage, and examination on practical examples drawn\nfrom various disciplines related to data science. Major\ntopics include: computer arithmetic, matrix multiplication,\nnumerical methods for solving linear systems, least\nsquares method, interpolation, concrete implementations\nin industrial program language, and sample applications\nrelated to data science.',
#  'DY5190': 'This module is designed to promote a strong research culture among the research students of the Faculty of Dentistry as well as improving their communication skills through presentations and conference attendance. It is spread over the candidature of the students and will be graded "Satisfactory/Unsatisfactory" on the basis of student presentation and participation.',
#  'DY5310': 'The Endodontic Residency Training Programme comprises of didactic, clinical and research components. Clinical training incorporating state-of-the-art technologies is corroborated with advanced didactic instruction in the principles of Endodontics and the basis for biomedical sciences. An array of features includes laboratory practical, seminars, lectures,literature reviews, multidisciplinary diagnostic and treatment planning sessions as well as undergraduate teaching. There may also be an opportunity for a 3-4 weeks attachment at Baylor College of Dentistry in USA for increased educational exposures. Research is an integral part of the program and the resident is required to engage in a clinical or basic science research project. The resident is encouraged to attend conferences (both local and international) and present their research findings, conduct table-clinics, etc. at such meetings. The main research interest of the Endodontic Residency Training Program is in the understan',
#  'DSA4212': 'Computational optimisation is ubiquitous in statistical learning and machine learning. The module covers several current and advanced topics in optimisation, with an emphasis on efficient algorithms for solving large scale data-driven inference problems. Topics include first and second order methods, stochastic gradient type approaches and duality principles. Many relevant examples in statistical learning and machine learning will be covered in detail. The algorithms will be implemented using the Python programming language.',
#  'DY5320': 'The Oral & Maxillofacial Surgery programme is a three-year programme, incorporating an applied basic science component to be taken in the first year. Students with a Primary MDS or its equivalent are exempted from the Basic Science course and Examination. The Oral & Maxillofacial Surgery residency programme will enable the resident to: ? Acquire the widest theoretical knowledge to be competent in the foundation for the practice of Oral & Maxillofacial Surgery; ? Acquire the foundation and practical experience in Oral & Maxillofacial Surgery to be competent to enter into higher specialty training; ? Effectively interface with other specialties and disciplines in patients requiring interdisciplinary management, especially in head and neck conditions, orthognathic surgery, cleft lip and palate management; ? Acquire the experience to carry out research projects, to critically evaluate scientific publications and to communicate clinical and research papers in journals and conference',
#  ...}

# %%
for key in d.keys():
    tokens = list(set(lemmatize_sentence(d[key])) - stopWords)
    dirty_tags = nltk.pos_tag(tokens)
    tags = [t[0] for t in dirty_tags if t[1] in ['NN','JJ','VBG','JJR','JJS','NNS','NP','NPS']]
    d[key] = tags
d
# Out:
# {'ACC1002': ['information',
#   'statement',
#   'investing',
#   'external',
#   'familiar',
#   'derive',
#   'need',
#   'accounting',
#   'learn',
#   'result',
#   'good',
#   'report',
#   'perspective',
#   'decision-making',
#   'lending',
#   'understand',
#   'investor',
#   'course',
#   'user',
#   'account',
#   'necessary',
#   'introduction',
#   'financial',
#   'make',
#   'understanding',
#   'attain',
#   'creditor',
#   'decision',
#   'order',
#   'examine'],
#  'ACC1002X': ['information',
#   'statement',
#   'investing',
#   'external',
#   'familiar',
#   'derive',
#   'need',
#   'accounting',
#   'learn',
#   'result',
#   'good',
#   'report',
#   'perspective',
#   'decision-making',
#   'lending',
#   'understand',
#   'investor',
#   'course',
#   'user',
#   'account',
#   'necessary',
#   'introduction',
#   'financial',
#   'make',
#   'understanding',
#   'attain',
#   'creditor',
#   'decision',
#   'order',
#   'examine'],
#  'ACC1006': ['enhance',
#   'operation',
#   'information',
#   'business',
#   'role',
#   'streamline',
#   'chain',
#   'student',
#   'supply',
#   'accounting',
#   'learn',
#   'cycle',
#   'particular',
#   'use',
#   'advantage',
#   'various',
#   'understand',
#   'hr/management',
#   'functional',
#   'course',
#   'competitive',
#   'finance/accounting',
#   'different',
#   'area',
#   'accounting/business',
#   'application',
#   'aim',
#   'system',
#   'innovative',
#   'examine',
#   'marketing'],
#  'ACC1701': ['statement',
#   'external',
#   'aware',
#   'derive',
#   'book-keeping',
#   'accounting',
#   'good',
#   'help',
#   'level',
#   'investor',
#   'course',
#   'user',
#   'introductory',
#   'introduction',
#   'financial',
#   'viewpoint',
#   'make',
#   'focus',
#   'preparation',
#   'reporting',
#   'decision',
#   'provide',
#   'cover'],
#  'ACC1701X': ['statement',
#   'external',
#   'aware',
#   'derive',
#   'book-keeping',
#   'accounting',
#   'good',
#   'help',
#   'level',
#   'investor',
#   'course',
#   'user',
#   'introductory',
#   'introduction',
#   'financial',
#   'viewpoint',
#   'make',
#   'focus',
#   'preparation',
#   'reporting',
#   'decision',
#   'provide',
#   'cover'],
#  'ACC2002': ['appreciation',
#   'control',
#   'context',
#   'business',
#   'information',
#   'technique',
#   'change',
#   'student',
#   'accounting',
#   'use',
#   'emphasis',
#   'decision-making',
#   'environment',
#   'usefulness',
#   'course',
#   'tool',
#   'activity',
#   'major',
#   'concept',
#   'traditional',
#   'system',
#   'organisational',
#   'managerial',
#   'evolves',
#   'planning',
#   'contemporary'],
#  'ACC2706': ['appreciation',
#   'control',
#   'context',
#   'business',
#   'information',
#   'technique',
#   'change',
#   'student',
#   'accounting',
#   'use',
#   'emphasis',
#   'decision-making',
#   'environment',
#   'usefulness',
#   'course',
#   'tool',
#   'activity',
#   'major',
#   'concept',
#   'traditional',
#   'system',
#   'organisational',
#   'managerial',
#   'evolves',
#   'planning',
#   'contemporary'],
#  'ACC2707': ['intangible',
#   'policy',
#   'equipment',
#   'special',
#   'change',
#   'reference',
#   'accounting',
#   'property',
#   'impairment',
#   'module',
#   'estimate',
#   'interim',
#   'intermediate',
#   'level',
#   'plant',
#   'post-balance-sheet',
#   'event',
#   'financial',
#   'investment',
#   'revenue',
#   'segment',
#   'reporting',
#   'sale',
#   'cover',
#   'asset'],
#  'ACC2708': ['lease',
#   'share-based',
#   'intermediate',
#   'level',
#   'instrument',
#   'reference',
#   'accounting',
#   'special',
#   'employee',
#   'tax',
#   'benefit',
#   'financial',
#   'compensation',
#   'provision',
#   'cover',
#   'module'],
#  'ACC2709': ['enhance',
#   'operation',
#   'information',
#   'business',
#   'role',
#   'streamline',
#   'chain',
#   'student',
#   'supply',
#   'accounting',
#   'learn',
#   'cycle',
#   'particular',
#   'use',
#   'advantage',
#   'various',
#   'understand',
#   'hr/management',
#   'functional',
#   'course',
#   'competitive',
#   'finance/accounting',
#   'different',
#   'area',
#   'accounting/business',
#   'application',
#   'aim',
#   'system',
#   'innovative',
#   'examine',
#   'marketing'],
#  'ACC3603': ['profession',
#   'attitude',
#   'audit',
#   'business',
#   'knowledge',
#   'student',
#   'accounting',
#   'process',
#   'module',
#   'necessary',
#   'understanding',
#   'require',
#   'engagement',
#   'aim',
#   'assurance',
#   'career',
#   'management',
#   'provide',
#   'attestation'],
#  'ACC3601': ['earnings',
#   'allow',
#   'information',
#   'statement',
#   'translation',
#   'quality',
#   'equip',
#   'conceptual',
#   'sheet',
#   'student',
#   'theoretical',
#   'treatment',
#   'accounting',
#   'economic',
#   'use',
#   'standard',
#   'requirement',
#   'currency',
#   'financing',
#   'decision-making',
#   'issue',
#   'u',
#   'understand',
#   'topic',
#   'framework',
#   'underlie',
#   'course',
#   'financial',
#   'foreign',
#   'major',
#   'consolidated',
#   'leasing',
#   'skill',
#   'preparation',
#   'off-balance',
#   'international',
#   'reporting',
#   'corporate',
#   'management',
#   'rationale',
#   'examine',
#   'cover',
#   'item'],
#  'ACC3604': ['obligation',
#   'operation',
#   'business',
#   'liquidation',
#   'life-span',
#   'operate',
#   'formation',
#   'introduce',
#   'future',
#   'amp',
#   'entire',
#   'various',
#   'solid',
#   'implication',
#   'objective',
#   'framework',
#   'course',
#   'secondary',
#   'legislation',
#   'understanding',
#   'primary',
#   'legal',
#   'takeover',
#   'act',
#   'security',
#   'company',
#   'pertinent',
#   'provision',
#   'code',
#   'cover',
#   'entity'],
#  'ACC3605': ['portion',
#   'relevant',
#   'field',
#   'business',
#   'wish',
#   'student',
#   'payment',
#   'accounting',
#   'tax',
#   'crucial',
#   'introduce',
#   'income',
#   'singapore',
#   'basic',
#   'taxation',
#   'module',
#   'large',
#   'financial',
#   'understanding',
#   'towards',
#   'concept',
#   'organisation',
#   'profit',
#   'management',
#   'consult',
#   'work'],
#  'ACC3606': ['firm',
#   'complex',
#   'statement',
#   'value',
#   'explore',
#   'acc1002',
#   'accounting',
#   'acc3601',
#   'introduce',
#   'risk',
#   'great',
#   'issue',
#   'topic',
#   'course',
#   'profitability',
#   'financial',
#   'viewpoint',
#   'preparer',
#   'reporting',
#   'relate',
#   'discussion',
#   'corporate',
#   'fair',
#   'examine',
#   'cpa',
#   'centre'],
#  'ACC3614': ['earnings',
#   'analysis',
#   'option',
#   'business',
#   'value',
#   'equip',
#   'pertain',
#   'flow',
#   'student',
#   'valuation',
#   'certain',
#   'real',
#   'class',
#   'available',
#   'use',
#   'significant',
#   'modern',
#   'able',
#   'multiple',
#   'accountant',
#   'manager',
#   'module',
#   'issue',
#   'various',
#   'interest',
#   'importance',
#   'course',
#   'understanding',
#   'methodology',
#   'concept',
#   'coverage',
#   'enterprise',
#   'liability',
#   'fair',
#   'discount',
#   'include',
#   'value-in-use',
#   'asset',
#   'cash'],
#  'ACC3616': ['term',
#   'law',
#   'treadway',
#   'economics',
#   'organization',
#   'accounting',
#   'commission',
#   'multidisciplinary',
#   'sponsoring',
#   'risk',
#   'perspective',
#   'module',
#   'issue',
#   'governance',
#   'framework',
#   'coso',
#   'finance',
#   'enterprise',
#   'committee',
#   'corporate',
#   'management',
#   'cover'],
#  'ACC3619': ['problem',
#   'chance',
#   'extent',
#   'mirror',
#   'business',
#   'complex',
#   'qualifying',
#   'neighbouring',
#   'technical',
#   'multi-disciplinary',
#   'knowledge',
#   'student',
#   'real',
#   'programme',
#   'accountant',
#   'singapore',
#   'region',
#   'module',
#   'face',
#   'case',
#   'different',
#   'area',
#   'capstone',
#   'aim',
#   'system',
#   'capture'],
#  'ACC3701': ['profession',
#   'attitude',
#   'audit',
#   'business',
#   'knowledge',
#   'student',
#   'accounting',
#   'process',
#   'module',
#   'necessary',
#   'understanding',
#   'require',
#   'engagement',
#   'aim',
#   'assurance',
#   'career',
#   'management',
#   'provide',
#   'attestation'],
#  'ACC3703': ['portion',
#   'relevant',
#   'field',
#   'business',
#   'wish',
#   'student',
#   'payment',
#   'accounting',
#   'tax',
#   'crucial',
#   'introduce',
#   'income',
#   'singapore',
#   'basic',
#   'taxation',
#   'module',
#   'large',
#   'financial',
#   'understanding',
#   'towards',
#   'concept',
#   'organisation',
#   'profit',
#   'management',
#   'consult',
#   'work'],
#  'ACC4611': ['context',
#   'business',
#   'discus',
#   'agreement',
#   'student',
#   'repatriation',
#   'arbitrage',
#   'available',
#   'use',
#   'tax',
#   'income',
#   'incentive',
#   'module',
#   'local',
#   'double',
#   'structure',
#   'capital',
#   'boundary',
#   'foundation',
#   'opportunity',
#   'foreign',
#   'different',
#   'make',
#   'etc',
#   'vehicle',
#   'operating',
#   'investment',
#   'international',
#   'deal',
#   'individual',
#   'choice',
#   'provide',
#   'cover',
#   'part',
#   'planning',
#   'entity'],
#  'ACC3702': ['obligation',
#   'operation',
#   'business',
#   'liquidation',
#   'life-span',
#   'operate',
#   'formation',
#   'introduce',
#   'future',
#   'entire',
#   'various',
#   'solid',
#   'implication',
#   'objective',
#   'framework',
#   'course',
#   'secondary',
#   'legislation',
#   'understanding',
#   'primary',
#   'legal',
#   'takeover',
#   'act',
#   'security',
#   'company',
#   'pertinent',
#   'provision',
#   'code',
#   'cover',
#   'entity'],
#  'ACC4615': ['student',
#   'theoretical',
#   'assurance',
#   'audit',
#   'complex',
#   'knowledge/techniques',
#   'variety',
#   'good',
#   'statutory',
#   'understanding',
#   'methodology',
#   'attestation',
#   'work',
#   'practical'],
#  'ACC4619': ['program',
#   'admission',
#   'ism',
#   'senior',
#   'report-writing',
#   'non-honors',
#   'student',
#   'accounting',
#   'bba',
#   'available',
#   'tackle',
#   'module',
#   'issue',
#   'requisite',
#   'well-defined',
#   'instructor',
#   'course',
#   'project',
#   'area',
#   'study',
#   'skill',
#   'independent',
#   'eligible',
#   'honor',
#   'choose',
#   'research',
#   'acc',
#   'guidance',
#   'work'],
#  'ACC3704': ['business',
#   'subsidiary',
#   'translation',
#   'disclosure',
#   'accounting',
#   'combination',
#   'currency',
#   'module',
#   'level',
#   'financial',
#   'foreign',
#   'transaction',
#   'focus',
#   'joint',
#   'relate',
#   'group',
#   'arrangement',
#   'associate',
#   'party'],
#  'AH2101': ['comparative',
#   'asia',
#   'field',
#   'special',
#   'survey',
#   'sculpture',
#   'painting',
#   'knowledge',
#   'architecture',
#   'student',
#   'theoretical',
#   'attention',
#   'artistic',
#   'main',
#   'europe',
#   'cross-cultural',
#   'introduce',
#   'tradition',
#   'module',
#   'foundation',
#   'different',
#   'i.e',
#   'methodology',
#   'distinctive',
#   'academic',
#   'human',
#   'landscape',
#   'art',
#   'body',
#   'represent',
#   'history',
#   'concern',
#   'trend',
#   'vocabulary',
#   'work',
#   'analysis',
#   'discipline'],
#  'ACC3705': ['earnings',
#   'analysis',
#   'option',
#   'business',
#   'value',
#   'equip',
#   'pertain',
#   'flow',
#   'student',
#   'valuation',
#   'certain',
#   'real',
#   'class',
#   'available',
#   'use',
#   'significant',
#   'modern',
#   'able',
#   'multiple',
#   'accountant',
#   'manager',
#   'module',
#   'issue',
#   'various',
#   'interest',
#   'importance',
#   'course',
#   'understanding',
#   'methodology',
#   'concept',
#   'coverage',
#   'enterprise',
#   'liability',
#   'fair',
#   'discount',
#   'include',
#   'value-in-use',
#   'asset',
#   'cash'],
#  'AH2201': ['comparative',
#   'context',
#   'aesthetic',
#   'special',
#   'thousand',
#   'survey',
#   'painting',
#   'key',
#   'student',
#   'classical',
#   'component',
#   'visual',
#   'modern',
#   'gain',
#   'emphasis',
#   'introduce',
#   'singapore',
#   'basic',
#   'western',
#   'culture',
#   'philosophical',
#   'transformation',
#   'course',
#   'addition',
#   'understanding',
#   'chinese',
#   'conception',
#   'study',
#   'art',
#   'underpin',
#   'historical',
#   'history',
#   'year',
#   'production',
#   'introductory-level',
#   'linkage',
#   'provide',
#   'contemporary'],
#  'ACC3706': ['term',
#   'law',
#   'treadway',
#   'economics',
#   'organization',
#   'accounting',
#   'commission',
#   'multidisciplinary',
#   'sponsoring',
#   'risk',
#   'perspective',
#   'module',
#   'issue',
#   'governance',
#   'framework',
#   'coso',
#   'finance',
#   'enterprise',
#   'committee',
#   'corporate',
#   'management',
#   'cover'],
#  'AH2202': ['textual',
#   'asia',
#   'critically-analyse',
#   '”',
#   'appreciate',
#   'explore',
#   'primary-source',
#   'encourage',
#   'modernity',
#   'modern',
#   'visual',
#   'historian',
#   'critic',
#   'multiple',
#   'century',
#   'multiplicity',
#   'interpret',
#   'chronological',
#   'material',
#   'case',
#   'course',
#   'relationship',
#   'introduction',
#   'different',
#   'understanding',
#   'question',
#   'study',
#   'global',
#   'art',
#   'history',
#   'artist',
#   'understood',
#   'diffusion',
#   'modernism',
#   'development'],
#  'ACC3707': ['problem',
#   'chance',
#   'extent',
#   'mirror',
#   'business',
#   'complex',
#   'qualifying',
#   'neighbouring',
#   'technical',
#   'multi-disciplinary',
#   'knowledge',
#   'student',
#   'real',
#   'programme',
#   'accountant',
#   'singapore',
#   'region',
#   'module',
#   'face',
#   'case',
#   'different',
#   'area',
#   'capstone',
#   'aim',
#   'system',
#   'capture'],
#  'AH3203': ['draw',
#   'asia',
#   'day',
#   'collection',
#   'overall',
#   'approach',
#   'shape',
#   'diverse',
#   'institutional',
#   'nationalism',
#   'theoretical',
#   'demonstrate',
#   'medieval',
#   'collecting',
#   'contribution',
#   'late',
#   'canon',
#   'value-arbitration',
#   'module',
#   'wide',
#   'practice',
#   'contour',
#   'private',
#   'inter-disciplinary',
#   'present',
#   'understand',
#   'cosmopolitan',
#   'course',
#   'art-production',
#   'period',
#   'taste-making',
#   'display',
#   'study',
#   'art',
#   'seek',
#   'range',
#   'history',
#   'examine',
#   'collector',
#   'development'],
#  'AH3204': ['approach',
#   'diverse',
#   'european',
#   'genre',
#   'appreciate',
#   'time',
#   'evolution',
#   'consumption',
#   'sequence',
#   'tradition',
#   'module',
#   'discipline',
#   'framework',
#   'art-production',
#   'analyse',
#   'compare',
#   'art',
#   'seek',
#   'text',
#   'difference',
#   'writing',
#   'history',
#   'asian',
#   'origin',
#   'method',
#   'examine',
#   'shift',
#   'contemporary'],
#  'ACC4614': ['control',
#   'regulation',
#   'banking',
#   'audit',
#   'analytics',
#   'laundering/countering',
#   'assess',
#   'operandi',
#   'auditing',
#   'equip',
#   'key',
#   'credit',
#   'student',
#   'data',
#   'internal',
#   'learn',
#   'wealth',
#   'rule',
#   'standard',
#   'programme',
#   'report',
#   'market',
#   'terrorist',
#   'financing',
#   'risk',
#   'module',
#   'lending',
#   'adequacy',
#   'common',
#   'topic',
#   'fraud',
#   'lapse',
#   'major',
#   'area',
#   'global',
#   'skill',
#   'writing',
#   'compliance',
#   'product',
#   'management',
#   'slant',
#   'modus',
#   'anti-money',
#   'cover',
#   'effectiveness',
#   'towards',
#   'design'],
#  'ALS1010': ['technique',
#   'pragmatic',
#   'term',
#   'learning',
#   'appreciate',
#   'derive',
#   'learn',
#   'use',
#   'rule',
#   'process',
#   'individualised',
#   'path',
#   'module',
#   'fundamental',
#   'lead',
#   'reveal',
#   'understand',
#   'step',
#   'evidence-based',
#   'understanding',
#   'motivation',
#   'science',
#   'build',
#   'learner',
#   'application',
#   'scientific',
#   'simple',
#   'counterintuitive',
#   'evidence',
#   'effective',
#   'short',
#   'work'],
#  'ACC4616': ['economy',
#   'change',
#   'time',
#   'theoretical',
#   'accounting',
#   'economic',
#   'rule',
#   'create',
#   'module',
#   'practice',
#   'essential',
#   'many',
#   'new',
#   'theory',
#   'financial',
#   'transaction',
#   'understanding',
#   'reason',
#   'body',
#   'seek',
#   'test',
#   'underpin',
#   'core',
#   'proper',
#   'state',
#   'hand',
#   'rationale',
#   'govern',
#   'examine',
#   'discipline'],
#  'ALS1010CP': ['technique',
#   'pragmatic',
#   'term',
#   'learning',
#   'appreciate',
#   'derive',
#   'learn',
#   'use',
#   'rule',
#   'process',
#   'individualised',
#   'path',
#   'module',
#   'fundamental',
#   'lead',
#   'reveal',
#   'understand',
#   'step',
#   'evidence-based',
#   'understanding',
#   'motivation',
#   'science',
#   'build',
#   'learner',
#   'application',
#   'scientific',
#   'simple',
#   'counterintuitive',
#   'evidence',
#   'effective',
#   'short',
#   'work'],
#  'ALS1020': ['regret',
#   'life',
#   'program',
#   'natural',
#   'day',
#   'influence',
#   'realize',
#   'bias',
#   'prudent',
#   'aware',
#   'knowledge',
#   'explore',
#   'good',
#   'think',
#   'module',
#   'lead',
#   'possess',
#   'u',
#   'many',
#   'illogical',
#   'cognitive',
#   'inherent',
#   'decision',
#   'choice'],
#  'ACC4711': ['context',
#   'business',
#   'discus',
#   'agreement',
#   'student',
#   'repatriation',
#   'arbitrage',
#   'available',
#   'use',
#   'tax',
#   'income',
#   'incentive',
#   'module',
#   'local',
#   'double',
#   'structure',
#   'capital',
#   'boundary',
#   'foundation',
#   'opportunity',
#   'foreign',
#   'different',
#   'make',
#   'etc',
#   'vehicle',
#   'operating',
#   'investment',
#   'international',
#   'deal',
#   'individual',
#   'choice',
#   'provide',
#   'cover',
#   'part',
#   'planning',
#   'entity'],
#  'AR1101': ['draw',
#   'representation',
#   'three-dimensional',
#   'technique',
#   'communication',
#   'visual',
#   'use',
#   'language',
#   'principle',
#   'design',
#   'basic',
#   'module',
#   'fundamental',
#   'issue',
#   'essential',
#   'thinking',
#   'requisite',
#   'medium',
#   'common',
#   'topic',
#   'foundation',
#   'reading',
#   'form',
#   'understanding',
#   'generator',
#   'human',
#   'skill',
#   'perception',
#   'relate',
#   'deal',
#   'graphic',
#   'method',
#   'subject',
#   'render',
#   'order',
#   'space',
#   'grounding'],
#  'ACC4713': ['control',
#   'regulation',
#   'banking',
#   'audit',
#   'analytics',
#   'laundering/countering',
#   'assess',
#   'operandi',
#   'auditing',
#   'equip',
#   'key',
#   'credit',
#   'student',
#   'data',
#   'internal',
#   'learn',
#   'wealth',
#   'rule',
#   'standard',
#   'programme',
#   'report',
#   'market',
#   'terrorist',
#   'financing',
#   'risk',
#   'module',
#   'lending',
#   'adequacy',
#   'common',
#   'topic',
#   'fraud',
#   'lapse',
#   'major',
#   'area',
#   'global',
#   'skill',
#   'writing',
#   'compliance',
#   'product',
#   'management',
#   'slant',
#   'modus',
#   'anti-money',
#   'cover',
#   'effectiveness',
#   'towards',
#   'design'],
#  'AR1327': ['interface',
#   'type',
#   'special',
#   'construction',
#   'function',
#   'architecture',
#   'architectural',
#   'student',
#   'force',
#   'property',
#   'principle',
#   'introduce',
#   'building',
#   'module',
#   'issue',
#   'effect',
#   'assemblage',
#   'relation',
#   'structural',
#   'system',
#   'examine',
#   'cover',
#   'space',
#   'servant',
#   'design'],
#  'ACC5001': ['business',
#   'managerial',
#   'statement',
#   'financial',
#   'decision',
#   'determine',
#   'fundamental',
#   'investment',
#   'analysis'],
#  'AR2101': ['context',
#   'sustainability',
#   'spatial',
#   'tropical',
#   'response',
#   'small',
#   'student',
#   'learn',
#   'big',
#   'building',
#   'module',
#   'environment',
#   'enable',
#   'hot',
#   'issue',
#   'private',
#   'topic',
#   'functional',
#   'public',
#   'relationship',
#   'understanding',
#   'humid',
#   'generator',
#   'focus',
#   'small-scale',
#   'site',
#   'climate',
#   'relate',
#   'deal',
#   'space',
#   'design'],
#  'AR2221': ['colonial',
#   'context',
#   'category',
#   'asia',
#   'term',
#   'response',
#   'architecture',
#   'architectural',
#   'time',
#   'student',
#   'post-independence',
#   'southeast',
#   'legacy',
#   'use',
#   'modern',
#   'rule',
#   'unit',
#   'introduce',
#   'late',
#   'module',
#   'debate',
#   'century',
#   'environment',
#   'discuss',
#   'pre-modern',
#   'material',
#   'argument',
#   'variety',
#   'period',
#   'theory',
#   'coincide',
#   'contextual',
#   'ii',
#   'historical',
#   'production',
#   'pre-colonial',
#   'early',
#   'cultural',
#   'contemporary'],
#  'AH2203': ['archaeological',
#   'control',
#   'colony',
#   'analysis',
#   'resistance',
#   'context',
#   'taste',
#   'institution',
#   'craft',
#   'survey',
#   'role',
#   'diverse',
#   'response',
#   'painting',
#   'genre',
#   'east-west',
#   'school',
#   'architectural',
#   'calendar',
#   'consumption',
#   'native',
#   'chiefly',
#   'visual',
#   'unravelled',
#   'singapore',
#   'module',
#   'building',
#   'material',
#   'understand',
#   'form',
#   'display',
#   'self-rule',
#   'project',
#   'india',
#   'desire',
#   'art',
#   'accompany',
#   'technology',
#   'production',
#   'photography',
#   'groom',
#   'investigation',
#   'malaya',
#   'interaction',
#   'express',
#   'british',
#   'shift',
#   'exhibition',
#   'museum'],
#  'AR2224': ['introduces',
#   'man-made',
#   'problem',
#   'analysis',
#   'context',
#   'category',
#   'sustainability',
#   'special',
#   'approach',
#   'active',
#   'knowledge',
#   'replete',
#   'highlight',
#   'architecture',
#   'object',
#   'use',
#   'process',
#   'language',
#   'social',
#   'relevance',
#   'nature',
#   'basic',
#   'module',
#   'practice',
#   'intellectual',
#   'show',
#   'critical',
#   'analyze',
#   'real-life',
#   'identity',
#   'meaning',
#   'discipline',
#   'topic',
#   'immediate',
#   'idea',
#   'introduction',
#   'period',
#   'style',
#   'concept',
#   'subjectivity',
#   'academic',
#   'set',
#   'imbue',
#   'historical',
#   'like',
#   'vocabulary',
#   'development',
#   'work',
#   'contemporary'],
#  'AH3201': ['reception',
#   'analysis',
#   'emergence',
#   'world',
#   'north',
#   'context',
#   'influence',
#   'role',
#   'contemporary',
#   'political',
#   'key',
#   'student',
#   'force',
#   'significant',
#   'modern',
#   'social',
#   'late',
#   'module',
#   'western',
#   'wider',
#   'discuss',
#   'interpret',
#   'framework',
#   'course',
#   'introduction',
#   'understanding',
#   'close',
#   'art',
#   'text',
#   'america',
#   'historical',
#   'artist',
#   'movement',
#   'examine',
#   'today',
#   'development',
#   'exhibition',
#   'cultural',
#   'tendency'],
#  'AR2225': ['propose',
#   'context',
#   'construct',
#   'survey',
#   'sculpture',
#   'painting',
#   'connect',
#   'student',
#   'end',
#   'encourage',
#   'chiefly',
#   'europe',
#   'emphasis',
#   'tradition',
#   'module',
#   'century',
#   'environment',
#   'enable',
#   'meaning',
#   'calligraphy',
#   'critical',
#   'analyze',
#   'interest',
#   'issue',
#   'indian',
#   'topic',
#   'islamic',
#   'second',
#   'renaissance',
#   'italy',
#   'idea',
#   'interpreting',
#   'section',
#   'way',
#   'relation',
#   'focus',
#   'study',
#   'chinese',
#   'landscape',
#   'art',
#   'skill',
#   'range',
#   'intention',
#   'aim',
#   'receive',
#   'asian',
#   'paint',
#   'look',
#   'composition',
#   'movement',
#   'work',
#   'design'],
#  'AH3202': ['postcolonial',
#   'experience',
#   'draw',
#   'asia',
#   'programmer',
#   'approach',
#   'educator',
#   'equip',
#   'nu',
#   'student',
#   'resource',
#   'southeast',
#   'use',
#   'gain',
#   'introduce',
#   'singapore',
#   'region',
#   'module',
#   'practice',
#   'inter-disciplinary',
#   'curator',
#   'public',
#   'curatorial',
#   'opportunity',
#   'theory',
#   'frame',
#   'hands-on',
#   'methodology',
#   'focus',
#   'gallery',
#   'art',
#   'conservator',
#   'national',
#   'history',
#   'provide',
#   'exhibition',
#   'museum'],
#  'AR2327': ['symbiosis',
#   'automation',
#   'lecture',
#   'assignment',
#   'logic',
#   'construct',
#   'construction',
#   'technique',
#   'depth',
#   'integration',
#   'emerge',
#   'architecture',
#   'architectural',
#   'materiality',
#   'printing',
#   'modular',
#   'rule',
#   'result',
#   'element',
#   'principle',
#   'module',
#   'fundamental',
#   'great',
#   'manufacture',
#   'typology',
#   'structure',
#   'material',
#   'applicable',
#   'engineering',
#   'necessary',
#   'climatic',
#   'new',
#   'seminar',
#   'aspect',
#   'form',
#   'theory',
#   'different',
#   'understanding',
#   'focus',
#   'whereby',
#   'accompany',
#   'studio',
#   'important',
#   'historical',
#   'structural',
#   'environmental',
#   'generate',
#   'system',
#   'condition',
#   'possibility',
#   'prefabrication',
#   'additive',
#   'design'],
#  'AR2522': ['shadowcasting',
#   'overall',
#   'option',
#   'approach',
#   'base',
#   'radiation',
#   'change',
#   'grow',
#   'architectural',
#   'solar',
#   'theoretical',
#   'daylight',
#   'process',
#   'computation',
#   'computational',
#   'nature',
#   'introduce',
#   'building',
#   'module',
#   'practice',
#   'importance',
#   'teach',
#   'performance',
#   'practical',
#   'feedback',
#   'simulation'],
#  'AR3101': ['regulation',
#   'context',
#   'impose',
#   'urban',
#   'awareness',
#   'construction',
#   'technical',
#   'architectural',
#   'student',
#   'holistic',
#   'demand',
#   'nature',
#   'building',
#   'module',
#   'environment',
#   'enable',
#   'issue',
#   'medium',
#   'integrative',
#   'topic',
#   'functional',
#   'constraint',
#   'consideration',
#   'statutory',
#   'project',
#   'focus',
#   'site',
#   'build',
#   'require',
#   'climate',
#   'relate',
#   'realism',
#   'complexity',
#   'technology',
#   'design'],
#  'AR1102': ['interface',
#   'measure',
#   'context',
#   'furniture',
#   'construct',
#   'communication',
#   'technical',
#   'development',
#   'ar1101',
#   'basic',
#   'module',
#   'people',
#   'environment',
#   'fitting',
#   'issue',
#   'essential',
#   'material',
#   'medium',
#   'topic',
#   'activity',
#   'form',
#   'drawing',
#   'make',
#   'focus',
#   'generator',
#   'illustrate',
#   'skill',
#   'relate',
#   'deal',
#   'graphic',
#   'method',
#   'space',
#   'part',
#   'man',
#   'design'],
#  'AR3101A': ['‘',
#   'experience',
#   'context',
#   'field',
#   'urban',
#   'city',
#   'architecture',
#   'architectural',
#   'student',
#   'first-time',
#   'eats',
#   'suburban',
#   '’',
#   'studio-based',
#   'mark',
#   'basic',
#   'module',
#   'lead',
#   'landscape',
#   'studio',
#   'meet',
#   'develop',
#   'work',
#   'design'],
#  'AR1328': ['shape',
#   'construct',
#   'construction',
#   'tropical',
#   'architectural',
#   'inter-relationship',
#   'module',
#   'envelope',
#   'material',
#   'passive',
#   'technique/technology',
#   'strategy',
#   'performance',
#   'climate',
#   'interdependence',
#   'environmental',
#   'method',
#   'choice',
#   'examine',
#   'design'],
#  'AR2102': ['program',
#   'context',
#   'appropriate',
#   'intent',
#   'urban',
#   'construction',
#   'response',
#   'integration',
#   'architectural',
#   'student',
#   'nature',
#   'building',
#   'module',
#   'structure',
#   'material',
#   'integrative',
#   'topic',
#   'fringe',
#   'focus',
#   'small-scale',
#   'climate',
#   'site',
#   'deal',
#   'design',
#   'consider'],
#  'AR3223': ['urban',
#   'complex',
#   'information',
#   'inquiry',
#   'knowledge',
#   'urbanism¿the',
#   'holistic',
#   'principle',
#   'emphasis',
#   'document',
#   'module',
#   'people',
#   'practice',
#   'environment',
#   'foundational',
#   'issue',
#   'critical',
#   'topic',
#   'comprehensive',
#   'reading',
#   'relationship',
#   'theory',
#   'understanding',
#   'area',
#   'study',
#   'analyse',
#   'landscape',
#   'build',
#   'synthesise',
#   'relate',
#   'history',
#   'regard',
#   'condition',
#   'analytical',
#   'provide',
#   'planning',
#   'design',
#   'contemporary'],
#  'AR2222': ['adopt',
#   'lecture',
#   'context',
#   'complex',
#   'innovation',
#   'knowledge',
#   'european',
#   'architectural',
#   'student',
#   'specific',
#   'exhaustive',
#   'modern',
#   'grasp',
#   'connection',
#   'thematic',
#   'western',
#   'module',
#   'pre-modern',
#   'introductory',
#   'idea',
#   'period',
#   'epochal',
#   'counter-movements',
#   'antiquity',
#   'postmodern/contemporary',
#   'mean',
#   'northern',
#   'rich',
#   'underpin',
#   'core',
#   'historical',
#   'production',
#   'trajectory',
#   'american',
#   'development'],
#  'AR3411': ['experience',
#   'perform',
#   'firm',
#   'special',
#   'centric',
#   'term',
#   'internship',
#   'school',
#   'architectural',
#   'student',
#   'use',
#   'programme',
#   'gain',
#   'learnt',
#   'report',
#   'company/organization',
#   'logbook',
#   'exposure',
#   'professional',
#   'evaluation',
#   'opportunity',
#   'week',
#   'focus',
#   'organisation',
#   'minimum',
#   'setting',
#   'aim',
#   'year',
#   'undergraduate',
#   'part',
#   'work',
#   'design',
#   'weekly'],
#  'AR3412': ['experience',
#   'stint',
#   'vacation',
#   'field',
#   'internship',
#   'open',
#   'credit',
#   'complete',
#   'exceed',
#   '’',
#   'least',
#   'module',
#   'lead',
#   'week',
#   'duration',
#   'new',
#   'period',
#   'major',
#   'accessible',
#   'differentiate',
#   'pathway',
#   'academic',
#   'full-time',
#   'plan',
#   'viable',
#   'undergraduate',
#   'work'],
#  'AR2524': ['interface',
#   'control',
#   'allow',
#   'modelling',
#   'complex',
#   'algorithmic',
#   'formulation',
#   'spatial',
#   'parametric',
#   'familiar',
#   'function',
#   'flow',
#   'programming',
#   'student',
#   'datasets',
#   'vary',
#   'solution',
#   'learn',
#   'exploration',
#   'visual',
#   'data-structures',
#   'process',
#   'element',
#   'computational',
#   'involve',
#   'scale',
#   'building',
#   'fundamental',
#   'geometric',
#   'structure',
#   'various',
#   'integrate',
#   'thinking',
#   'decomposition',
#   'tool',
#   'idea',
#   'focus',
#   'test',
#   'recognise',
#   'generate',
#   'method',
#   'abstraction',
#   'manipulation',
#   'higher-level',
#   'develop',
#   'development',
#   'encapsulation',
#   'semantic',
#   'discipline'],
#  'AR3421': ['student',
#   'context',
#   'framework',
#   'building',
#   'operate',
#   'gain',
#   'construction',
#   'industry',
#   'module',
#   'professional',
#   'practice',
#   'design',
#   'architectural'],
#  'AR2723': ['energy',
#   'context',
#   'buildings',
#   'operation',
#   'technical',
#   'knowledge',
#   'architecture',
#   'student',
#   'solution',
#   'principle',
#   'basic',
#   'module',
#   'enable',
#   'water',
#   'issue',
#   'material',
#   'topic',
#   'sustainable',
#   'etc',
#   'focus',
#   'environmental',
#   'generate',
#   'deal',
#   'ecological',
#   'cover',
#   'design'],
#  'AR3721': ['light',
#   'well-being',
#   'address',
#   'assemble',
#   'sustainability',
#   'safety',
#   'achieve',
#   'acoustic',
#   'construction',
#   'exterior',
#   'fire',
#   'interior',
#   'familiarity',
#   'integration',
#   'physic',
#   'thermal',
#   'architecture',
#   'student',
#   'electric',
#   'learn',
#   'requirement',
#   'detail',
#   'introduce',
#   'symbiotic',
#   'building',
#   'fundamental',
#   'quantitative',
#   'practice',
#   'environment',
#   'various',
#   'structure',
#   'goal',
#   'material',
#   'understand',
#   'course',
#   'sustainable',
#   'consideration',
#   'manner',
#   'service',
#   'strategy',
#   'mean',
#   'human',
#   'build',
#   'relate',
#   'environmental',
#   'system',
#   'mechanical',
#   'performance-targets',
#   'code',
#   'technology',
#   'develop'],
#  'AR3102': ['program',
#   'address',
#   'context',
#   'natural',
#   'urban',
#   'brief',
#   'communication',
#   'integration',
#   'student',
#   'demonstrate',
#   'and/or',
#   'emphasis',
#   'environment',
#   'issue',
#   'thinking',
#   'objective',
#   'level',
#   'technological',
#   'build',
#   'site',
#   'technology',
#   'competence',
#   'research',
#   'give',
#   'generic',
#   'operational',
#   'design',
#   'acquisition'],
#  'AR4001': ['critical',
#   'computing',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'urban',
#   'theory',
#   'involve',
#   'thorough',
#   'design',
#   'module',
#   'architecture',
#   'heritage'],
#  'AR3102A': ['‘',
#   'experience',
#   'context',
#   'field',
#   'urban',
#   'city',
#   'open',
#   'architecture',
#   'architectural',
#   'student',
#   'studio-based',
#   'mark',
#   'basic',
#   'module',
#   'lead',
#   'public',
#   'central',
#   'landscape',
#   'build',
#   'studio',
#   'defines',
#   'space',
#   'develop',
#   'work',
#   'design',
#   'second-time'],
#  'AR4103': ['stage',
#   'light',
#   'specification',
#   'equivalent',
#   'scope',
#   'aesthetic',
#   'information',
#   'construction',
#   'translating',
#   'technical',
#   'architectural',
#   'student',
#   'solution',
#   'learn',
#   'separate',
#   'pre-tender',
#   'detail',
#   'scheme',
#   'design',
#   'submission',
#   'issue',
#   'opportunity',
#   'technological',
#   'resolution',
#   'activity',
#   'communicate',
#   'drawing',
#   'project',
#   'iv',
#   'ii',
#   'studio',
#   'aim',
#   'intention',
#   'eg',
#   'iii',
#   'architectural/construction',
#   'development'],
#  'AR4421': ['experience',
#   'perform',
#   'firm',
#   'internship',
#   'school',
#   'architectural',
#   'student',
#   'use',
#   'programme',
#   'gain',
#   'learnt',
#   'report',
#   'company/organization',
#   'logbook',
#   'exposure',
#   'professional',
#   'evaluation',
#   'opportunity',
#   'fourth',
#   'month',
#   'focus',
#   'organisation',
#   'minimum',
#   'setting',
#   'aim',
#   'year',
#   'undergraduate',
#   'part',
#   'work',
#   'design',
#   'weekly'],
#  'AR5011': ['brief',
#   'claim',
#   'approach',
#   'change',
#   'proceeds',
#   'and/or',
#   'presentation',
#   'definition',
#   'gain',
#   'language',
#   'task',
#   'lead',
#   'structure',
#   'interest',
#   'degree',
#   'university',
#   'instructor',
#   'course',
#   'aspect',
#   'premise',
#   'focus',
#   'parameter',
#   'undertake',
#   'writing',
#   'history',
#   'deal',
#   'discussion',
#   'method',
#   'dissertation',
#   'research',
#   'examine',
#   'develop',
#   'principal'],
#  'AR5121': ['specification',
#   'example',
#   'relevant',
#   'final',
#   'aware',
#   'right',
#   'student',
#   'requirement',
#   'introduce',
#   'design',
#   'building',
#   'module',
#   'select',
#   'issue',
#   'submission',
#   'conduct',
#   'topic',
#   'second',
#   'intensive',
#   'week',
#   'consideration',
#   'phase',
#   'compromise',
#   'workshop',
#   'project',
#   'performance',
#   'application',
#   'buildability',
#   's2',
#   'one-week',
#   'aim',
#   'writing',
#   'deal',
#   'individual',
#   'start',
#   'total',
#   'dissertation',
#   'management',
#   'advanced',
#   'code',
#   'successful',
#   'development',
#   'early',
#   'stage'],
#  'AR4002': ['supervision',
#   'evaluate',
#   'urban',
#   'ability',
#   'architecture',
#   'student',
#   'theory/history',
#   'carry',
#   'heritage',
#   'computing',
#   'course',
#   'area',
#   'study',
#   'faculty',
#   'member',
#   'independent',
#   'subject',
#   'research',
#   'design'],
#  'AR5321': ['lecturer',
#   'experience',
#   'engineer',
#   'aesthetic',
#   'proposal',
#   'multi-disciplinary',
#   'commence',
#   'charrette',
#   'learning',
#   'emerge',
#   'architecture',
#   'optimization',
#   'architectural',
#   'student',
#   'multidisciplinary',
#   'interdisciplinary',
#   'create',
#   'consultant',
#   'module',
#   'architect',
#   'problem-solving',
#   'practice',
#   'goal',
#   'case',
#   'foundation',
#   'study',
#   'series',
#   'performance',
#   'overview',
#   'roundtable',
#   'prepare',
#   'collaboration',
#   'innovative',
#   'advanced',
#   'technology',
#   'design',
#   'contemporary'],
#  'AR5322': ['fuel-based',
#   'energy',
#   'natural',
#   'construction',
#   'city',
#   'highlight',
#   'architecture',
#   'student',
#   'resource',
#   'need',
#   'scale',
#   'intend',
#   'building',
#   'practice',
#   'module',
#   'material',
#   'present',
#   'renewable',
#   'sustainable',
#   'different',
#   'understanding',
#   'single-house',
#   'strategy',
#   'interrelationship',
#   'application',
#   'source',
#   'shift',
#   'design',
#   'general'],
#  'AR4955': ['healthcare',
#   'example',
#   'post',
#   'housing',
#   'learning',
#   'architecture',
#   'architectural',
#   'participating',
#   'community',
#   'specific',
#   'involve',
#   'module',
#   'practice',
#   'discuss',
#   'critical',
#   'topic',
#   'evaluation',
#   'universal',
#   'methodology',
#   'discussion',
#   'place',
#   'occupancy',
#   'elderly',
#   'design'],
#  'AR5422': ['enter',
#   'responsibility',
#   'role',
#   'construction',
#   'institute',
#   'law',
#   'knowledge',
#   'architectural',
#   'sector',
#   'student',
#   'tort',
#   'property',
#   'singapore',
#   'module',
#   'architect',
#   'copyright',
#   'industry',
#   'practice',
#   'enable',
#   'branch',
#   'applicable',
#   'topic',
#   'public',
#   'form',
#   'major',
#   'understanding',
#   'legal',
#   'land',
#   'cover',
#   'duty',
#   'contract'],
#  'AR5423': ['b',
#   'control',
#   'lecture',
#   'context',
#   'category',
#   'responsibility',
#   'construction',
#   'change',
#   'law',
#   'knowledge',
#   'architecture',
#   'architectural',
#   'student',
#   'singapore',
#   'future',
#   'emergent',
#   'module',
#   'fundamental',
#   'practice',
#   'industry',
#   'structure',
#   'architect',
#   'building',
#   'topic',
#   'form',
#   'agency',
#   'understanding',
#   'legal',
#   'landscape',
#   'state',
#   'system',
#   'trajectory',
#   'code',
#   'technology',
#   'professional',
#   'planning',
#   'duty',
#   'c.',
#   'contract'],
#  'AR5601': ['place-making',
#   'intangible',
#   'instrumental',
#   'sustainability',
#   'urban',
#   'view',
#   'key',
#   'examination',
#   'in-depth',
#   'community',
#   'vital',
#   'myriad',
#   'social',
#   'introduce',
#   'future',
#   'design',
#   'module',
#   'perspective',
#   'local',
#   'issue',
#   'face',
#   'identity',
#   'topic',
#   'comprehensive',
#   'density',
#   'foundation',
#   'diversity',
#   'public',
#   'tangible',
#   'idea',
#   'theory',
#   'form',
#   'methodology',
#   'strategy',
#   'primary',
#   'challenge',
#   'focus',
#   'global',
#   'physical',
#   'range',
#   'praxis',
#   'rationale',
#   'examine',
#   'space',
#   'today'],
#  'AR5801': ['knowledge',
#   'student',
#   'cluster',
#   'drive',
#   'module',
#   'intellectual',
#   'select',
#   'interest',
#   'topic',
#   'opportunity',
#   'variety',
#   'curriculum',
#   'faculty',
#   'build',
#   'studio',
#   'year',
#   'first',
#   'undergraduate',
#   'research',
#   'investigation',
#   'theme',
#   'align',
#   'foundational',
#   'design'],
#  'AR5802': ['knowledge',
#   'student',
#   'cluster',
#   'drive',
#   'module',
#   'intellectual',
#   'select',
#   'interest',
#   'topic',
#   'opportunity',
#   'variety',
#   'curriculum',
#   'faculty',
#   'build',
#   'studio',
#   'year',
#   'first',
#   'undergraduate',
#   'research',
#   'investigation',
#   'theme',
#   'align',
#   'foundational',
#   'design'],
#  'AR5803': ['stage',
#   'light',
#   'specification',
#   'equivalent',
#   'scope',
#   'aesthetic',
#   'information',
#   'construction',
#   'translating',
#   'technical',
#   'architectural',
#   'student',
#   'solution',
#   'learn',
#   'separate',
#   'pre-tender',
#   'detail',
#   'scheme',
#   'design',
#   'submission',
#   'issue',
#   'opportunity',
#   'technological',
#   'resolution',
#   'activity',
#   'communicate',
#   'drawing',
#   'project',
#   'iv',
#   'ii',
#   'studio',
#   'aim',
#   'intention',
#   'eg',
#   'iii',
#   'architectural/construction',
#   'development'],
#  'AR5806': ['b',
#   'thesis',
#   'problem',
#   'hypothesis',
#   'address',
#   'f',
#   'statement',
#   'formulation',
#   'term',
#   'small',
#   'political',
#   'key',
#   'architecture',
#   'architectural',
#   'economic',
#   'significant',
#   'programme',
#   'g',
#   'delineate',
#   'social',
#   'intervention',
#   'design',
#   'literature',
#   'module',
#   'fundamental',
#   'selection',
#   'issue',
#   'cultural',
#   'critique',
#   'evaluation',
#   'technological',
#   'consideration',
#   'activity',
#   'precedent',
#   'study',
#   'site',
#   'preliminary',
#   'c',
#   'environmental',
#   'research',
#   'support',
#   'embody',
#   'acquisition'],
#  'AR5804': ['configuration',
#   'allow',
#   'optimal',
#   'interactive',
#   'student',
#   'solution',
#   'process',
#   'simulate',
#   'building',
#   'module',
#   'revit',
#   'impact',
#   'digital',
#   'form',
#   'performance',
#   'study',
#   'cfd',
#   'employ',
#   'development',
#   'design'],
#  'AR5807': ['stage',
#   'assign',
#   'thesis',
#   'brief',
#   'response',
#   'key',
#   'architectural',
#   'student',
#   'formulate',
#   'solution',
#   'supervisor',
#   'report',
#   'design',
#   'late',
#   'submission',
#   'issue',
#   'material',
#   'topic',
#   'comprehensive',
#   'technological',
#   'agenda',
#   'drawing',
#   'project',
#   'assist',
#   'spend',
#   'require',
#   'identify',
#   'studio',
#   'model',
#   'research',
#   'part'],
#  'AR5808': ['address',
#   'instrumental',
#   'positive',
#   'aesthetic',
#   'field',
#   'relevant',
#   'supervise',
#   'culmination',
#   'value',
#   'technical',
#   'final',
#   'learning',
#   'resource',
#   'student',
#   'demonstrate',
#   'panel',
#   'specialist',
#   'basis',
#   'arch',
#   'conservation',
#   'use',
#   'exploration',
#   'tutor',
#   'social',
#   'wider',
#   'building',
#   'emergent',
#   'industry',
#   'environment',
#   'specialization',
#   'issue',
#   'impact',
#   'experimentation',
#   'sustainable',
#   'resolution',
#   'form',
#   'agenda',
#   'drawing',
#   'project',
#   'assist',
#   'illustrate',
#   'produce',
#   'mean',
#   'practical',
#   'build',
#   'require',
#   'infrastructure',
#   'environmental',
#   'perceive',
#   'model',
#   'lab',
#   'technology',
#   'aid',
#   'management',
#   'research',
#   'predicate',
#   'choice',
#   'base',
#   'design',
#   'cultural'],
#  'AR5951': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5952A': ['example',
#   'urban',
#   'tropical',
#   'ecourbanism',
#   'specific',
#   'involve',
#   'module',
#   'practice',
#   'critical',
#   'topic',
#   'sustainable',
#   'methodology',
#   'study',
#   'thorough',
#   'discussion',
#   'planning',
#   'design'],
#  'AR5951A': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5952B': ['example',
#   'urban',
#   'tropical',
#   'ecourbanism',
#   'specific',
#   'involve',
#   'module',
#   'practice',
#   'critical',
#   'topic',
#   'sustainable',
#   'methodology',
#   'study',
#   'thorough',
#   'discussion',
#   'planning',
#   'design'],
#  'AR5951B': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5952E': ['regeneration',
#   'healthcare',
#   'asia',
#   'urban',
#   'approach',
#   'city',
#   'transdisciplinary',
#   'emerge',
#   'examination',
#   'student',
#   'community',
#   'data',
#   'economic',
#   'conservation',
#   'multiple',
#   'big',
#   'vision',
#   'future',
#   'emergent',
#   'module',
#   'resilience',
#   'perspective',
#   'issue',
#   'various',
#   'face',
#   'character',
#   'expose',
#   'participation',
#   'offer',
#   'topic',
#   'sustainable',
#   'new',
#   'informality',
#   'technological',
#   'form',
#   'age',
#   'understanding',
#   'norm',
#   'question',
#   'distinctive',
#   'strategy',
#   'conception',
#   'challenge',
#   'inter-',
#   'relate',
#   'model',
#   'cope',
#   'environmental',
#   'asian',
#   'innovative',
#   'provide',
#   'complexity',
#   'social',
#   'conventional',
#   'today'],
#  'AR5951C': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5954A': ['example',
#   'urban',
#   'city',
#   'visualisation',
#   'architecture',
#   'specific',
#   'megacities',
#   'module',
#   'informal',
#   'discuss',
#   'critical',
#   'topic',
#   'sustainable',
#   'landscape',
#   'discussion',
#   'design'],
#  'AR5951L': ['healthcare',
#   'exercise',
#   'appropriate',
#   'post',
#   'population',
#   'knowledge',
#   'systematic',
#   'holistic',
#   'learn',
#   'gain',
#   'able',
#   'basic',
#   'module',
#   'conduct',
#   'evaluation',
#   'consideration',
#   'manner',
#   'age',
#   'frame',
#   'question',
#   'skill',
#   'setting',
#   'aim',
#   'group',
#   'occupancy',
#   'design'],
#  'AR5954B': ['example',
#   'urban',
#   'city',
#   'visualisation',
#   'architecture',
#   'specific',
#   'architecturein',
#   'megacities',
#   'module',
#   'informal',
#   'discuss',
#   'critical',
#   'topic',
#   'sustainable',
#   'landscape',
#   'thorough',
#   'discussion',
#   'design'],
#  'AR5953A': ['example',
#   'construct',
#   'role',
#   'technique',
#   'validation',
#   'specific',
#   'process',
#   'involve',
#   'module',
#   'typology',
#   'critical',
#   'thinking',
#   'material',
#   'topic',
#   'new',
#   'relationship',
#   'tool',
#   'form',
#   'performance',
#   'thorough',
#   'fabric',
#   'system',
#   'discussion',
#   'technology',
#   'design',
#   'evolve'],
#  'AR5955': ['‘',
#   'healthcare',
#   'example',
#   'post',
#   'housing',
#   'learning',
#   'architecture',
#   'architectural',
#   'participating',
#   'community',
#   'specific',
#   'involve',
#   'module',
#   'practice',
#   'parent',
#   'discuss',
#   'critical',
#   'topic',
#   'evaluation',
#   'universal',
#   'methodology',
#   'discussion',
#   'place',
#   'occupancy',
#   'elderly',
#   'design'],
#  'AR5953B': ['example',
#   'construct',
#   'role',
#   'technique',
#   'validation',
#   'specific',
#   'process',
#   'involve',
#   'module',
#   'typology',
#   'critical',
#   'thinking',
#   'material',
#   'topic',
#   'new',
#   'relationship',
#   'tool',
#   'form',
#   'performance',
#   'thorough',
#   'fabric',
#   'system',
#   'discussion',
#   'technology',
#   'design',
#   'evolve'],
#  'AR5956A': ['example',
#   'urban',
#   'construct',
#   'technique',
#   'module',
#   'environment',
#   'critical',
#   'thinking',
#   'topic',
#   'universal',
#   'sustainable',
#   'landscape',
#   'thorough',
#   'discussion',
#   'ecology',
#   'design'],
#  'AR5953D': ['example',
#   'construct',
#   'role',
#   'technique',
#   'validation',
#   'specific',
#   'process',
#   'involve',
#   'module',
#   'typology',
#   'critical',
#   'thinking',
#   'material',
#   'topic',
#   'new',
#   'relationship',
#   'tool',
#   'form',
#   'performance',
#   'thorough',
#   'fabric',
#   'system',
#   'discussion',
#   'technology',
#   'design',
#   'evolve'],
#  'AR5956B': ['example',
#   'urban',
#   'construct',
#   'technique',
#   'module',
#   'environment',
#   'critical',
#   'thinking',
#   'topic',
#   'universal',
#   'sustainable',
#   'landscape',
#   'thorough',
#   'discussion',
#   'ecology',
#   'design'],
#  'AR5954': ['example',
#   'urban',
#   'city',
#   'visualisation',
#   'architecture',
#   'specific',
#   'megacities',
#   'module',
#   'informal',
#   'discuss',
#   'critical',
#   'topic',
#   'sustainable',
#   'landscape',
#   'discussion',
#   'design'],
#  'AR5956C': ['example',
#   'urban',
#   'construct',
#   'technique',
#   'module',
#   'environment',
#   'critical',
#   'thinking',
#   'topic',
#   'universal',
#   'sustainable',
#   'landscape',
#   'thorough',
#   'discussion',
#   'ecology',
#   'design'],
#  'AR5956D': ['example',
#   'urban',
#   'construct',
#   'technique',
#   'module',
#   'environment',
#   'critical',
#   'thinking',
#   'topic',
#   'universal',
#   'sustainable',
#   'landscape',
#   'thorough',
#   'discussion',
#   'ecology',
#   'design'],
#  'AR5956E': ['example',
#   'urban',
#   'construct',
#   'technique',
#   'module',
#   'environment',
#   'critical',
#   'thinking',
#   'topic',
#   'universal',
#   'sustainable',
#   'landscape',
#   'thorough',
#   'discussion',
#   'ecology',
#   'design'],
#  'AR5954C': ['example',
#   'urban',
#   'city',
#   'visualisation',
#   'architecture',
#   'specific',
#   'megacities',
#   'module',
#   'informal',
#   'discuss',
#   'critical',
#   'topic',
#   'sustainable',
#   'landscape',
#   'discussion',
#   'design'],
#  'AR5957A': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5955B': ['contingent',
#   'asia',
#   'aesthetic',
#   'novel',
#   'emerge',
#   'architecture',
#   'student',
#   'resource',
#   'theoretical',
#   'fabrication',
#   'design',
#   'emergent',
#   'east',
#   'wide',
#   'material',
#   'expose',
#   'case',
#   'climatic',
#   'theory',
#   'south',
#   'concept',
#   'strategy',
#   'precedent',
#   'performance',
#   'study',
#   'act',
#   'range',
#   'underpin',
#   'history',
#   'surround',
#   'production',
#   'equator',
#   'research',
#   'calibration',
#   'inhabitation',
#   'space',
#   'architectonics',
#   'inform',
#   'contemporary'],
#  'AR5957B': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5957C': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5957D': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5957E': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5957F': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5958A': ['example',
#   'urban',
#   'specific',
#   'involve',
#   'module',
#   'practice',
#   'critical',
#   'topic',
#   'sustainable',
#   'methodology',
#   'study',
#   'discussion',
#   'planning',
#   'design'],
#  'AR5956F': ['example',
#   'urban',
#   'construct',
#   'technique',
#   'module',
#   'environment',
#   'critical',
#   'thinking',
#   'topic',
#   'universal',
#   'sustainable',
#   'landscape',
#   'thorough',
#   'discussion',
#   'ecology',
#   'design'],
#  'AR5958B': ['example',
#   'urban',
#   'specific',
#   'involve',
#   'module',
#   'practice',
#   'critical',
#   'topic',
#   'sustainable',
#   'methodology',
#   'study',
#   'discussion',
#   'planning',
#   'design'],
#  'AR5958C': ['example',
#   'urban',
#   'specific',
#   'involve',
#   'module',
#   'practice',
#   'critical',
#   'topic',
#   'sustainable',
#   'methodology',
#   'study',
#   'discussion',
#   'planning',
#   'design'],
#  'AR5957G': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5959A': ['example',
#   'construct',
#   'role',
#   'technique',
#   'validation',
#   'specific',
#   'process',
#   'involve',
#   'module',
#   'typology',
#   'critical',
#   'thinking',
#   'material',
#   'topic',
#   'new',
#   'relationship',
#   'tool',
#   'form',
#   'performance',
#   'thorough',
#   'fabric',
#   'system',
#   'discussion',
#   'technology',
#   'design',
#   'evolve'],
#  'AR5957H': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5959B': ['example',
#   'construct',
#   'role',
#   'technique',
#   'validation',
#   'specific',
#   'process',
#   'involve',
#   'module',
#   'typology',
#   'critical',
#   'thinking',
#   'material',
#   'topic',
#   'new',
#   'relationship',
#   'tool',
#   'form',
#   'performance',
#   'thorough',
#   'fabric',
#   'system',
#   'discussion',
#   'technology',
#   'design',
#   'evolve'],
#  'AR5957I': ['critical',
#   'analysis',
#   'history',
#   'topic',
#   'specific',
#   'discussion',
#   'criticism',
#   'theory',
#   'involve',
#   'module',
#   'architecture'],
#  'AR5959C': ['example',
#   'construct',
#   'role',
#   'technique',
#   'validation',
#   'specific',
#   'process',
#   'involve',
#   'module',
#   'typology',
#   'critical',
#   'thinking',
#   'material',
#   'topic',
#   'new',
#   'relationship',
#   'tool',
#   'form',
#   'performance',
#   'thorough',
#   'fabric',
#   'system',
#   'discussion',
#   'technology',
#   'design',
#   'evolve'],
#  'AR5957J': ['critical',
#   'analysis',
# ...
#   'advantage',
#   'big',
#   'introduce',
#   'basic',
#   'environment',
#   'era',
#   'master',
#   'essential',
#   'teach',
#   'present',
#   'objective',
#   'sharing',
#   'visualize',
#   'powerful',
#   'course',
#   'competitive',
#   'case',
#   'way',
#   'r',
#   'analyse',
#   'study',
#   'enterprise',
#   'managerial',
#   'become',
#   'structured',
#   'decision',
#   'order',
#   'meaningful'],
#  'DSC3215': ['discrete',
#   'probabilistic',
#   'measure',
#   'world',
#   'random',
#   'operation',
#   'field',
#   'evaluate',
#   'construct',
#   'characterise',
#   'chain',
#   'student',
#   'demonstrate',
#   'inadequate',
#   'real',
#   'manage',
#   'phenomenon',
#   'simulate',
#   'randomness',
#   'introduce',
#   'feasible',
#   'module',
#   'discuss',
#   'engineering',
#   'well-known',
#   'markov',
#   'financial',
#   'inventory',
#   'science',
#   'illustrate',
#   'performance',
#   'study',
#   'application',
#   'model',
#   'finance',
#   'simulation',
#   'queue',
#   'system',
#   'analytical',
#   'method',
#   'management',
#   'elementary',
#   'several'],
#  'DSC3216': ['rest',
#   'forecast',
#   'firm',
#   'personnel',
#   'season',
#   'business',
#   'intelligence',
#   'value',
#   'technique',
#   'line',
#   'survey',
#   'extensive',
#   'chain',
#   'ability',
#   'emerge',
#   'e.g',
#   'time',
#   'network',
#   'supply',
#   'cycle',
#   'demand',
#   'regression',
#   'requirement',
#   'good',
#   'drive',
#   'module',
#   'quantitative',
#   'logistics',
#   'excel',
#   'encompass',
#   'schedule',
#   'capital',
#   'delphi',
#   'service',
#   'package',
#   'software',
#   'concept',
#   'illustrate',
#   'series',
#   'investment',
#   'application',
#   'qualitative',
#   'forecasting',
#   'traditional',
#   'front',
#   'production',
#   'method',
#   'neural',
#   'etc.this',
#   'managerial',
#   'success',
#   'trend',
#   'effective',
#   'provide',
#   'base',
#   'planning'],
#  'DBA3712': ['life',
#   'insight',
#   'logic',
#   'pricing',
#   'business',
#   'value',
#   'knowledge',
#   'deliver',
#   'price',
#   'conceptual',
#   'dynamic',
#   'supply',
#   'real',
#   'need',
#   'demand',
#   'multidisciplinary',
#   'good',
#   'principle',
#   'tactical',
#   'manager',
#   'design',
#   'consultant',
#   'maximum',
#   'applicable',
#   'framework',
#   'underlie',
#   'course',
#   'extract',
#   'tool',
#   'service',
#   'strategic',
#   'bundle',
#   'application',
#   'recommendation',
#   'revenue',
#   'high-level',
#   'managerial',
#   'management',
#   'align',
#   'state-of-art',
#   'operational',
#   'general'],
#  'DSC3224': ['life',
#   'insight',
#   'logic',
#   'pricing',
#   'business',
#   'value',
#   'knowledge',
#   'deliver',
#   'price',
#   'conceptual',
#   'dynamic',
#   'supply',
#   'real',
#   'need',
#   'demand',
#   'multidisciplinary',
#   'good',
#   'principle',
#   'tactical',
#   'manager',
#   'design',
#   'consultant',
#   'maximum',
#   'applicable',
#   'framework',
#   'underlie',
#   'course',
#   'extract',
#   'tool',
#   'service',
#   'strategic',
#   'bundle',
#   'application',
#   'recommendation',
#   'revenue',
#   'high-level',
#   'managerial',
#   'management',
#   'align',
#   'state-of-art',
#   'operational',
#   'general'],
#  'DSC3229': ['business',
#   'ism',
#   'report-writing',
#   'student',
#   'individual-based',
#   'tackle',
#   'module',
#   'issue',
#   'specialization',
#   'requisite',
#   'expose',
#   'well-defined',
#   'instructor',
#   'respective',
#   'project',
#   'area',
#   'study',
#   'independent',
#   'research',
#   'background',
#   'guidance',
#   'work'],
#  'DBA4811': ['data',
#   'segmentation',
#   'rank',
#   'consultant',
#   'environment',
#   'medium',
#   'advancement',
#   'stattools',
#   'challenge',
#   'magazine',
#   'skill',
#   'capstone',
#   'prepare',
#   'analytical',
#   'management',
#   'cover',
#   'hr',
#   'problem',
#   'forecast',
#   'analytics',
#   'department',
#   'demand',
#   'process',
#   'refine',
#   'audience',
#   'knowledge-based',
#   'stress',
#   'benchmark',
#   'face',
#   'case',
#   'topic',
#   'precision',
#   'tree',
#   'strategic',
#   'polish',
#   'software',
#   'work',
#   'analysis',
#   'auction',
#   'firm',
#   'business',
#   'money',
#   'participant',
#   'write',
#   'diverse',
#   'communication',
#   'chain',
#   'optimization',
#   'flow',
#   'supply',
#   'cluster',
#   'result',
#   'staff',
#   'position',
#   'reverse',
#   'level',
#   'seasonal',
#   'analyst',
#   'salary',
#   'mining',
#   'forecasting',
#   'finance',
#   'job',
#   'simulation',
#   'efficient',
#   'cash',
#   'marketing',
#   'profitable',
#   'experience',
#   'oral',
#   'outsource',
#   'top',
#   'crm',
#   'evolutionary',
#   'survey',
#   'extensive',
#   'e.g',
#   'customer-centric',
#   'gain',
#   'satisfaction',
#   'risk',
#   'pedagogical',
#   'solver',
#   'right-sizing',
#   'objective',
#   'course',
#   'customer',
#   'revenue',
#   'decision',
#   'support'],
#  'DSC4213': ['data',
#   'segmentation',
#   'rank',
#   'consultant',
#   'environment',
#   'medium',
#   'advancement',
#   'stattools',
#   'challenge',
#   'magazine',
#   'skill',
#   'capstone',
#   'prepare',
#   'analytical',
#   'management',
#   'cover',
#   'hr',
#   'problem',
#   'forecast',
#   'analytics',
#   'department',
#   'demand',
#   'process',
#   'refine',
#   'audience',
#   'knowledge-based',
#   'stress',
#   'benchmark',
#   'face',
#   'case',
#   'topic',
#   'precision',
#   'tree',
#   'strategic',
#   'polish',
#   'software',
#   'work',
#   'analysis',
#   'auction',
#   'firm',
#   'business',
#   'money',
#   'participant',
#   'write',
#   'diverse',
#   'communication',
#   'chain',
#   'optimization',
#   'flow',
#   'supply',
#   'cluster',
#   'result',
#   'staff',
#   'position',
#   'reverse',
#   'level',
#   'seasonal',
#   'analyst',
#   'salary',
#   'mining',
#   'forecasting',
#   'finance',
#   'job',
#   'simulation',
#   'efficient',
#   'cash',
#   'marketing',
#   'profitable',
#   'experience',
#   'oral',
#   'outsource',
#   'top',
#   'crm',
#   'evolutionary',
#   'survey',
#   'extensive',
#   'e.g',
#   'customer-centric',
#   'gain',
#   'satisfaction',
#   'risk',
#   'pedagogical',
#   'solver',
#   'right-sizing',
#   'objective',
#   'course',
#   'customer',
#   'revenue',
#   'decision',
#   'support'],
#  'DE5107': ['program',
#   'policy',
#   'measure',
#   'instrument',
#   'urban',
#   'graduate',
#   'formulation',
#   'construction',
#   'technical',
#   'multi-disciplinary',
#   'architecture',
#   'explore',
#   'sector',
#   'resource',
#   'student',
#   'demonstrate',
#   'target',
#   'procedure',
#   'economic',
#   'process',
#   'use',
#   'principle',
#   'introduce',
#   'nature',
#   'basic',
#   'module',
#   'local',
#   'mitigation',
#   'environment',
#   'decision-making',
#   'selection',
#   'regulatory',
#   'discuss',
#   'master',
#   'objective',
#   'framework',
#   'impact',
#   'suitability',
#   'public',
#   'sustainable',
#   'course',
#   'strategic',
#   'introduction',
#   'theory',
#   'apply',
#   'project',
#   'investment',
#   'physical',
#   'site',
#   'environmental',
#   'regional',
#   'candidate',
#   'participatory',
#   'plan',
#   'discussion',
#   'subject',
#   'augmentation',
#   'management',
#   'research',
#   'decision',
#   'availability',
#   'cover',
#   'place',
#   'intensity',
#   'development',
#   'planning',
#   'design'],
#  'DSC4216': ['stream',
#   'type',
#   'information',
#   'business',
#   'role',
#   'productivity',
#   'change',
#   'growth',
#   'cluster',
#   'organization',
#   'tailor',
#   'myriad',
#   'overabundance',
#   'create',
#   'tackle',
#   'manager',
#   'help',
#   'various',
#   'face',
#   'size',
#   'organizational',
#   'new',
#   'manner',
#   'age',
#   'way',
#   'different',
#   'differentiate',
#   'deploy',
#   'organisation',
#   'methodology',
#   'determine',
#   'assist',
#   'revenue',
#   'identifying',
#   'organisational',
#   'categorize',
#   'choice',
#   'leader',
#   'technology',
#   'stage',
#   'invest'],
#  'DSC4219': ['program',
#   'business',
#   'admission',
#   'ism',
#   'senior',
#   'report-writing',
#   'non-honors',
#   'student',
#   'bba',
#   'available',
#   'tackle',
#   'module',
#   'specialization',
#   'issue',
#   'requisite',
#   'well-defined',
#   'instructor',
#   'course',
#   'respective',
#   'project',
#   'area',
#   'study',
#   'independent',
#   'eligible',
#   'honor',
#   'choose',
#   'research',
#   'acc',
#   'guidance',
#   'work'],
#  'DSC5101': ['example',
#   'participant',
#   'price',
#   'datasets',
#   'theoretical',
#   'economic',
#   'lay',
#   'use',
#   'formation',
#   'market',
#   'industry',
#   'analyze',
#   'framework',
#   'competitive',
#   'strategic',
#   'statistical',
#   'performance',
#   'model',
#   'method',
#   'interaction',
#   'stochastic'],
#  'DSC5102': ['world',
#   'team',
#   'collection',
#   'business',
#   'learning',
#   'knowledge',
#   'student',
#   'engage',
#   'competency',
#   'solution',
#   'data',
#   'organization',
#   'real',
#   'insightful',
#   'module',
#   'issue',
#   'organizational',
#   'opportunity',
#   'span',
#   'capability',
#   'academic',
#   'important',
#   'aim',
#   'personal',
#   'action-based',
#   'year',
#   'setting',
#   'professional',
#   'work',
#   'analysis'],
#  'DEP5103A': ['profession',
#   'analysis',
#   'urban',
#   'technique',
#   'limitation',
#   'planning',
#   'appreciate',
#   'student',
#   'data',
#   'emphasis',
#   'basic',
#   'module',
#   'quantitative',
#   'practice',
#   'common',
#   'conduct',
#   'argument',
#   'introduction',
#   'power',
#   'statistical',
#   'sound',
#   'prepare',
#   'review',
#   'plan',
#   'discussion',
#   'research',
#   'work',
#   'design'],
#  'DSC5211A': ['control',
#   'insight',
#   'operation',
#   'business',
#   'technique',
#   'chain',
#   'robust',
#   'student',
#   'supply',
#   'gain',
#   'modeling/analysis',
#   'recent',
#   'introduce',
#   'design',
#   'risk',
#   'discuss',
#   'issue',
#   'expose',
#   'understand',
#   'objective',
#   'topic',
#   'conduct',
#   'course',
#   'coordination',
#   'variety',
#   'tool',
#   'focus',
#   'important',
#   'management',
#   'efficient',
#   'development',
#   'analysis'],
#  'DTS5701': ['system', 'engineering', 'scale', 'large'],
#  'DTS5702': ['appreciation',
#   'approach',
#   'participant',
#   'well',
#   'integration',
#   'emerge',
#   'key',
#   'underlying',
#   'modern',
#   'use',
#   'good',
#   'principle',
#   'module',
#   'practice',
#   'c3',
#   'enable',
#   'weapon',
#   'topic',
#   'engineering',
#   'consideration',
#   'concept',
#   'challenge',
#   'sensor',
#   'application',
#   'system',
#   'associate',
#   'trend',
#   'cover',
#   'technology',
#   'development',
#   'design'],
#  'DEP5109': ['field',
#   'supervise',
#   'urban',
#   'complex',
#   'final',
#   'ability',
#   'student',
#   'twofold',
#   'basis',
#   'prove',
#   'specific',
#   'mup',
#   'programme',
#   'tutor',
#   'content',
#   'intend',
#   'module',
#   'perspective',
#   'master',
#   'interest',
#   'topic',
#   'opportunity',
#   'coordination',
#   'project',
#   'specialise',
#   'last',
#   'studio',
#   'aim',
#   'undertake',
#   'hand',
#   'individual',
#   'choose',
#   'research',
#   'align',
#   'professional',
#   'planning'],
#  'DTS5734': ['counter-measures',
#   'control',
#   'tracking',
#   'teaming',
#   'e.g',
#   'counter-counter-measures',
#   'target',
#   'mission',
#   'uxvs',
#   'principle',
#   'smart',
#   'module',
#   'various',
#   'weapon',
#   'case',
#   'topic',
#   'impact',
#   'precision',
#   'guidance/navigation',
#   'additional',
#   'aspect',
#   'identification',
#   'command',
#   'consideration',
#   'interoperability',
#   'cooperation',
#   'course',
#   'concept',
#   'vehicle',
#   'study',
#   'actual',
#   'technology',
#   'system',
#   'sub-systems',
#   'munition',
#   'combat',
#   'examine',
#   'cover',
#   'effectiveness',
#   'operational',
#   'interplay'],
#  'DOS3702': ['control',
#   'problem',
#   'lecture',
#   'assignment',
#   'instrument',
#   'insight',
#   'distribution',
#   'acquaint',
#   'field',
#   'considerable',
#   'interactive',
#   'key',
#   'student',
#   'supply',
#   'combination',
#   'attention',
#   'use',
#   'informative',
#   'big',
#   'logistics',
#   'fundamental',
#   'issue',
#   'material',
#   'case',
#   'pedagogy',
#   'devote',
#   'course',
#   'inventory',
#   'area',
#   'concept',
#   'primary',
#   'practical',
#   'model',
#   'current',
#   'discussion',
#   'buy',
#   'management',
#   'interested',
#   'managerial',
#   'application-oriented',
#   'provide',
#   'cover',
#   'stock',
#   'development',
#   'purchasing',
#   'contract'],
#  'DTS5735': ['policy',
#   'operation',
#   'communication',
#   'learning',
#   'making',
#   'manage',
#   'use',
#   'cryptography',
#   'introduce',
#   'module',
#   'various',
#   'computing',
#   'attack',
#   'case',
#   'topic',
#   'cybersecurity',
#   'factor',
#   'activity',
#   'concept',
#   'illustrate',
#   'human',
#   'study',
#   'reinforce',
#   'application',
#   'malicious',
#   'mitigate',
#   'security',
#   'aim',
#   'threat',
#   'system',
#   'trust',
#   'cloud',
#   'iot',
#   'foundational',
#   'channel'],
#  'DOS3703': ['relating',
#   'control',
#   'problem',
#   'analysis',
#   'outlet',
#   'operation',
#   'improvement',
#   'bank',
#   'wish',
#   'planning',
#   'quality',
#   'hospital',
#   'allocation',
#   'student',
#   'resource',
#   'systematic',
#   'scheduling',
#   'manage',
#   'service-oriented',
#   'consultant',
#   'restaurant',
#   'environment',
#   'essential',
#   'retail',
#   'location',
#   'objective',
#   'airline',
#   'comprehensive',
#   'topic',
#   'workshift',
#   'course',
#   'vehicular',
#   'service',
#   'agency',
#   'strategy',
#   'organisation',
#   'routing',
#   'coverage',
#   'system',
#   'cover',
#   'work',
#   'design'],
#  'DTS5736': ['problem',
#   'multi-dimensional',
#   'unman',
#   'operation',
#   'complex',
#   'defence',
#   'intelligence',
#   'student',
#   'formulate',
#   'solution',
#   'principle',
#   'artificial',
#   'module',
#   'c3',
#   'integrate',
#   'goal',
#   'engineering',
#   'etc',
#   'sensor',
#   'study',
#   'analyse',
#   'actual',
#   'military',
#   'technology',
#   'system',
#   'research',
#   'cyber',
#   'design'],
#  'DSA2102': ['interpolation',
#   'program',
#   'linear',
#   'multiplication',
#   'draw',
#   'example',
#   'analytics',
#   'numerical',
#   'sample',
#   'integration',
#   'examination',
#   'programming',
#   'industrial',
#   'data',
#   'least',
#   'language',
#   'introduce',
#   'emphasis',
#   'basic',
#   'module',
#   'various',
#   'concrete',
#   'algorithm',
#   'compute',
#   'implementation',
#   'topic',
#   'foundation',
#   'arithmetic',
#   'major',
#   'computer',
#   'solve',
#   'concept',
#   'science',
#   'related',
#   'practical',
#   'application',
#   'relate',
#   'aim',
#   'tight',
#   'system',
#   'square',
#   'method',
#   'discipline'],
#  'DY5190': ['promote',
#   'communication',
#   'grade',
#   'student',
#   'attendance',
#   'presentation',
#   'basis',
#   'conference',
#   'dentistry',
#   'culture',
#   'module',
#   'participation',
#   'spread',
#   'faculty',
#   'candidature',
#   'strong',
#   'research',
#   'satisfactory/unsatisfactory',
#   'design'],
#  'DY5310': ['integral',
#   'lecture',
#   'program',
#   'biomedical',
#   'didactic',
#   'finding',
#   'meeting',
#   'teaching',
#   'treatment',
#   'session',
#   'basis',
#   'component',
#   'encourage',
#   'increase',
#   'laboratory',
#   'multidisciplinary',
#   'programme',
#   'main',
#   'conference',
#   'principle',
#   'array',
#   'understan',
#   'literature',
#   'basic',
#   'local',
#   'educational',
#   'attend',
#   'dentistry',
#   'exposure',
#   'interest',
#   'college',
#   'present',
#   'conduct',
#   'attachment',
#   'feature',
#   '3-4',
#   'seminar',
#   'week',
#   'opportunity',
#   'state-of-the-art',
#   'incorporate',
#   'etc',
#   'project',
#   'science',
#   'practical',
#   'training',
#   'baylor',
#   'endodontic',
#   'require',
#   'international',
#   'resident',
#   'clinical',
#   'technology',
#   'review',
#   'residency',
#   'endodontics',
#   'research',
#   'undergraduate',
#   'instruction',
#   'diagnostic',
#   'corroborate',
#   'part',
#   'planning',
#   'table-clinics'],
#  'DSA4212': ['data-driven',
#   'problem',
#   'type',
#   'example',
#   'relevant',
#   'approach',
#   'implement',
#   'learning',
#   'programming',
#   'machine',
#   'use',
#   'language',
#   'computational',
#   'scale',
#   'emphasis',
#   'principle',
#   'detail',
#   'module',
#   'optimisation',
#   'python',
#   'algorithm',
#   'topic',
#   'large',
#   'inference',
#   'second',
#   'many',
#   'statistical',
#   'duality',
#   'ubiquitous',
#   'current',
#   'method',
#   'gradient',
#   'efficient',
#   'order',
#   'cover',
#   'several',
#   'stochastic'],
#  'DY5320': ['interface',
#   'experience',
#   'oral',
#   'equivalent',
#   'evaluate',
#   'knowledge',
#   'surgery',
#   'examination',
#   'student',
#   'theoretical',
#   'publication',
#   'component',
#   'programme',
#   'patient',
#   'conference',
#   'interdisciplinary',
#   'palate',
#   'basic',
#   'carry',
#   'wide',
#   'practice',
#   'enable',
#   'cleft',
#   'competent',
#   'high',
#   'foundation',
#   'course',
#   'specialty',
#   'exempt',
#   'communicate',
#   'paper',
#   'incorporate',
#   'project',
#   'primary',
#   'science',
#   'practical',
#   'training',
#   'resident',
#   'clinical',
#   'neck',
#   'orthognathic',
#   'scientific',
#   'lip',
#   'residency',
#   'condition',
#   'three-year',
#   'maxillofacial',
#   'year',
#   'management',
#   'research',
#   'journal',
#   'take',
#   'discipline'],
#  ...}

# %%
id2word = corpora.Dictionary(d.values())
corpus = [id2word.doc2bow(text) for text in d.values()]
freq = [[(id2word[id], freq) for id, freq in cp] for cp in corpus]
freq_d = {}
for f in freq:
    for f2 in f:
        if f2[0] in freq_d:
            freq_d[f2[0]] += f2[1]
        else:
            freq_d[f2[0]] = f2[1]
freq_d
# Out:
# {'account': 83,
#  'accounting': 42,
#  'attain': 14,
#  'course': 1529,
#  'creditor': 9,
#  'decision': 237,
#  'decision-making': 49,
#  'derive': 38,
#  'examine': 648,
#  'external': 53,
#  'familiar': 47,
#  'financial': 205,
#  'good': 270,
#  'information': 249,
#  'introduction': 349,
#  'investing': 7,
#  'investor': 27,
#  'learn': 453,
#  'lending': 11,
#  'make': 81,
#  'necessary': 140,
#  'need': 104,
#  'order': 163,
#  'perspective': 306,
#  'report': 160,
#  'result': 105,
#  'statement': 39,
#  'understand': 322,
#  'understanding': 683,
#  'user': 43,
#  'accounting/business': 2,
#  'advantage': 32,
#  'aim': 653,
#  'application': 761,
#  'area': 372,
#  'business': 412,
#  'chain': 60,
#  'competitive': 54,
#  'cycle': 69,
#  'different': 461,
#  'enhance': 112,
#  'finance/accounting': 2,
#  'functional': 77,
#  'hr/management': 2,
#  'innovative': 50,
#  'marketing': 106,
#  'operation': 197,
#  'particular': 255,
#  'role': 460,
#  'streamline': 2,
#  'student': 2999,
#  'supply': 71,
#  'system': 837,
#  'use': 945,
#  'various': 638,
#  'aware': 13,
#  'book-keeping': 2,
#  'cover': 1172,
#  'focus': 771,
#  'help': 234,
#  'introductory': 117,
#  'level': 259,
#  'preparation': 51,
#  'provide': 403,
#  'reporting': 17,
#  'viewpoint': 16,
#  'activity': 151,
#  'appreciation': 111,
#  'change': 296,
#  'concept': 823,
#  'contemporary': 275,
#  'context': 350,
#  'control': 291,
#  'emphasis': 359,
#  'environment': 351,
#  'evolves': 2,
#  'major': 674,
#  'managerial': 44,
#  'organisational': 27,
#  'planning': 220,
#  'technique': 626,
#  'tool': 392,
#  'traditional': 122,
#  'usefulness': 16,
#  'asset': 63,
#  'equipment': 35,
#  'estimate': 28,
#  'event': 83,
#  'impairment': 4,
#  'intangible': 4,
#  'interim': 11,
#  'intermediate': 28,
#  'investment': 167,
#  'module': 3447,
#  'plant': 51,
#  'policy': 337,
#  'post-balance-sheet': 1,
#  'property': 237,
#  'reference': 75,
#  'revenue': 13,
#  'sale': 25,
#  'segment': 18,
#  'special': 149,
#  'benefit': 36,
#  'compensation': 10,
#  'employee': 25,
#  'instrument': 90,
#  'lease': 7,
#  'provision': 27,
#  'share-based': 1,
#  'tax': 24,
#  'assurance': 16,
#  'attestation': 3,
#  'attitude': 26,
#  'audit': 18,
#  'career': 95,
#  'engagement': 48,
#  'knowledge': 595,
#  'management': 549,
#  'process': 715,
#  'profession': 18,
#  'require': 187,
#  'allow': 96,
#  'conceptual': 114,
#  'consolidated': 1,
#  'corporate': 117,
#  'currency': 21,
#  'earnings': 4,
#  'economic': 340,
#  'equip': 141,
#  'financing': 46,
#  'foreign': 97,
#  'framework': 221,
#  'international': 348,
#  'issue': 894,
#  'item': 10,
#  'leasing': 1,
#  'off-balance': 1,
#  'quality': 124,
#  'rationale': 24,
#  'requirement': 139,
#  'sheet': 4,
#  'skill': 283,
#  'standard': 117,
#  'theoretical': 271,
#  'topic': 1593,
#  'translation': 22,
#  'treatment': 107,
#  'u': 80,
#  'underlie': 65,
#  'act': 44,
#  'amp': 9,
#  'code': 34,
#  'company': 129,
#  'entire': 24,
#  'entity': 40,
#  'formation': 73,
#  'future': 123,
#  'implication': 120,
#  'introduce': 698,
#  'legal': 289,
#  'legislation': 19,
#  'life-span': 3,
#  'liquidation': 3,
#  'objective': 363,
#  'obligation': 36,
#  'operate': 58,
#  'pertinent': 60,
#  'primary': 103,
#  'secondary': 25,
#  'security': 153,
#  'solid': 85,
#  'takeover': 8,
#  'basic': 801,
#  'consult': 13,
#  'crucial': 26,
#  'field': 334,
#  'income': 34,
#  'large': 115,
#  'organisation': 121,
#  'payment': 21,
#  'portion': 17,
#  'profit': 17,
#  'relevant': 272,
#  'singapore': 275,
#  'taxation': 25,
#  'towards': 73,
#  'wish': 53,
#  'work': 763,
#  'acc1002': 1,
#  'acc3601': 1,
#  'centre': 31,
#  'complex': 240,
#  'cpa': 1,
#  'discussion': 318,
#  'explore': 182,
#  'fair': 13,
#  'firm': 90,
#  'great': 71,
#  'preparer': 1,
#  'profitability': 15,
#  'relate': 307,
#  'risk': 187,
#  'value': 182,
#  'able': 189,
#  'accountant': 4,
#  'analysis': 900,
#  'available': 88,
#  'cash': 20,
#  'certain': 30,
#  'class': 217,
#  'coverage': 69,
#  'discount': 9,
#  'enterprise': 57,
#  'flow': 109,
#  'importance': 126,
#  'include': 125,
#  'interest': 290,
#  'liability': 45,
#  'manager': 79,
#  'methodology': 179,
#  'modern': 279,
#  'multiple': 77,
#  'option': 75,
#  'pertain': 54,
#  'real': 231,
#  'significant': 78,
#  'valuation': 38,
#  'value-in-use': 2,
#  'commission': 3,
#  'committee': 16,
#  'coso': 2,
#  'economics': 159,
#  'finance': 132,
#  'governance': 88,
#  'law': 437,
#  'multidisciplinary': 39,
#  'organization': 165,
#  'sponsoring': 2,
#  'term': 148,
#  'treadway': 2,
#  'capstone': 42,
#  'capture': 17,
#  'case': 436,
#  'chance': 32,
#  'extent': 34,
#  'face': 112,
#  'mirror': 6,
#  'multi-disciplinary': 34,
#  'neighbouring': 2,
#  'problem': 629,
#  'programme': 189,
#  'qualifying': 3,
#  'region': 107,
#  'technical': 119,
#  'agreement': 75,
#  'arbitrage': 9,
#  'boundary': 35,
#  'capital': 101,
#  'choice': 116,
#  'deal': 217,
#  'discus': 11,
#  'double': 13,
#  'etc': 75,
#  'foundation': 263,
#  'incentive': 12,
#  'individual': 231,
#  'local': 97,
#  'operating': 31,
#  'opportunity': 316,
#  'part': 291,
#  'repatriation': 3,
#  'structure': 409,
#  'vehicle': 25,
#  'knowledge/techniques': 1,
#  'practical': 365,
#  'statutory': 18,
#  'variety': 171,
#  'acc': 6,
#  'admission': 10,
#  'bba': 7,
#  'choose': 33,
#  'eligible': 6,
#  'guidance': 47,
#  'honor': 7,
#  'independent': 179,
#  'instructor': 45,
#  'ism': 12,
#  'non-honors': 6,
#  'program': 158,
#  'project': 587,
#  'report-writing': 10,
#  'requisite': 12,
#  'research': 770,
#  'senior': 45,
#  'study': 1107,
#  'tackle': 37,
#  'well-defined': 10,
#  'arrangement': 22,
#  'associate': 61,
#  'combination': 37,
#  'disclosure': 4,
#  'group': 261,
#  'joint': 34,
#  'party': 44,
#  'subsidiary': 2,
#  'transaction': 63,
#  'academic': 150,
#  'architecture': 122,
#  'art': 99,
#  'artistic': 27,
#  'asia': 181,
#  'attention': 105,
#  'body': 88,
#  'comparative': 98,
#  'concern': 162,
#  'cross-cultural': 14,
#  'discipline': 178,
#  'distinctive': 18,
#  'europe': 24,
#  'history': 292,
#  'human': 319,
#  'i.e': 28,
#  'landscape': 76,
#  'main': 214,
#  'painting': 15,
#  'represent': 44,
#  'sculpture': 7,
#  'survey': 140,
#  'tradition': 63,
#  'trend': 83,
#  'vocabulary': 38,
#  'addition': 139,
#  'aesthetic': 44,
#  'chinese': 141,
#  'classical': 98,
#  'component': 173,
#  'conception': 18,
#  'culture': 277,
#  'gain': 236,
#  'historical': 211,
#  'introductory-level': 4,
#  'key': 335,
#  'linkage': 23,
#  'philosophical': 54,
#  'production': 146,
#  'thousand': 2,
#  'transformation': 84,
#  'underpin': 44,
#  'visual': 62,
#  'western': 56,
#  'year': 219,
#  'appreciate': 73,
#  'artist': 11,
#  'century': 125,
#  'chronological': 6,
#  'critic': 4,
#  'critically-analyse': 1,
#  'development': 748,
#  'diffusion': 29,
#  'encourage': 59,
#  'global': 281,
#  'historian': 11,
#  'interpret': 52,
#  'material': 327,
#  'modernism': 6,
#  'modernity': 14,
#  'multiplicity': 1,
#  'primary-source': 1,
#  'question': 234,
#  'relationship': 296,
#  'textual': 14,
#  'understood': 29,
#  '”': 65,
#  'approach': 496,
#  'art-production': 2,
#  'canon': 3,
#  'collecting': 1,
#  'collection': 58,
#  'collector': 1,
#  'contour': 4,
#  'contribution': 46,
#  'cosmopolitan': 4,
#  'day': 50,
#  'demonstrate': 107,
#  'display': 15,
#  'diverse': 82,
#  'draw': 155,
#  'institutional': 65,
#  'inter-disciplinary': 14,
#  'late': 80,
#  'medieval': 9,
#  'nationalism': 28,
#  'overall': 39,
#  'period': 114,
#  'practice': 601,
#  'present': 286,
#  'private': 77,
#  'range': 203,
#  'seek': 145,
#  'shape': 128,
#  'taste-making': 1,
#  'value-arbitration': 1,
#  'wide': 103,
#  'analyse': 219,
#  'asian': 163,
#  'compare': 52,
#  'consumption': 35,
#  'difference': 73,
#  'european': 46,
#  'evolution': 73,
#  'genre': 65,
#  'method': 539,
#  'origin': 48,
#  'sequence': 53,
#  'shift': 25,
#  'text': 161,
#  'time': 221,
#  'writing': 164,
#  'adequacy': 2,
#  'analytics': 70,
#  'anti-money': 2,
#  'assess': 114,
#  'auditing': 5,
#  'banking': 35,
#  'common': 183,
#  'compliance': 16,
#  'credit': 59,
#  'data': 389,
#  'design': 1188,
#  'effectiveness': 46,
#  'fraud': 8,
#  'internal': 26,
#  'lapse': 3,
#  'laundering/countering': 2,
#  'market': 263,
#  'modus': 3,
#  'operandi': 2,
#  'product': 204,
#  'regulation': 110,
#  'rule': 118,
#  'slant': 2,
#  'terrorist': 3,
#  'wealth': 21,
#  'build': 120,
#  'counterintuitive': 2,
#  'effective': 131,
#  'evidence': 80,
#  'evidence-based': 23,
#  'fundamental': 502,
#  'individualised': 2,
#  'lead': 153,
#  'learner': 11,
#  'learning': 205,
#  'motivation': 26,
#  'path': 27,
#  'pragmatic': 20,
#  'reveal': 22,
#  'science': 419,
#  'scientific': 130,
#  'short': 62,
#  'simple': 101,
#  'step': 35,
#  'core': 119,
#  'create': 117,
#  'economy': 127,
#  'essential': 181,
#  'govern': 64,
#  'hand': 44,
#  'many': 178,
#  'new': 344,
#  'proper': 15,
#  'reason': 58,
#  'state': 260,
#  'test': 102,
#  'theory': 707,
#  'bias': 11,
#  'cognitive': 48,
#  'illogical': 1,
#  'influence': 171,
#  'inherent': 14,
#  'life': 325,
#  'natural': 92,
#  'possess': 12,
#  'prudent': 1,
#  'realize': 4,
#  'regret': 1,
#  'think': 34,
#  'communication': 271,
#  'form': 352,
#  'generator': 10,
#  'graphic': 16,
#  'grounding': 20,
#  'language': 259,
#  'medium': 174,
#  'perception': 50,
#  'principle': 624,
#  'reading': 210,
#  'render': 9,
#  'representation': 81,
#  'space': 120,
#  'subject': 169,
#  'thinking': 149,
#  'three-dimensional': 1,
#  'architectural': 37,
#  'assemblage': 2,
#  'building': 152,
#  'construction': 125,
#  'effect': 154,
#  'force': 108,
#  'function': 258,
#  'interface': 51,
#  'relation': 256,
#  'servant': 2,
#  'structural': 78,
#  'type': 189,
#  'determine': 40,
#  'big': 35,
#  'climate': 51,
#  'enable': 250,
#  'hot': 5,
#  'humid': 3,
#  'public': 316,
#  'response': 108,
#  'site': 56,
#  'small': 69,
#  'small-scale': 6,
#  'spatial': 46,
#  'sustainability': 62,
#  'tropical': 21,
#  'argument': 39,
#  'category': 27,
#  'coincide': 2,
#  'colonial': 30,
#  'contextual': 9,
#  'cultural': 221,
#  'debate': 109,
#  'discuss': 389,
#  'early': 65,
#  'ii': 67,
#  'legacy': 20,
#  'post-independence': 5,
#  'pre-colonial': 2,
#  'pre-modern': 7,
#  'southeast': 79,
#  'unit': 34,
#  'accompany': 10,
#  'archaeological': 2,
#  'british': 9,
#  'calendar': 3,
#  'chiefly': 3,
#  'colony': 2,
#  'craft': 15,
#  'desire': 9,
#  'east-west': 3,
#  'exhibition': 8,
#  'express': 26,
#  'groom': 1,
#  'india': 36,
#  'institution': 164,
#  'interaction': 177,
#  'investigation': 54,
#  'malaya': 2,
#  'museum': 7,
#  'native': 11,
#  'photography': 8,
#  'resistance': 21,
#  'school': 46,
#  'self-rule': 1,
#  'taste': 4,
#  'technology': 398,
#  'unravelled': 1,
#  'active': 58,
#  'analyze': 99,
#  'critical': 365,
#  'highlight': 72,
#  'idea': 193,
#  'identity': 98,
#  'imbue': 3,
#  'immediate': 7,
#  'intellectual': 83,
#  'introduces': 32,
#  'like': 3,
#  'man-made': 2,
#  'meaning': 65,
#  'nature': 222,
#  'object': 31,
#  'real-life': 51,
#  'relevance': 96,
#  'replete': 2,
#  'set': 35,
#  'show': 41,
#  'social': 529,
#  'style': 66,
#  'subjectivity': 5,
#  'america': 7,
#  'close': 35,
#  'emergence': 35,
#  'movement': 72,
#  'north': 5,
#  'political': 282,
#  'reception': 8,
#  'tendency': 5,
#  'today': 94,
#  'wider': 18,
#  'world': 378,
#  'calligraphy': 3,
#  'composition': 64,
#  'connect': 18,
#  'construct': 113,
#  'end': 160,
#  'indian': 19,
#  'intention': 10,
#  'interpreting': 2,
#  'islamic': 15,
#  'italy': 2,
#  'look': 105,
#  'paint': 8,
#  'propose': 67,
#  'receive': 26,
#  'renaissance': 13,
#  'second': 188,
#  'section': 40,
#  'way': 251,
#  'conservator': 1,
#  'curator': 1,
#  'curatorial': 1,
#  'educator': 1,
#  'experience': 335,
#  'frame': 26,
#  'gallery': 3,
#  'hands-on': 127,
#  'national': 113,
#  'nu': 72,
#  'postcolonial': 11,
#  'programmer': 3,
#  'resource': 131,
#  'additive': 11,
#  'applicable': 50,
#  'aspect': 323,
#  'assignment': 182,
#  'automation': 20,
#  'climatic': 3,
#  'condition': 106,
#  'depth': 114,
#  'element': 130,
#  'emerge': 105,
#  'engineering': 487,
#  'environmental': 217,
#  'generate': 45,
#  'important': 337,
#  'integration': 100,
#  'lecture': 179,
#  'logic': 45,
#  'manufacture': 31,
#  'materiality': 2,
#  'modular': 9,
#  'possibility': 26,
#  'prefabrication': 1,
#  'printing': 8,
#  'seminar': 138,
#  'studio': 38,
#  'symbiosis': 1,
#  'typology': 20,
#  'whereby': 2,
#  'base': 279,
#  'computation': 35,
#  'computational': 78,
#  'daylight': 3,
#  'feedback': 28,
#  'grow': 32,
#  'performance': 319,
#  'radiation': 34,
#  'shadowcasting': 1,
#  'simulation': 89,
#  'solar': 18,
#  'teach': 178,
#  'awareness': 51,
#  'complexity': 60,
#  'consideration': 104,
#  'constraint': 35,
#  'demand': 63,
#  'holistic': 30,
#  'impose': 2,
#  'integrative': 13,
#  'realism': 12,
#  'urban': 141,
#  'ar1101': 1,
#  'drawing': 13,
#  'fitting': 10,
#  'furniture': 2,
#  'illustrate': 95,
#  'man': 10,
#  'measure': 87,
#  'people': 136,
#  'city': 80,
#  'develop': 155,
#  'eats': 1,
#  'first-time': 1,
#  'mark': 21,
#  'meet': 90,
#  'studio-based': 9,
#  'suburban': 3,
#  '‘': 45,
#  '’': 182,
#  'envelope': 6,
#  'inter-relationship': 8,
#  'interdependence': 4,
#  'passive': 13,
#  'strategy': 325,
#  'technique/technology': 1,
#  'appropriate': 147,
#  'consider': 113,
#  'fringe': 1,
#  'intent': 7,
#  'analytical': 155,
#  'comprehensive': 98,
#  'document': 44,
#  'foundational': 58,
#  'inquiry': 25,
#  'regard': 53,
#  'synthesise': 2,
#  'urbanism¿the': 1,
#  'adopt': 49,
#  'american': 12,
#  'antiquity': 7,
#  'connection': 38,
#  'counter-movements': 1,
#  'epochal': 1,
#  'exhaustive': 1,
#  'grasp': 24,
#  'innovation': 104,
#  'mean': 136,
#  'northern': 2,
#  'postmodern/contemporary': 1,
#  'rich': 33,
#  'specific': 280,
#  'thematic': 17,
#  'trajectory': 21,
#  'centric': 1,
#  'company/organization': 3,
#  'evaluation': 211,
#  'exposure': 56,
#  'internship': 66,
#  'learnt': 12,
#  'logbook': 3,
#  'minimum': 29,
#  'perform': 145,
#  'professional': 161,
#  'setting': 108,
#  'undergraduate': 109,
#  'week': 92,
#  'weekly': 18,
#  'accessible': 18,
#  'complete': 123,
#  'differentiate': 7,
#  'duration': 16,
#  'exceed': 6,
#  'full-time': 19,
#  'least': 65,
#  'open': 65,
#  'pathway': 20,
#  'plan': 134,
#  'stint': 1,
#  'vacation': 20,
#  'viable': 16,
#  'abstraction': 17,
#  'algorithmic': 23,
#  'data-structures': 1,
#  'datasets': 16,
#  'decomposition': 15,
#  'encapsulation': 3,
#  'exploration': 47,
#  'formulation': 89,
#  'geometric': 16,
#  'higher-level': 5,
#  'integrate': 113,
#  'involve': 188,
#  'manipulation': 22,
#  'modelling': 96,
#  'parametric': 12,
#  'programming': 128,
#  'recognise': 14,
#  'scale': 65,
#  'semantic': 5,
#  'solution': 198,
#  'vary': 54,
#  'industry': 229,
#  'buildings': 1,
#  'ecological': 37,
#  'energy': 160,
#  'sustainable': 92,
#  'water': 66,
#  'achieve': 35,
#  'acoustic': 16,
#  'address': 228,
#  'assemble': 9,
#  'detail': 134,
#  'electric': 25,
#  'exterior': 2,
#  'familiarity': 20,
#  'fire': 6,
#  'goal': 110,
#  'interior': 4,
#  'light': 47,
#  'manner': 47,
#  'mechanical': 71,
#  'performance-targets': 1,
#  'physic': 87,
#  'quantitative': 125,
#  'safety': 59,
#  'service': 197,
#  'symbiotic': 2,
#  'thermal': 37,
#  'well-being': 14,
#  'acquisition': 75,
#  'and/or': 98,
#  'brief': 33,
#  'competence': 27,
#  'generic': 15,
#  'give': 240,
#  'operational': 52,
#  'technological': 71,
#  'computing': 47,
#  'heritage': 23,
#  'thorough': 35,
#  'central': 81,
#  'defines': 1,
#  'second-time': 1,
#  'architectural/construction': 2,
#  'communicate': 65,
#  'eg': 5,
#  'equivalent': 27,
#  'iii': 43,
#  'iv': 28,
#  'pre-tender': 2,
#  'resolution': 52,
#  'scheme': 30,
#  'scope': 55,
#  'separate': 11,
#  'specification': 41,
#  'stage': 71,
#  'submission': 16,
#  'translating': 2,
#  'fourth': 7,
#  'month': 8,
#  'claim': 46,
#  'definition': 39,
#  'degree': 43,
#  'dissertation': 33,
#  'parameter': 41,
#  'premise': 9,
#  'presentation': 196,
#  'principal': 25,
#  'proceeds': 4,
#  'task': 52,
#  'undertake': 89,
#  'university': 49,
#  'advanced': 53,
#  'buildability': 3,
#  'compromise': 4,
#  'conduct': 205,
#  'example': 252,
#  'final': 118,
#  'intensive': 31,
#  'one-week': 2,
#  'phase': 62,
#  'right': 93,
#  's2': 1,
#  'select': 244,
#  'start': 76,
#  'successful': 65,
#  'total': 15,
#  'workshop': 27,
#  'ability': 110,
#  'carry': 35,
#  'evaluate': 107,
#  'faculty': 123,
#  'member': 102,
#  'supervision': 83,
#  'theory/history': 1,
#  'architect': 13,
#  'charrette': 1,
#  'collaboration': 30,
#  'commence': 8,
#  'consultant': 13,
#  'engineer': 100,
#  'interdisciplinary': 71,
#  'lecturer': 73,
#  'optimization': 60,
#  'overview': 157,
#  'prepare': 125,
#  'problem-solving': 17,
#  'proposal': 46,
#  'roundtable': 1,
#  'series': 102,
#  'fuel-based': 1,
#  'general': 219,
#  'intend': 66,
#  'interrelationship': 7,
#  'renewable': 10,
#  'single-house': 1,
#  'source': 115,
#  'community': 146,
#  'elderly': 9,
#  'healthcare': 51,
#  'housing': 27,
#  'occupancy': 4,
#  'participating': 2,
#  'place': 213,
#  'post': 16,
#  'universal': 20,
#  'branch': 15,
#  'contract': 99,
#  'copyright': 7,
#  'duty': 25,
#  'enter': 14,
#  'institute': 7,
#  'land': 34,
#  'responsibility': 80,
#  'sector': 69,
#  'tort': 17,
#  'agency': 45,
#  'b': 40,
#  'c.': 8,
#  'emergent': 11,
#  'challenge': 265,
#  'density': 17,
#  'diversity': 47,
#  'examination': 115,
#  'in-depth': 136,
#  'instrumental': 26,
#  'myriad': 6,
#  'physical': 149,
#  'place-making': 1,
#  'praxis': 3,
#  'tangible': 4,
#  'view': 79,
#  'vital': 15,
#  'align': 14,
#  'cluster': 19,
#  'curriculum': 49,
#  'drive': 57,
#  'first': 148,
#  'theme': 112,
#  'c': 35,
#  'critique': 58,
#  'delineate': 2,
#  'embody': 3,
#  'f': 11,
#  'g': 10,
#  'hypothesis': 51,
#  'intervention': 65,
#  'literature': 190,
#  'precedent': 9,
#  'preliminary': 18,
#  'selection': 121,
#  'support': 103,
#  'thesis': 47,
#  'cfd': 2,
#  'configuration': 13,
#  'digital': 105,
#  'employ': 57,
#  'impact': 245,
#  'interactive': 46,
#  'optimal': 28,
#  'revit': 1,
#  'simulate': 25,
#  'agenda': 6,
#  'assign': 35,
#  'assist': 23,
#  'formulate': 54,
#  'identify': 70,
#  'model': 477,
#  'spend': 10,
#  'supervisor': 95,
#  'aid': 38,
#  'arch': 1,
#  'basis': 144,
#  'conservation': 62,
#  'culmination': 4,
#  'experimentation': 16,
#  'infrastructure': 43,
#  'lab': 27,
#  'panel': 16,
#  'perceive': 14,
#  'positive': 22,
#  'predicate': 6,
#  'produce': 32,
#  'specialist': 6,
#  'specialization': 25,
#  'supervise': 42,
#  'tutor': 5,
#  'criticism': 28,
#  'ecourbanism': 3,
#  'age': 74,
#  'character': 30,
#  'conventional': 27,
#  'cope': 3,
#  'expose': 124,
#  ...}

# %%
topd = {}
for k,v in d.items():
    innerd = {}
    for word in v:
        innerd[word] = freq_d[word]
    words = list(dict(sorted(innerd.items(), key=lambda x:x[1])).keys())[:5]
    topd[k] = words

    
with open('topics.pickle', 'wb') as handle:
    pickle.dump(topd, handle)
    
topd
# Out:
# {'ACC1002': ['investing', 'creditor', 'lending', 'attain', 'investor'],
#  'ACC1002X': ['investing', 'creditor', 'lending', 'attain', 'investor'],
#  'ACC1006': ['streamline',
#   'hr/management',
#   'finance/accounting',
#   'accounting/business',
#   'advantage'],
#  'ACC1701': ['book-keeping', 'aware', 'viewpoint', 'reporting', 'investor'],
#  'ACC1701X': ['book-keeping', 'aware', 'viewpoint', 'reporting', 'investor'],
#  'ACC2002': ['evolves',
#   'usefulness',
#   'organisational',
#   'accounting',
#   'managerial'],
#  'ACC2706': ['evolves',
#   'usefulness',
#   'organisational',
#   'accounting',
#   'managerial'],
#  'ACC2707': ['post-balance-sheet',
#   'intangible',
#   'impairment',
#   'interim',
#   'revenue'],
#  'ACC2708': ['share-based', 'lease', 'compensation', 'tax', 'employee'],
#  'ACC2709': ['streamline',
#   'hr/management',
#   'finance/accounting',
#   'accounting/business',
#   'advantage'],
#  'ACC3603': ['attestation', 'assurance', 'profession', 'audit', 'attitude'],
#  'ACC3601': ['consolidated', 'leasing', 'off-balance', 'earnings', 'sheet'],
#  'ACC3604': ['liquidation', 'life-span', 'takeover', 'amp', 'legislation'],
#  'ACC3605': ['consult', 'portion', 'profit', 'payment', 'tax'],
#  'ACC3606': ['acc1002', 'acc3601', 'preparer', 'cpa', 'fair'],
#  'ACC3614': ['value-in-use', 'earnings', 'accountant', 'discount', 'fair'],
#  'ACC3616': ['treadway', 'sponsoring', 'coso', 'commission', 'committee'],
#  'ACC3619': ['neighbouring', 'qualifying', 'accountant', 'mirror', 'capture'],
#  'ACC3701': ['attestation', 'assurance', 'profession', 'audit', 'attitude'],
#  'ACC3703': ['consult', 'portion', 'profit', 'payment', 'tax'],
#  'ACC4611': ['repatriation', 'arbitrage', 'discus', 'incentive', 'double'],
#  'ACC3702': ['liquidation', 'life-span', 'takeover', 'legislation', 'entire'],
#  'ACC4615': ['knowledge/techniques',
#   'attestation',
#   'assurance',
#   'audit',
#   'statutory'],
#  'ACC4619': ['non-honors', 'eligible', 'acc', 'bba', 'honor'],
#  'ACC3704': ['subsidiary',
#   'disclosure',
#   'currency',
#   'translation',
#   'arrangement'],
#  'AH2101': ['sculpture',
#   'cross-cultural',
#   'painting',
#   'distinctive',
#   'europe'],
#  'ACC3705': ['value-in-use', 'earnings', 'accountant', 'discount', 'fair'],
#  'AH2201': ['thousand',
#   'introductory-level',
#   'painting',
#   'conception',
#   'linkage'],
#  'ACC3706': ['treadway', 'sponsoring', 'coso', 'commission', 'committee'],
#  'AH2202': ['critically-analyse',
#   'primary-source',
#   'multiplicity',
#   'critic',
#   'chronological'],
#  'ACC3707': ['neighbouring', 'qualifying', 'accountant', 'mirror', 'capture'],
#  'AH3203': ['collecting',
#   'value-arbitration',
#   'taste-making',
#   'collector',
#   'art-production'],
#  'AH3204': ['art-production', 'shift', 'consumption', 'european', 'origin'],
#  'ACC4614': ['laundering/countering',
#   'operandi',
#   'adequacy',
#   'slant',
#   'anti-money'],
#  'ALS1010': ['individualised',
#   'counterintuitive',
#   'learner',
#   'pragmatic',
#   'reveal'],
#  'ACC4616': ['proper', 'rationale', 'accounting', 'underpin', 'hand'],
#  'ALS1010CP': ['individualised',
#   'counterintuitive',
#   'learner',
#   'pragmatic',
#   'reveal'],
#  'ALS1020': ['regret', 'prudent', 'illogical', 'realize', 'bias'],
#  'ACC4711': ['repatriation', 'arbitrage', 'discus', 'incentive', 'double'],
#  'AR1101': ['three-dimensional',
#   'render',
#   'generator',
#   'requisite',
#   'graphic'],
#  'ACC4713': ['laundering/countering',
#   'operandi',
#   'adequacy',
#   'slant',
#   'anti-money'],
#  'AR1327': ['assemblage',
#   'servant',
#   'architectural',
#   'interface',
#   'structural'],
#  'ACC5001': ['statement',
#   'determine',
#   'managerial',
#   'investment',
#   'financial'],
#  'AR2101': ['humid', 'hot', 'small-scale', 'generator', 'tropical'],
#  'AR2221': ['coincide',
#   'pre-colonial',
#   'post-independence',
#   'pre-modern',
#   'contextual'],
#  'AH2203': ['unravelled', 'self-rule', 'groom', 'archaeological', 'colony'],
#  'AR2224': ['man-made', 'replete', 'imbue', 'like', 'subjectivity'],
#  'AH3201': ['north', 'tendency', 'america', 'reception', 'exhibition'],
#  'AR2225': ['italy', 'interpreting', 'chiefly', 'calligraphy', 'sculpture'],
#  'AH3202': ['educator', 'curator', 'curatorial', 'conservator', 'programmer'],
#  'AR2327': ['symbiosis',
#   'prefabrication',
#   'materiality',
#   'whereby',
#   'climatic'],
#  'AR2522': ['shadowcasting', 'daylight', 'solar', 'feedback', 'grow'],
#  'AR3101': ['impose', 'realism', 'integrative', 'statutory', 'holistic'],
#  'AR1102': ['ar1101', 'furniture', 'fitting', 'generator', 'man'],
#  'AR3101A': ['first-time', 'eats', 'suburban', 'studio-based', 'mark'],
#  'AR1328': ['technique/technology',
#   'interdependence',
#   'envelope',
#   'inter-relationship',
#   'passive'],
#  'AR2102': ['fringe', 'small-scale', 'intent', 'integrative', 'architectural'],
#  'AR3223': ['urbanism¿the', 'synthesise', 'inquiry', 'holistic', 'document'],
#  'AR2222': ['exhaustive',
#   'epochal',
#   'counter-movements',
#   'postmodern/contemporary',
#   'northern'],
#  'AR3411': ['centric', 'company/organization', 'logbook', 'learnt', 'weekly'],
#  'AR3412': ['stint', 'exceed', 'differentiate', 'duration', 'viable'],
#  'AR2524': ['data-structures',
#   'encapsulation',
#   'higher-level',
#   'semantic',
#   'parametric'],
#  'AR3421': ['architectural',
#   'operate',
#   'construction',
#   'building',
#   'professional'],
#  'AR2723': ['buildings', 'ecological', 'generate', 'water', 'etc'],
#  'AR3721': ['performance-targets',
#   'exterior',
#   'symbiotic',
#   'interior',
#   'fire'],
#  'AR3102': ['generic', 'competence', 'brief', 'operational', 'site'],
#  'AR4001': ['heritage', 'thorough', 'computing', 'architecture', 'urban'],
#  'AR3102A': ['defines',
#   'second-time',
#   'studio-based',
#   'mark',
#   'architectural'],
#  'AR4103': ['translating',
#   'pre-tender',
#   'architectural/construction',
#   'eg',
#   'intention'],
#  'AR4421': ['company/organization', 'logbook', 'fourth', 'month', 'learnt'],
#  'AR5011': ['proceeds', 'premise', 'principal', 'brief', 'dissertation'],
#  'AR5121': ['s2', 'one-week', 'buildability', 'compromise', 'aware'],
#  'AR4002': ['theory/history', 'heritage', 'carry', 'computing', 'supervision'],
#  'AR5321': ['charrette', 'roundtable', 'commence', 'consultant', 'architect'],
#  'AR5322': ['fuel-based',
#   'single-house',
#   'interrelationship',
#   'renewable',
#   'shift'],
#  'AR4955': ['participating', 'occupancy', 'elderly', 'post', 'universal'],
#  'AR5422': ['institute', 'copyright', 'architect', 'enter', 'branch'],
#  'AR5423': ['c.', 'emergent', 'architect', 'trajectory', 'duty'],
#  'AR5601': ['place-making', 'praxis', 'intangible', 'tangible', 'myriad'],
#  'AR5801': ['align', 'cluster', 'studio', 'curriculum', 'investigation'],
#  'AR5802': ['align', 'cluster', 'studio', 'curriculum', 'investigation'],
#  'AR5803': ['translating',
#   'pre-tender',
#   'architectural/construction',
#   'eg',
#   'intention'],
#  'AR5806': ['delineate', 'embody', 'precedent', 'g', 'f'],
#  'AR5804': ['revit', 'cfd', 'configuration', 'simulate', 'optimal'],
#  'AR5807': ['agenda', 'spend', 'drawing', 'submission', 'assist'],
#  'AR5808': ['arch', 'culmination', 'tutor', 'specialist', 'agenda'],
#  'AR5951': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5952A': ['ecourbanism', 'tropical', 'thorough', 'sustainable', 'urban'],
#  'AR5951A': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5952B': ['ecourbanism', 'tropical', 'thorough', 'sustainable', 'urban'],
#  'AR5951B': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5952E': ['transdisciplinary',
#   'informality',
#   'inter-',
#   'cope',
#   'regeneration'],
#  'AR5951C': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5954A': ['megacities', 'informal', 'visualisation', 'landscape', 'city'],
#  'AR5951L': ['occupancy', 'post', 'frame', 'holistic', 'manner'],
#  'AR5954B': ['architecturein',
#   'megacities',
#   'informal',
#   'visualisation',
#   'thorough'],
#  'AR5953A': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'AR5955': ['participating', 'parent', 'occupancy', 'elderly', 'post'],
#  'AR5953B': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'AR5956A': ['universal', 'thorough', 'ecology', 'landscape', 'sustainable'],
#  'AR5953D': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'AR5956B': ['universal', 'thorough', 'ecology', 'landscape', 'sustainable'],
#  'AR5954': ['megacities', 'informal', 'visualisation', 'landscape', 'city'],
#  'AR5956C': ['universal', 'thorough', 'ecology', 'landscape', 'sustainable'],
#  'AR5956D': ['universal', 'thorough', 'ecology', 'landscape', 'sustainable'],
#  'AR5956E': ['universal', 'thorough', 'ecology', 'landscape', 'sustainable'],
#  'AR5954C': ['megacities', 'informal', 'visualisation', 'landscape', 'city'],
#  'AR5957A': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5955B': ['equator',
#   'architectonics',
#   'inhabitation',
#   'contingent',
#   'climatic'],
#  'AR5957B': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5957C': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5957D': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5957E': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5957F': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5958A': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AR5956F': ['universal', 'thorough', 'ecology', 'landscape', 'sustainable'],
#  'AR5958B': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AR5958C': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AR5957G': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5959A': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'AR5957H': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5959B': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'AR5957I': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5959C': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'AR5957J': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5959D': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'AR5957K': ['criticism', 'architecture', 'involve', 'specific', 'history'],
#  'AR5959E': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'AUD5114': ['electrophysiological', 'nuh', 'auditory', 'clinic', 'associate'],
#  'AR5958D': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AUD5216': ['rehabilitative',
#   'vestibular',
#   'migraine',
#   'neuro-otological',
#   'disorder'],
#  'AR5958E': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AUD5217': ['suit', 'hear', 'aid', 'user', 'psychological'],
#  'AR5958F': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AUD5218': ['audiological',
#   'audiology',
#   'hearing',
#   'professionalism',
#   'shock'],
#  'AR5958G': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AUD5219': ['neonate', 'audiological', 'audiology', 'infant', 'refine'],
#  'AR5958H': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AUD5220': ['aud5115', 'clearance', 'pilot', 'max', 'client'],
#  'AR5958I': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'AY1130': ['anantomy',
#   'integumentary',
#   'haematology',
#   'musculoskeletal',
#   'endocrine'],
#  'AR5958J': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'BAA6002': ['post-earnings-announcement',
#   'erc',
#   'non-directional',
#   'insider',
#   'drift'],
#  'AR5958K': ['sustainable', 'urban', 'methodology', 'involve', 'planning'],
#  'BBP5000': ['initiation',
#   'characterize',
#   'collaborative',
#   'distinctive',
#   'networking'],
#  'AR5959F': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'BDC5101': ['thread',
#   'deterministic',
#   'telecommunication',
#   'integer',
#   'interesting'],
#  'AR5959G': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'BDC6111': ['conic', 'convex', 'robust', 'phd', 'stochastic'],
#  'AR5959H': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'BDC6112': ['nonhomogeneous',
#   'memorylessness',
#   'superposition',
#   'martingale',
#   'stationary'],
#  'AR5959I': ['fabric', 'typology', 'validation', 'thorough', 'evolve'],
#  'BDC6302': ['polyhedral', 'tentative', 'cutting-plane', 'assortment', '•'],
#  'BHD4001': ['generalisation', 'prose', 'deduction', 'predictive', 'clear'],
#  'ASP1201CH': ['h3', 'embark', 'exceptional', 'junior', 'college'],
#  'BI3001A': ['minimum', 'set', 'hour', 'last', 'week'],
#  'ASP1201EC': ['h3', 'embark', 'exceptional', 'junior', 'college'],
#  'BI3001B': ['minimum', 'set', 'hour', 'last', 'week'],
#  'ASP1201EN': ['h3', 'embark', 'exceptional', 'junior', 'college'],
#  'BI3001C': ['minimum', 'set', 'hour', 'last', 'week'],
#  'ASP1201GE': ['h3', 'embark', 'exceptional', 'junior', 'college'],
#  'BI3002A': ['minimum', 'hour', 'last', 'internship', 'week'],
#  'ASP1201HY': ['h3', 'embark', 'exceptional', 'junior', 'college'],
#  'BI3002B': ['minimum', 'hour', 'last', 'internship', 'week'],
#  'ASP1201MS': ['h3', 'embark', 'exceptional', 'junior', 'malay'],
#  'BI3003': ['bi3001', 'bi3003', 'bi3002', '10-12', 'duration'],
#  'AUD5221': ['non-prescriptive',
#   'tinnitus',
#   'prescriptive',
#   'amplification',
#   'hearing'],
#  'BI3003A': ['bi3001', 'bi3003', 'bi3002', '10-12', 'duration'],
#  'AUD5222': ['audiological',
#   'audiology',
#   'hearing',
#   'professionalism',
#   'shock'],
#  'BI3003B': ['bi3001', 'bi3003', 'bi3002', '10-12', 'duration'],
#  'AUD5223': ['aud5219', 'neonate', 'audiological', 'audiology', 'infant'],
#  'BI3003C': ['bi3001', 'bi3003', 'bi3002', '10-12', 'duration'],
#  'AUD5224': ['apa', 'peer', 'modification', 'draft', 'feedback'],
#  'BI3003D': ['bi3001', 'bi3003', 'bi3002', '10-12', 'duration'],
#  'BIS3001': ['mentorship', 'invaluable', 'indepth', 'close', 'instructor'],
#  'BBP6794': ['past',
#   'entrepreneurship',
#   'contribution',
#   'organizational',
#   'sociology'],
#  'BIS3001A': ['mentorship', 'invaluable', 'indepth', 'close', 'instructor'],
#  'BL5102': ['non-living',
#   'biogeochemical',
#   'ecosystems',
#   'integrity',
#   'suitability'],
#  'BDC6304': ['robust',
#   'optimization',
#   'necessary',
#   'foundation',
#   'theoretical'],
#  'BL5198': ['conducive', 'fellow', 'picture', 'aware', 'grade'],
#  'BL5201': ['structure-function',
#   'presentations/discussion',
#   'protein-protein',
#   'folding',
#   'proteomics'],
#  'BL5207A': ['endoderm',
#   'angiogenesis',
#   'embryonic',
#   'vascular',
#   'transduction'],
#  'BL5209': ['barcoding', 'qc', 'transcriptomics', 'trouble', 'amplicons'],
#  'BL5217': ['genome-wide', 'introgression', 'snp', 'lineage', 'admixture'],
#  'BL5222': ['microtubular',
#   'cytoskeleton',
#   'pioneer',
#   'polarization',
#   'fresh'],
#  'BL5223': ['elegans', 'prion', 'folding', 'energetics', 'drosophila'],
#  'BL5229': ['biophysical', 'fourier', 'microscopy', 'optic', 'quantum'],
#  'BL5232': ['bioimaging', 'excellent', 'electron', 'temporal', 'resonance'],
#  'BL5232B': ['microscope', 'nowadays', 'bioimaging', 'excellent', 'temporal'],
#  'BL5232C': ['microscope', 'nowadays', 'bioimaging', 'excellent', 'temporal'],
#  'BL5236': ['nm', 'bioimaging', 'virus', 'electron', 'interesting'],
#  'BL5237': ['sequence-structure-function',
#   'allostery',
#   'presentations/discussion',
#   'evolutionary',
#   'protein'],
#  'BL5202A': ['excitable', 'macromolecule', 'convey', 'ion', 'membrane'],
#  'BLD3002': ['synergizing', 'unite', 'synchronise', 'ceo', 'strive'],
#  'BL5203': ['extracellular',
#   'defense',
#   'protein-ligand',
#   'intracellular',
#   'stimulus'],
#  'BLD3003': ['follower', '•', 'trait', 'developing', 'delve'],
#  'BL5204': ['biocomputing',
#   'interfacing',
#   'flexibility',
#   'delve',
#   'biotechnology'],
#  'BLD3004': ['accord', 'matter', 'leadership', 'supervisor', 'need'],
#  'BL5210': ['biogeography',
#   'dating',
#   'occurrence',
#   'specimen',
#   'biogeographic'],
#  'BMA5001': ['principal-agent',
#   'modernist',
#   'asymmetric',
#   'owner',
#   'functioning'],
#  'BMA5002': ['add-in', 'variability', 'dedicate', 'margin', 'scm'],
#  'BL5216': ['genomics-based',
#   'sense.upon',
#   'function.the',
#   'characterizing',
#   'genomic'],
#  'BMA5003': ['non-accounting',
#   'procedural',
#   'statement',
#   'accounting',
#   'managerial'],
#  'BL5218': ['student-directed',
#   'presenting',
#   'tailor',
#   'inquiry',
#   'behavioural'],
#  'BL5220': ['invertebrate',
#   'pioneer',
#   'vertebrate',
#   'differentiation',
#   'well'],
#  'BMA5008': ['maximize', 'budgeting', 'valuation', 'liability', 'financing'],
#  'BL5221': ['gametogenesis', 'dormancy', 'apomixis', 'quorum', 'dimorphism'],
#  'BMA5009': ['buyer', 'implementing', 'targeting', 'deploy', 'creativity'],
#  'BL5224': ['confocal', 'cryo', 'tomography', 'drawback', 'electron'],
#  'BMA5011': ['macro-economy', 'macro-', 'fluctuation', 'short-term', 'track'],
#  'BL5228': ['characterizing', 'weakness', 'organism', 'molecule', 'strength'],
#  'BMA5013': ['organisationa', 'entitya', 'planta', 'managera', 'top'],
#  'BL5233': ['mixed-effects',
#   'publishable',
#   'additive',
#   'inherent',
#   'datasets'],
#  'BL5234': ['theoretician', 'high-impact', 'predator-prey', 'forest', 'yield'],
#  'BMA5017': ['subsidiary',
#   'products/services',
#   'indirect',
#   'refers',
#   'ultimate'],
#  'BL5235': ['simplest', 'formalism', 'stake', 'coherence', 'microscope'],
#  'BMA5108': ['know-how', 'invention', 'exit', 'revenue', 'entrepreneurial'],
#  'BLD3001': ['want', 'contextual', 'labor', 'in-class', 'interactive'],
#  'BMA5122': ['cyclical',
#   'pre-requisite',
#   'adjustment',
#   'shock',
#   'cross-border'],
#  'BMA5126': ['detailed', 'turn', 'advantage', 'big', 'capability'],
#  'BMA5236': ['geopolitical', 'entry', 'aspire', 'division', 'operating'],
#  'BMA5314': ['stategies', 'founder', 'starting-up', 'banker', 'provider'],
#  'BMA5323': ['sell-side', 'buy-side', 'model-based', 'discount', 'frequent'],
#  'BMA5005': ['include—job',
#   'break-even',
#   'costing',
#   'decisionmaking',
#   'variance'],
#  'BMA5324': ['standpoint', 'invest', 'equity', '“', '”'],
#  'BMA5404': ['gut',
#   'conjecture',
#   'innovativeness',
#   'long-established',
#   'utilizes'],
#  'BMA5016': ['selfawareness', 'opening', 'journey', 'answer', 'invite'],
#  'BMA5530': ['human-centric',
#   'desirability',
#   'viability',
#   'feasibility',
#   'user'],
#  'BMA5104': ['globlize',
#   'multidimensional',
#   'worldwide',
#   'sensitivity',
#   'operating'],
#  'BMA5801': ['workplace', 'c', 'speaking', 'b', 'demonstrate'],
#  'BMA5104A': ['worldwide', 'sensitivity', 'intend', 'manager', 'today'],
#  'BMA5802': ['extemporaneous',
#   'situational',
#   'enrolment',
#   'persuasion',
#   'augment'],
#  'BMA5112': ['coursefocuses',
#   'endowment',
#   'environments—a',
#   'keep',
#   'contextual'],
#  'BMA5902': ['mba', 'rid', 'commercialise', 'launchpad', 'competitor'],
#  'BMA5127': ['dozen', 'roleplay', 'consulting', 'driver', 'consult'],
#  'BMA5903': ['minimum', 'hour', 'last', 'internship', 'week'],
#  'BMA5128': ['surge', 'startup', 'founding', 'allocate', 'raising'],
#  'BMC5001A': ['delegate',
#   'east-west',
#   'responsiveness',
#   'supportive',
#   'empowerment'],
#  'BMA5129': ['prosper', 'survive', 'mature', 'email', 'phone'],
#  'BMC5001B': ['east-west',
#   'coordination',
#   'functioning',
#   'imperative',
#   'sociological'],
#  'BMA5271': ['edge', 'worldwide', 'cross', 'corporation', 'competitive'],
#  'BMC5003A': ['problemformulation', 'overcome', 'bias', 'executive', 'senior'],
#  'BMC5004A': ['imperfect',
#   'competitiveness',
#   'indicator',
#   'externality',
#   'functioning'],
#  'BMA5313': ['grace', 'verifiable', 'unvalidated', 'prescibes', 'testable'],
#  'BMC5006A': ['buyer',
#   'implementing',
#   'segmentation',
#   'executive',
#   'constitute'],
#  'BMC5006B': ['bmc5006a', 'induce', 'behavioral', 'external', 'exposure'],
#  'BMA5313C': ['restructuring',
#   'merger',
#   'organizational',
#   'acquisition',
#   'strategic'],
#  'BMC5007A': ['executive',
#   'budgeting',
#   'valuation',
#   'accounting',
#   'liability'],
#  'BMA5313E': ['venturing', 'post-investment', 'screening', 'raising', 'exit'],
#  'BMC5007B': ['maximize', 'possess', 'executive', 'financing', 'operate'],
#  'BMA5332': ['2008-9', 'fundraising', 'pillar', 'fintech', 'regulate'],
#  'BMC5008A': ['hrm',
#   'crosscultural',
#   'specialized',
#   'retention',
#   'bargaining'],
#  'BMA5411': ['derail', 'leveraging', 'unlock', 'branding', 'succession'],
#  'BMC5008B': ['reorienting',
#   'hr',
#   'restructuring',
#   'diversification',
#   'labor'],
#  'BMA5511': ['retailer', 'trucker', 'marry', 'suppose', 'convince'],
#  'BMC5009A': ['manpower',
#   'interrelationship',
#   'challenging',
#   'output',
#   'input'],
#  'BMA5511A': ['malleable', 'meant', 'marry', 'existence', 'reliable'],
#  'BMC5010A': ['diagnose', 'similarity', 'merger', 'remedy', 'list'],
#  'BMC5010B': ['policy-makers',
#   'disclosure',
#   'auditing',
#   'mechanisms',
#   'transparency'],
#  'BMA5524A': ['day-to-day', 'prevalent', 'marketing', 'professional', 'many'],
#  'BMC5011A': ['business-government',
#   'heading',
#   'managing',
#   'korean',
#   'multinational'],
#  'BMC5011B': ['business-government',
#   'heading',
#   'managing',
#   'korean',
#   'multinational'],
#  'BME5001': ['employeea',
#   'co-ordination',
#   'delegate',
#   'responsiveness',
#   'supportive'],
#  'BME5002': ['reconcile',
#   'mission',
#   'diversification',
#   'generic',
#   'viewpoint'],
#  'BME5003': ['problem-formulation',
#   'familiarization',
#   'requester',
#   'arrive',
#   'analyst'],
#  'BME5004': ['imperfect', 'marginal', 'microeconomic', 'block', 'accounting'],
#  'BME5006': ['buyer',
#   'implementing',
#   'segmentation',
#   'executive',
#   'constitute'],
#  'BMC5002A': ['mission',
#   'diversification',
#   'generic',
#   'concentrate',
#   'division'],
#  'BME5007': ['maximize', 'possess', 'executive', 'budgeting', 'valuation'],
#  'BMC5002B': ['reconcile', 'viewpoint', 'west', 'evolution', 'difference'],
#  'BME5008': ['reorienting', 'hrm', 'hr', 'restructuring', 'specialise'],
#  'BMC5003B': ['number-crunching',
#   'requester',
#   'arrive',
#   'familiarize',
#   'executive'],
#  'BME5009': ['pooling',
#   'excellence',
#   'vendor',
#   'warehousing',
#   'research-based'],
#  'BMC5004B': ['world-order',
#   'north-south',
#   'diplomat',
#   'politician',
#   'diplomacy'],
#  'BME5010': ['business/industry',
#   'intrapreneurial',
#   'low-cost',
#   'classmate',
#   'mindset'],
#  'BMC5005A': ['sociopolitical',
#   'sensitize',
#   'multinational',
#   'cross-border',
#   'array'],
#  'BME5011': ['business-government',
#   'heading',
#   'managing',
#   'korean',
#   'multinational'],
#  'BMC5005B': ['insider', 'enforceable', 'discharge', 'passing', 'default'],
#  'BME5012': ['value-creation',
#   'organisation-government',
#   'inter-firm',
#   'heading',
#   'alliance'],
#  'BME5014': ['expedient', 'cost-effective', 'forum', 'topical', 'resolve'],
#  'BME5015': ['long-run', 'short-', 'stabilization', 'imbalance', 'adjustment'],
#  'BMC5012': ['concluding', 'apex', 'emba', 'note', 'benefit'],
#  'BME5018': ['sustainability',
#   'firm',
#   'consideration',
#   'national',
#   'corporate'],
#  'BME5019': ['discount', 'shareholder', 'cash', 'stock', 'return'],
#  'BME5020': ['dominance', 'psychic', 'forbes', 'commensurate', 'strewn'],
#  'BME5021': ['cg', 'paraphrase', '–with', 'oecd', 'academia'],
#  'BMF5331': ['officer', 'loan', 'chief', 'constituent', 'offering'],
#  'BME5022': ['creativity', 'execution', 'competitive', 'leadership', 'today'],
#  'BMF5332': ['etrs', 'mutual', 'hedge', 'allocation', 'income'],
#  'BME5033': ['routine', 'selfawareness', 'habit', 'react', 'self-awareness'],
#  'BMF5333': ['fixed', 'hedging', 'bond', 'derivative', 'income'],
#  'BMF5001': ['ceo', 'succession', 'constrain', 'preference', 'affair'],
#  'BMF5334': ['exchange-rate',
#   'helpful',
#   'currency',
#   'budgeting',
#   'determination'],
#  'BMF5321': ['interpolation',
#   'excel',
#   'optimization',
#   'mathematics',
#   'statistic'],
#  'BMK6102': ['genesis', 'bmk6101', 'deliverable', 'forecast', 'advertising'],
#  'BMF5322': ['payout', 'discount', 'cash', 'stock', 'budgeting'],
#  'BMF5323': ['knowledgeable', 'investor', 'statement', 'accounting', 'user'],
#  'BMK6111O': ['doctoral', 'professor', 'stream', 'priority', 'representative'],
#  'BMK5003': ['persistent',
#   'depart',
#   'deviation',
#   'maximization',
#   'self-interest'],
#  'BMK6111P': ['doctoral', 'professor', 'stream', 'priority', 'representative'],
#  'BMK5004': ['raise', 'intensive', 'c', 'b', 'significance'],
#  'BMK6111Q': ['doctoral', 'professor', 'stream', 'priority', 'representative'],
#  'BMK5006': ['cct',
#   'mass-mediated',
#   'patterning',
#   'sociohistorical',
#   'synthesize'],
#  'BMM5003': ['olices', 'cyclical', 'accumulation', 'fiscal', 'interplay'],
#  'BMO5003': ['mgt', '3-year', 'mim', 'cems', 'flagship'],
#  'BMO6015A': ['ineffective', 'non-for-profit', 'profit', 'get', '–'],
#  'BMM5001': ['esponsiveness',
#   'supportive',
#   'empowerment',
#   'chief',
#   'coordination'],
#  'BMO6019': ['organizationa', 'gt', 'artifact', 'picture', 'motion'],
#  'BMM5002': ['ramework',
#   'rbanization',
#   'imperfect',
#   'industrialization',
#   'scarce'],
#  'BMP5001': ['vc', 'capitalism', 'entrepreneur', 'raise', 'fund'],
#  'BMM5101': ['trap', 'insightful', 'avoid', 'deviate', 'cross-disciplinary'],
#  'BMP5002': ['business/economic',
#   'arrange',
#   'macroeconomic',
#   'guest',
#   'speaker'],
#  'BMM5105': ['bubble', 'soe', 'ups', 'transitional', 'state-owned'],
#  'BMS5108': ['hedging', 'speculation', 'imbalance', 'shock', 'macroeconomics'],
#  'BMO5004': ['organizational',
#   'behaviour',
#   'seminar',
#   'contemporary',
#   'field'],
#  'BMS5109': ['planningimplementation',
#   'bcg',
#   'perspective-oriented',
#   'utilizes',
#   'none'],
#  'BMO6016A': ['recruitment',
#   'appraisal',
#   'employment',
#   'training',
#   'selection'],
#  'BMS5111': ['expedient', 'avenue', 'applies', 'bind', 'cost-effective'],
#  'BMO6018': ['charismatic', 'fictional', 'prototyping', 'fiction', 'journal'],
#  'BMS5202': ['cost-effectively',
#   'configure',
#   'internationalization',
#   'emerging',
#   'aspire'],
#  'BMS5105': ['detailed', 'turn', 'advantage', 'big', 'capability'],
#  'BMS5203': ['phenomenom', 'contemplate', 'ai', 'merit', 'iot'],
#  'BMS5107': ['smes', 'labour/human', 'triple', 'bottom', 'consult'],
#  'BMS5304': ['post-investment',
#   'fundraising',
#   'korea',
#   'screening',
#   'raising'],
#  'BMS5110': ['economic/managerial',
#   'functioning',
#   'behavioral',
#   'motivate',
#   'microeconomic'],
#  'BMS5306': ['exchange-rate',
#   'helpful',
#   'currency',
#   'budgeting',
#   'determination'],
#  'BMS5204': ['world-class',
#   'understaning',
#   'fast-moving',
#   'contextual',
#   'craft'],
#  'BMS5309': ['boutique', 'ib', 'delve', 'touch', 'player'],
#  'BMS5205': ['data-rich', 'technicality', 'mindset', 'era', 'tackle'],
#  'BMS5403': ['cross-national', 'globe', 'amount', 'hence', 'expect'],
#  'BMS5307': ['asset', 'instrument', 'trade', 'characteristic', 'mechanism'],
#  'BMS5404': ['react', 'globe', 'desire', 'well-being', 'behavioural'],
#  'BMS5308': ['accumulation', 'aspire', 'enter', 'wealth', 'benefit'],
#  'BMS5405': ['convert', 'coach', 'transform', 'reaction', 'customer'],
#  'BMS5503': ['firm/product', 'stimulus', 'widespread', 'buyer', 'positioning'],
#  'BMS5504': ['well-informed',
#   'consulting',
#   'high-level',
#   'scholar',
#   'underlying'],
#  'BMS5505': ['nimble', 'savvy', 'forward-looking', 'marketer', 'disruption'],
#  'BMS5902': ['rid', 'commercialise', 'launchpad', 'competitor', 'lean'],
#  'BMS5506': ['business-relevant',
#   'action-learning-oriented',
#   'not-forprofit',
#   'decisionmaking',
#   'uncover'],
#  'BMU5004': ['long-run', 'short-', 'stabilization', 'imbalance', 'adjustment'],
#  'BMS5901': ['orient', 'input', 'side', 'partnership', 'reinforce'],
#  'BMU5006': ['alumnus', 'thought', 'influential', 'dialogue', 'executive'],
#  'BMU5007': ['cumulate', 'certainty', 'merger', 'return', 'optimal'],
#  'BMU5008': ['sub-module', 'dilemma', 'contrast', 'managerial', 'stakeholder'],
#  'BMU5017': ['2-part', 'anderson', 'practicum', 'supervise', 'classroom'],
#  'BMU5014': ['bmu5010', 'loyalty', 'lifetime', 'retain', 'heading'],
#  'BN1101': ['epp', 'fabricate', 'possess', 'predict', 'prototype'],
#  'BMU5015': ['sharpen', 'robust', 'judgment', 'aid', 'uncertainty'],
#  'BN2001': ['laboratory-based',
#   'prescription',
#   'self-motivated',
#   'learner',
#   'research-based'],
#  'BN2201': ['biotransport',
#   'biocontrol',
#   'bioenergy',
#   'bioengineering',
#   'contrast'],
#  'BN1102': ['optimize', 'epp', 'possess', 'expect', 'biomedical'],
#  'BN2202': ['macrocirculation',
#   'non-newtonian',
#   'microcirculation',
#   'hemorheology',
#   'dialysis'],
#  'BN2403': ['biopotentials',
#   'bioamplifiers',
#   'microcontroller',
#   'bioinstrumentation',
#   'amplify'],
#  'BN2102': ['anova', 'bioengineering', 'explanation', 'tutorial', 'typical'],
#  'BN3101': ['calibration',
#   'bioengineering',
#   'branch',
#   'documentation',
#   'prototype'],
#  'BN2204': ['bend', 'torsion', 'musculoskeletal', 'shear', 'moment'],
#  'BN3202': ['orthopaedics',
#   'biomechanics',
#   'musculoskeletal',
#   'sport',
#   'occupational'],
#  'BN2301': ['biomedicine',
#   'enzymatic',
#   'biomaterials',
#   'biomolecules',
#   'catalysis'],
#  'BN3402': ['bioassay',
#   'palsmon',
#   'biomodified',
#   'topological',
#   'biomaterials'],
#  'BN4101': ['research-based',
#   'consecutive',
#   'consist',
#   'supervision',
#   'member'],
#  'BN3301': ['ligament', 'teeth', 'vasculature', 'cartilage', 'skin'],
#  'BN4101R': ['research-based',
#   'consecutive',
#   'consist',
#   'supervision',
#   'member'],
#  'BN3501': ['calorimetry',
#   'multicomponent',
#   'fermentation',
#   'solubility',
#   'electrochemical'],
#  'BN4202': ['liver', 'intra-aortic', 'valve', 'pancreas', 'substitute'],
#  'BN4301': ['nurture', 'next', 'tissue', 'derive', 'central'],
#  'BN4406': ['biophotonics',
#   'nanobiotechnology',
#   'light-tissue',
#   'biospectroscopy',
#   'biophotonic'],
#  'BN4203': ['congenital',
#   'neuromuscular',
#   'osteopathy',
#   'amputation',
#   'anthropathy'],
#  'BN4501': ['combinatorial',
#   'modification',
#   'abstraction',
#   'societal',
#   'genetic'],
#  'BN4402': ['huxley',
#   'electrophysiology',
#   'hodgkin',
#   'biopotential',
#   'excitable'],
#  'BN5101': ['bmr', 'state-of-art', 'biomechanics', 'indepth', 'mobility'],
#  'BN4403': ['epithelium', 'organs', 'bioelectric', 'solute', 'solvent'],
#  'BN5104': ['intercellular', 'nerve', 'receptor', 'muscle', 'endocrine'],
#  'BN4404': ['micropatterning',
#   'microengineering',
#   'biochip',
#   'biomems',
#   'microfabrication'],
#  'BN5202': ['underestimate',
#   'heterogeneity',
#   'patient-specific',
#   'remodeling',
#   'viscoelasticity'],
#  'BN5102': ['electrophysiological',
#   'adequate',
#   'imaging',
#   'electronics',
#   'sensor'],
#  'BN5205': ['biocomputation',
#   'biomechanical',
#   'biocomputational',
#   'mechanosensory',
#   'biomechanics'],
#  'BN5201': ['orthopedic',
#   'shielding',
#   'polyurethane',
#   'bioadhesion',
#   'biodegradation'],
#  'BN5207': ['single-photon',
#   'positron',
#   'ultrasound',
#   'tomography',
#   'forming'],
#  'BN5203': ['mini-proposals',
#   'vitro',
#   'implantation',
#   'scaffold',
#   'cartilage'],
#  'BN5208': ['qms', 'sterility', 'professionalism', 'assurance', 'impart'],
#  'BN5209': ['digitization', 'map', 'brain', 'electric', 'matrix'],
#  'BN5501': ['reimbursement',
#   'biodesign',
#   'needs-based',
#   'singapore-stanford',
#   'veteran'],
#  'BN5511': ['asiapacific',
#   'subtopics',
#   'harmonization',
#   'submission',
#   'asean'],
#  'BN5513': ['harmonization',
#   'blend',
#   'asia-pacific',
#   'submission',
#   'translate'],
#  'BN5512': ['postmarketing', 'pmas', 'sub-topics', 'fda', 'mdd'],
#  'BN5666': ['attachment', 'company', 'experience', 'engineering', 'work'],
#  'BN6209': ['neurosurgical',
#   'neuroengineering',
#   'neurotechnology',
#   'telemetry',
#   'neurophysiology'],
#  'BN6202': ['clinicial',
#   'orthopaedics',
#   'biomechanics',
#   'rehabilitation',
#   'execute'],
#  'BN6401': ['fluorescence-based',
#   'traction',
#   'superresolution',
#   'transfer-based',
#   'fluorescence'],
#  'BPM1701': ['fresh', 'calculus', 'short', 'mathematics', 'statistic'],
#  'BPM1702': ['microsoft', 'accountancy', 'bba', 'spreadsheet', 'excel'],
#  'BPS5112': ['iaq', 'ventilation', 'retrofit', 'forefront', 'performing'],
#  'BPM1705': ['nut', 'bolt', 'funding', 'journey', 'conception'],
#  'BPS5222': ['iaq', 'acoustical', 'ieq', 'occupant', 'color'],
#  'BPS5225': ['upon', 'commences', 'designing', 'ranking', 'retrofit'],
#  'BPS5111': ['devolve', 'tbp', 'facade', 'commission', 'interior'],
#  'BPS5226': ['optimize', 'smart', 'hardware', 'facility', 'analytics'],
#  'BPS5227': ['façade', 'spearhead', 'basement', 'wet', 'planning/design'],
#  'BPS5221': ['microclimatic', 'vice-versa', 'tropic', 'humid', 'comfort'],
#  'BPS5228': ['masonry', 'superior', 'coating', 'wood', 'nanotechnology'],
#  'BPS5223': ['facade', 'ee', 'daylight', 'interrelation', 'ventilation'],
#  'BPS5300': ['6,000-word', 'state-of-the-art', 'submit', 'guidance', 'novel'],
#  'BPS5224': ['cooling/heating',
#   'cogeneration/tri-generation',
#   'ventilate',
#   'energyefficient',
#   'district'],
#  'BSE3701': ['deficit/surplus',
#   'unemployment',
#   'inflation',
#   'budget',
#   'macroeconomics'],
#  'BSE3702': ['positioning',
#   'microeconomic',
#   'sustain',
#   'boundary',
#   'capability'],
#  'BSE3703': ['econometric', 'square', 'carry', 'regression', 'estimation'],
#  'BSN3702': ['dominance', 'psychic', 'forbes', 'commensurate', 'blind'],
#  'BSN3701A': ['first-mover',
#   'socio-economic/competitive',
#   'life-cycles',
#   'organizational/management',
#   'driver'],
#  'BSP1004': ['misstatement', 'trader', 'negligence', 'recourse', 'amp'],
#  'BSN3701B': ['first-mover',
#   'socio-economic/competitive',
#   'life-cycles',
#   'organizational/management',
#   'driver'],
#  'BSP1004X': ['misstatement', 'trader', 'negligence', 'recourse', 'amp'],
#  'BSP1005': ['systematically.information',
#   'anti-trust',
#   'non-price',
#   'coming',
#   'monopoly'],
#  'BSP1702': ['misstatement', 'trader', 'negligence', 'recourse', 'valid'],
#  'BSP1702X': ['misstatement', 'trader', 'negligence', 'recourse', 'valid'],
#  'BSP1703': ['systematically.information',
#   'anti-trust',
#   'non-price',
#   'coming',
#   'monopoly'],
#  'BSP2001': ['macro-economics',
#   'micro-economics',
#   'unemployment',
#   'inflation',
#   'fiscal'],
#  'BSP2005': ['discretion', 'corruption', 'segment', 'macroeconomic', 'vary'],
#  'BSP2701': ['liberalization',
#   'policy-makers',
#   'inflation',
#   'literacy',
#   'fiscal'],
#  'BSP1707A': ['motivate',
#   'microeconomic',
#   'observation',
#   'exposure',
#   'real-world'],
#  'BSP3001': ['fast-paced', 'pressing', 'alliance', 'macro', 'diversification'],
#  'BSP1707B': ['motivate',
#   'microeconomic',
#   'observation',
#   'exposure',
#   'real-world'],
#  'BSP3513': ['demise', 'defy', 'imminent', 'wisdom', 'lose'],
#  'BSP4513': ['window-based', 'refresh', 'officer', 'capm', 'eviews'],
#  'BT1101': ['well-informed',
#   'non-profit',
#   'spreadsheet',
#   'analytic',
#   'interpret'],
#  'BT2101': ['carlo', 'monte', 'forecast', 'markov', 'prediction'],
#  'BSP3001A': ['value-rarity-imitatibility-organization',
#   'vrio',
#   'integrative',
#   'reward',
#   'workplace'],
#  'BT2102': ['warehouse', 'dashboard', 'proportion', 'relational', 'temporal'],
#  'BSP3001B': ['contributor',
#   'join',
#   'alliance',
#   'diversification',
#   'managing'],
#  'BT3101': ['business/technical',
#   'sharpen',
#   'monitor',
#   'privacy',
#   'consultation'],
#  'BSP3701X': ['fast-paced',
#   'pressing',
#   'alliance',
#   'macro',
#   'diversification'],
#  'BT3102': ['monte-carlo', 'prevalent', 'accessible', 'get', 'graph'],
#  'BSS4003A': ['smarter', 'run', 'microeconomics', 'publish', 'ongoing'],
#  'BT3103': ['tradeoff', 'applications', 'conversant', 'script', 'track'],
#  'BSS4003B': ['microeconomics',
#   'publish',
#   'econometric',
#   'datasets',
#   'ongoing'],
#  'BT4012': ['laundering', 'collusion', 'lapse', 'terror', 'intrusion'],
#  'BT4016': ['credit', 'sector', 'analytics', 'expose', 'teach'],
#  'BT4101': ['summarize',
#   'initiative',
#   'panel',
#   'determination',
#   'dissertation'],
#  'BT4212': ['un-paid', 'remove', 'keywords', 'indexing', 'persuade'],
#  'BT4221': ['instructure',
#   'cassandra',
#   'tolerable',
#   'dynamo',
#   'information-sensing'],
#  'BT4240': ['accurate', 'reliable', 'discover', 'predictive', 'artificial'],
#  'BT5110': ['systems.the', 'sql', 'relational', 'manipulation', 'logical'],
#  'BT4010': ['unsatisfactory', 'cs/cu', 'duration', 'monitor', 'full-time'],
#  'BT5152': ['msba', 'pre-processing', 'sensitive', 'well-known', 'vertical'],
#  'BT4013': ['placement', 'trading', 'optimal', 'execution', 'portfolio'],
#  'BZD6000': ['aversion',
#   'decisionmaking',
#   'intuition',
#   'center',
#   'microeconomic'],
#  'BT4014': ['a/b',
#   'randomize',
#   'crowdsourcing',
#   'personalize',
#   'collaborative'],
#  'BZD6003': ['observational', 'center', 'causal', 'block', 'identification'],
#  'BZD6008': ['dehumanization',
#   'ambivalence',
#   'prosocial',
#   'egoism-altruism',
#   'metacognition'],
#  'BT4211': ['roi', 'campaign', 'initiative', 'metric', 'leverage'],
#  'BZD6010': ['reasonable', 'behavioral', 'stream', 'inquiry', 'extensive'],
#  'BT4222': ['hypertext', 'hyperlink', 'twitter', 'log', 'clickstream'],
#  'CAS5101': ['come', 'root', 'indigenous', 'rest', 'autonomous'],
#  'BT5126': ['learning-by-doing',
#   'breadth',
#   'pipeline',
#   'econometric',
#   'causal'],
#  'CAS6770': ['ph.d.', 'forum', 'dissertation', 'active', 'share'],
#  'BT5153': ['know-how', 'ai', 'offering', 'advise', 'sufficient'],
#  'CDM5102': ['histopathology',
#   'familial',
#   'prognostic',
#   'biomarkers',
#   'tumor'],
#  'BX5101': ['fuller', 'future-oriented', 'assure', 'likely', 'suitability'],
#  'CDM5103': ['ribonucleoprotein', 'rna-binding', 'landmark', 'rna', 'club'],
#  'BZD6001': ['backward', 'incentive', 'asymmetric', 'induction', 'mixed'],
#  'CE1101': ['straightforward',
#   'withstand',
#   'tall',
#   'impressive',
#   'spectacular'],
#  'BZD6004': ['venter', 'observational', 'center', 'econometric', 'exist'],
#  'CE2112': ['geological',
#   'compressibility',
#   'mini-project',
#   'granular',
#   'cohesive'],
#  'BZD6009': ['self-regulation', 'construal', 'fairness', 'self', 'bias'],
#  'CE2134': ['frictional', 'wake', 'drag', 'laminar', 'hydrostatic'],
#  'CE2183': ['budget',
#   'schedule',
#   'deliver',
#   'specification',
#   'administration'],
#  'BZD6012': ['quasi-experimental',
#   'within-subject',
#   'statistician',
#   'repeat',
#   'covariance'],
#  'CE2407': ['dynamics/vibrations',
#   'reasonable',
#   'algebraic',
#   'reliability',
#   'bridge'],
#  'CAS6101': ['interreferencing',
#   'referencing',
#   'decentre',
#   'inter-asia',
#   'speaks'],
#  'CE2409': ['detailing', 'computer-aided', 'cad', 'drawing', 'cross'],
#  'CDM5101': ['suppressor', 'aberrant', 'neoplasia', 'metastasis', 'oncogene'],
#  'CE3101': ['large-scale',
#   'infrastructure',
#   'competition',
#   'master',
#   'real-world'],
#  'CDM5104': ['locus', 'onthology', 'blast', 'convential', 'annotation'],
#  'CE3116': ['superstructure',
#   'overstress',
#   'sensible',
#   'shallow',
#   'derivation'],
#  'CE1102': ['companion',
#   'repercussion',
#   'cost-effective',
#   'considerable',
#   'feasible'],
#  'CE3121': ['pavement', 'traffic', 'road', 'geometric', 'intersection'],
#  'CE2155': ['constitutive', 'qualify', 'steel', 'practise', 'concrete'],
#  'CE3165': ['serviceability', 'qualify', 'ultimate', 'practise', 'concrete'],
#  'CE3102': ['work-force',
#   'field-work',
#   'socio-technical',
#   'globalized',
#   'varied'],
#  'CE3166': ['portal/industrial',
#   'plat',
#   'multi-storey',
#   'economical',
#   'conceive'],
#  'CE3115': ['embankment', 'slope', 'serviceability', 'excavation', 'passive'],
#  'CE4103': ['interpersonal', 'assign', 'early', 'leadership', 'oral'],
#  'CE3132': ['pressurise', 'pond', 'hydrological', 'diffusive', 'kinematic'],
#  'CE4104': ['b.', 'achievement', 'spend', 'interim', 'attitude'],
#  'CE3155': ['respectable',
#   'idealization',
#   'determinacy',
#   'truss',
#   'redundancy'],
#  'CE4257': ['axisymmetric', 'isoparametric', '2-d', '1-d', '3-d'],
#  'CE4257A': ['geotechnical', 'finite', 'behavior', 'structural', 'civil'],
#  'CE5001': ['feasibility', 'minor', 'committee', 'combination', 'civil'],
#  'CE4221': ['rail', 'transit', 'highway', 'terminal', 'bus'],
#  'CE5101': ['dewatering', 'two-phase', 'darcy', 'seepage', '1-d'],
#  'CE4257B': ['weighted', 'ce4257a', 'seepage', 'residual', 'fem'],
#  'CE5104': ['world-wide', 'jack', 'austrian', 'lining', 'cavern'],
#  'CE4258': ['multi-degree-of-freedom',
#   'single-degree-of-freedom',
#   'buckling',
#   'column',
#   'vibration'],
#  'CE5106A': ['clay', 'grout', 'sandy', 'vibratory', 'preloading'],
#  'CE4282': ['revolutionary', 'bim', 'database', 'delivery', 'best'],
#  'CE5106B': ['pvd', 'geosynthetics', 'stringent', 'nail', 'tunnelling'],
#  'CE5107A': ['axial', 'deflection', 'bearing', 'installation', 'realistic'],
#  'CE5107B': ['loading', 'eurocode', 'installation', 'marine', 'difficult'],
#  'CE5104A': ['lining', 'underpass', 'subway', 'metro', 'station'],
#  'CE5108': ['eurocode7', 'earth-retaining', 'cofferdam', 'sl', 'bs8002'],
#  'CE5104B': ['tunnelling', 'austrian', 'underground', 'cavern', 'underpass'],
#  'CE5108A': ['ce5108b', 'eurocode7', 'using', 'earth-retaining', 'sl'],
#  'CE5105': ['winkler', 'pasternak', 'raft', 'axial', 'pile'],
#  'CE5111': ['wale', 'adjacent', 'drawdown', 'strut', 'temporary'],
#  'CE5106': ['vibro-flotation', 'drain', 'grouting', 'preloading', 'peaty'],
#  'CE5113': ['bore', 'geophysical', 'drawdown', 'strut', 'hole'],
#  'CE5107': ['unipile', 'plaxis', '.the', 'accordance', 'pile'],
#  'CE5108B': ['multi-strut', 'ce5108a', 'undrained', 'shaft', 'lateral'],
#  'CE5205': ['infer', 'harness', 'capable', 'observe', 'contrast'],
#  'CE5307': ['shoaling',
#   'morison',
#   'hydrodynamics',
#   'short-term',
#   'corresponding'],
#  'CE5112': ['anchorage', 'splice', 'soil-structure', 'walers', 'contiguous'],
#  'CE5310': ['hydroinformatics',
#   'hydrological',
#   'originate',
#   'data-driven',
#   'hydraulics'],
#  'CE5113A': ['ec7', 'underground', 'in-situ', 'eurocode', 'disturbance'],
#  'CE5312': ['bedforms', 'alluvial', 'weir', 'inflow', 'sluice'],
#  'CE5113B': ['resistivity', 'geophysical', 'drawdown', 'strut', 'deflection'],
#  'CE5207': ['pm', 'airfield', 'pavement', 'deficiency', 'life-cycle'],
#  'CE5377': ['eigen-analysis', 'miniprojects', 'box', 'homework', 'finite'],
#  'CE5308': ['bedload', 'wave-current', 'turbidity', 'groyne', 'headland'],
#  'CE5509': ['long-span', 'tubular', 'steel-concrete', 'steel', 'composite'],
#  'CE5509A': ['ppvc',
#   'volumetric',
#   'prefabricate',
#   'prefinished',
#   'buildability'],
#  'CE5510A': ['detailing', 'crack', 'deflection', 'refine', 'keen'],
#  'CE5509B': ['steel-concrete',
#   'multi-storey',
#   'post-graduate',
#   'economical',
#   'conceive'],
#  'CE5510B': ['slab', 'slender', 'irregular', 'corbel', 'non-flexural'],
#  'CE5510': ['strut-and-tie', 'flexural', 'seismic', 'collapse', 'opening'],
#  'CE5513': ['hinge', 'portal', 'plasticity', 'multi-storey', 'inelastic'],
#  'CE5610': ['retrofitting',
#   'non-destructive',
#   'deterioration',
#   'retrofit',
#   'in-situ'],
#  'CE5603': ['inflation', 'rational', 'allocation', 'uncertainty', 'purpose'],
#  'CE5610A': ['cement-based',
#   'cementitious',
#   'replacing',
#   'precast',
#   'retrofit'],
#  'CE5603A': ['rent-buy', 'fee', 'recovery', 'budgeting', 'estimate'],
#  'CE5610B': ['nondestructive',
#   'retrofitting',
#   'non-destructive',
#   'deterioration',
#   'retrofit'],
#  'CE5604': ['harden',
#   'high-strength',
#   'admixture',
#   'lightweight',
#   'performance-based'],
#  'CE5666': ['attachment', 'company', 'experience', 'engineering', 'work'],
#  'CE5806': ['diagnose', 'devise', 'delay', 'lean', 'reliable'],
#  'CE5611': ['floor', 'diaphragm', 'precast', 'msc', 'keen'],
#  'CE5611A': ['self-compacting',
#   'highperformance',
#   'harden',
#   'high-strength',
#   'admixture'],
#  'CE6001': ['scarce', 'vibration', 'non-linear', 'comprise', 'allocation'],
#  'CE5611B': ['floor', 'diaphragm', 'precast', 'keen', 'frame'],
#  'CE6077': ['eigen-analysis', 'miniprojects', 'box', 'homework', 'finite'],
#  'CE5804': ['reposition',
#   'constructor',
#   'computer-integrated',
#   'bidding',
#   'survival'],
#  'CE5805': ['dfma', 'logistical', 'fleet', 'just-in-time', 'ease'],
#  'CFG1002': ['e-seminars',
#   'three/four-year',
#   'roadmap',
#   'maximise',
#   'confident'],
#  'CE5806A': ['delay', 'compression', 'schedule', 'organise', 'execution'],
#  'CFG1010': ['maximise',
#   'volatile',
#   'e-learning',
#   'mindset',
#   'self-awareness'],
#  'CE5806B': ['diagnose', 'devise', 'lean', 'reliable', 'commitment'],
#  'CG1111': ['interconnected',
#   'drone',
#   'reconstruct',
#   'subsystem',
#   'computer-aided'],
#  'CE5808A': ['repository', 'bim', 'update', 'lifecycle', 'manipulate'],
#  'CG2027': ['cg1112', 'cg1111', 'pas', 'mosfets', 'timing'],
#  'CE5808B': ['vdc', 'lean', 'bim', 'virtual', 'mapping'],
#  'CG2028': ['microarchitecture',
#   'assembly',
#   'arm',
#   'microprocessor',
#   'instruction'],
#  'CE5881': ['ambient', 'geological', 'agree', 'rock', 'damage'],
#  'CG2271': ['realtime', 'rtoss', 'customise', 'customisation', 'rtos'],
#  'CE5883A': ['estuary',
#   'advective',
#   'diffusive',
#   'hydrodynamic',
#   'dispersive'],
#  'CG3002': ['cg2007',
#   'cs2103',
#   'conceptualisation',
#   'cg1101',
#   'cg1102/cg1103'],
#  'CG3207': ['fpga', 'cpu', 'micro-controllers', 'microprocessor', 'parallel'],
#  'CE6002': ['in-laboratory',
#   'hydraulics',
#   'gather',
#   'deterministic',
#   'geotechnical'],
#  'CG4001': ['6-month', 'lifelong', 'embark', 'mix', 'extension'],
#  'CE6006': ['meshless', 'degenerate', 'time-dependent', 'plate', 'weak'],
#  'CH1101E': ['assassin', 'lover', 'revengeful', 'ghost', 'assigned'],
#  'CH2121': ['studies/chinese', 'qing', 'cater', 'dynasty', 'writer'],
#  'CH2221': ['hu', 'giant', 'flourish', 'lu', 'ailing'],
#  'CH2243': ['mid-19th', 'understand/analyse', '20th', 'ethnic', 'internal'],
#  'CG1112': ['fault-tolerant', 'epp', 'interfacing', 'metric', 'extend'],
#  'CH2275': ['identity-construction',
#   'sinophone',
#   'dialect',
#   'taiwan',
#   'regionalism'],
#  'CG2023': ['bandwidth', 'bode', 'filtering', 'reconstruction', 'fourier'],
#  'CH3221': ['rhymeprose', 'poetic', 'promote', 'wish', 'style'],
#  'CH3225': ['ch2225', 'outstanding', 'modernism', 'diasporic', 'nineteenth'],
#  'CH3273': ['close-reading', 'charm', 'vernacular', 'qing', 'dynasty'],
#  'CH3295': ['fieldtrips', 'westernization', 'topical', 'past', 'intensive'],
#  'CH4204': ['rime', 'dialectal', 'phonogram', 'phonology', 'reconstruction'],
#  'CH4223': ['correlative',
#   'lyricism',
#   'connoisseurship',
#   'aesthetical',
#   'taste'],
#  'CH4247': ['printing', 'print', 'symbolic', 'illustration', 'newspaper'],
#  'CH2141': ['opium', 'socio-political', 'imperial', 'dynasty', 'ancient'],
#  'CH4401': ['stipulated', 'optional', 'schedule', 'submit', 'progress'],
#  'CH2161': ['ji', 'emperor', 'miscellaneous', 'jing', 'quanshu'],
#  'CH4882A': ['century-china',
#   'unofficial',
#   'biography',
#   'objectivity',
#   'autobiography'],
#  'CH2274': ['reformation', 'undergone', 'tremendous', 'mainland', 'adapt'],
#  'CH5210': ['demonstration', 'lexical', 'semantics', 'frame', 'expect'],
#  'CH2293': ['neolithic-period',
#   'calligraphy',
#   'manifestation',
#   'ceramic',
#   'early'],
#  'CH5211': ['co-op', 'deixis', 'politeness', 'pragmatic', 'conversation'],
#  'CH2391': ['dispossess', 'downtrodden', 'nobody', 'outsider', 'stranger'],
#  'CH2392': ['oppress', 'chastity', 'simplistic', 'patriarchal', 'wisdom'],
#  'CH5212': ['stone',
#   'phonological',
#   'shortcoming',
#   'optimality',
#   'applicability'],
#  'CH2393': ['nusri', 'sme', 'state-owned', 'suzhou', 'institute'],
#  'CH5213': ['lexicon', 'dialect', 'linguistics', 'systematic', 'cognitive'],
#  'CH3222': ['southern', 'northern', 'vernacular', 'fourth', 'opera'],
#  'CH3228': ['nourish', 'prosody', 'tang-song', 'masterpiece', 'tone'],
#  'CH6203': ['lexicalization',
#   'unidirectionality',
#   'grammatic',
#   're-examine',
#   'similarity'],
#  'CH3246': ['rebellion', 'establishment', 'opium', '20th', 'republic'],
#  'CH6241': ['historiography',
#   'dynasty',
#   'combination',
#   'reference',
#   'intellectual'],
#  'CH3550': ['advertise', 'vet', 'length', 'beginning', 'reflection'],
#  'CH6261': ['interpretive',
#   'chosen',
#   'team-taught',
#   'handling',
#   'scholarship'],
#  'CH4207': ['mono-/bi-syllabic', 'tone', 'phonology', 'sentence', 'syntax'],
#  'CH6262': ['independent-study',
#   'finalize',
#   'permission',
#   'consultation',
#   'dissertation'],
#  'CH4226': ['beijing', 'metropolis', 'shanghai', 'illuminate', 'photograph'],
#  'CH6263': ['domestication',
#   'incompatibility',
#   'misunderstanding',
#   'cross-boundary',
#   'versus'],
#  'CH4261': ['ch3261', 'ch2261', 'chapter', 'extend', 'intensive'],
#  'CH6770': ['ay2004/2005',
#   'admit',
#   'satisfactory/unsatisfactory',
#   'spread',
#   'dissertation'],
#  'CH4262': ['locale',
#   'transregionalism',
#   'sojourn',
#   'historicisation',
#   'singapore-malaysia'],
#  'CHC5101': ['influential', 'publication', 'compulsory', 'english', 'read'],
# ...
#   'nanomaterials',
#   'fine',
#   'renewable',
#   'inorganic'],
#  'CS1231': ['pigeonhole',
#   'bijection',
#   'subset',
#   'combinatoric',
#   'inclusion-exclusion'],
#  'CN6251': ['fouling', 'biomimetic', 'symmetric', 'inspire', 'purification'],
#  'CS2010': ['prefix/infix/postfix', 'b-trees', 'avl', 'cs1020', 'heap'],
#  'CS2030': ['lambda',
#   'effect-free',
#   'medium-scale',
#   'polymorphism',
#   'closure'],
#  'CS2040': ['heap', 'hash', 'sort', 'stack', 'table'],
#  'CS2040C': ['heap', 'hash', 'sort', 'stack', 'table'],
#  'CS2100': ['input/output',
#   'pipelining',
#   'combinational',
#   'assembly',
#   'processor'],
#  'CS2101': ['modes',
#   'student-centric',
#   'nontechnical',
#   'team-based',
#   'comprehensible'],
#  'CS2102': ['boyce-codd',
#   'tuple',
#   'entity-relationship',
#   'normalisation',
#   'sql'],
#  'CS2103': ['modularisation',
#   'uml',
#   'correctness',
#   'fulfill',
#   'object-oriented'],
#  'CS2103T': ['modularisation',
#   'uml',
#   'correctness',
#   'fulfill',
#   'object-oriented'],
#  'CS2104': ['programming-languages',
#   'haskell',
#   'smalltalk',
#   'pseudo-code',
#   'prolog'],
#  'CS2105': ['lan', 'handson', 'socket', 'dns', 'reliable'],
#  'CS2106': ['paging', 'metadata', 'directory', 'unix/linux', 'interrupt'],
#  'CS2107': ['classical/historical',
#   'engineering/phishing',
#   'cryptosystems',
#   'cipher',
#   'malicious'],
#  'CS2113': ['small-to-medium',
#   'revisioning',
#   'multi-person',
#   'assurance',
#   'automation'],
#  'CS2113T': ['small-to-medium',
#   'revisioning',
#   'multi-person',
#   'assurance',
#   'automation'],
#  'CS2220': ['confident', 'flexible', 'bioinformatics', 'predict', 'dna'],
#  'CS3103': ['netstat', 'devices/technologies', 'vlan', 'sdn', 'router'],
#  'CS1010R': ['1-mc', 'host', 'pertain', 'matter', 'in-depth'],
#  'CS3203': ['sdlc', 'well-designed', 'well-tested', 'large-scaled', 'version'],
#  'CS3210': ['distributed-memory',
#   'shared-memory',
#   'gpgpu',
#   'scalability',
#   'parallelism'],
#  'CS1010X': ['cs1010s', 'cs1010e', 'foremost', 'cs1010', 'pseudo-codes'],
#  'CS3216': ['user-friendly', 'ux', 'ui', 'production-quality', 'gather'],
#  'CS1010XCP': ['cs1010s', 'cs1010e', 'foremost', 'cs1010', 'pseudo-codes'],
#  'CS3219': ['replicable', 'elicitation', 'proven', 'explicate', 'accompany'],
#  'CS3230': ['branch-and-bound',
#   'prune-and-search',
#   'amortized',
#   'traversal',
#   'np-completeness'],
#  'CS3230R': ['1-mc', 'host', 'pertain', 'matter', 'in-depth'],
#  'CS3235': ['overflow', 'mail', 'buffer', 'dns', 'intrusion'],
#  'CS3236R': ['1-mc', 'host', 'pertain', 'matter', 'in-depth'],
#  'CS3240': ['user-centred',
#   'hci',
#   'usability',
#   'human-computer',
#   'contextual'],
#  'CS3241': ['clip', 'enrichment', 'terminology', 'interesting', 'graphic'],
#  'CS3241R': ['clip', 'enrichment', 'terminology', 'interesting', 'graphic'],
#  'CS3244': ['already-too-many',
#   'self-learning',
#   'regularity',
#   'capable',
#   'raw'],
#  'CS3245R': ['1-mc', 'host', 'pertain', 'matter', 'in-depth'],
#  'CS4211': ['proving', 'checking', 'inculcate', 'notation', 'temporal'],
#  'CS4212': ['parsing', 'un-optimised', 'parser', 'data-flow', 'context-free'],
#  'CS4223': ['message-passing',
#   'supercomputer',
#   'multi-cores',
#   'high-end',
#   'cache'],
#  'CS4224': ['replication', 'peer-to-peer', 'query', 'adapt', 'cloud'],
#  'CS4226': ['openflow', 'ospf', 'cubic', 'intra-', 'bgp'],
#  'CS2108': ['synchronization',
#   'media-rich',
#   'confident',
#   'enough',
#   'retrieval'],
#  'CS4232': ['non-determinism',
#   'digitalisation',
#   'equivalence',
#   'reduction',
#   'object'],
#  'CS4234': ['approximability',
#   'good-enough',
#   'np-hard',
#   'optimality',
#   'integer'],
#  'CS4236': ['signature', 'cryptology', 'cryptographic', 'side-channel', 'ssl'],
#  'CS4238': ['lab-based', 'memory-error', 'dns', 'attack', 'exploit'],
#  'CS3211': ['synchronise',
#   'asynchronous',
#   'debugging',
#   'concurrency',
#   'collaborate'],
#  'CS4239': ['check', 'malicious', 'life-cycle', 'detect', 'vulnerability'],
#  'CS3217': ['enginnering',
#   'well-tested',
#   'production-quality',
#   'cloud',
#   'mobile'],
#  'CS4243': ['quaternion', 'binocular', 'vanish', 'equalization', 'histogram'],
#  'CS3223': ['object-database',
#   'multi-user',
#   'on-line',
#   'concurrency',
#   'warehousing'],
#  'CS4246': ['non-deterministic',
#   'uncertainy',
#   'multi-agent',
#   'tactical',
#   'deterministic'],
#  'CS4248': ['viterbi',
#   'chunking',
#   'co-reference',
#   'disambiguation',
#   'corpus-based'],
#  'CS3233': ['backtracking', 'conquer', 'deepening', 'toolkits', 'a*'],
#  'CS4249': ['hci', 'human-computer', 'metaphor', 'designer', 'constraint'],
#  'CS3233R': ['backtracking', 'conquer', 'deepening', 'toolkits', 'a*'],
#  'CS4261': ['indivisible', 'rent', 'airport', 'nash', 'cooperative'],
#  'CS3234': ['non-classical', 'deductive', 'prove', 'non-standard', 'verify'],
#  'CS4350': ['animation',
#   'project-based',
#   'progression',
#   'graphic',
#   'practise'],
#  'CS4351': ['non-photorealistic',
#   'shading',
#   'shade',
#   'multiple-pass',
#   'post-rendering'],
#  'CS3236': ['information-theoretic',
#   'noisy-channel',
#   'compress',
#   'error-correcting',
#   'quantify'],
#  'CS5219': ['run-time', 'debugging', 'reactive', 'guarantee', 'sequential'],
#  'CS5223': ['tolerant', 'interprocess', 'corba', 'naming', 'middleware'],
#  'CS3242': ['lighting', 'animation', 'render', 'deformation', 'hierarchical'],
#  'CS5228': ['denclue', 'apriori', 'outliers/deviants', 'outlier', 'k-mediods'],
#  'CS3243': ['assumption-based', 'alpha-beta', 'turing', 'refutation', 'lisp'],
#  'CS5229': ['fundamentals/techniques',
#   'specification/verification',
#   'hot',
#   'briefly',
#   'networking'],
#  'CS5231': ['desktop', 'forensic', 'web-based', 'audit', 'trust'],
#  'CS3244R': ['1-mc', 'host', 'pertain', 'matter', 'in-depth'],
#  'CS5234': ['cs3230', 'algorithms', 'combinatorial', 'assume', 'equivalent'],
#  'CS3245': ['newswire', 'capturing', 'semi-structured', 'transcribe', 'email'],
#  'CS5236': ['learnability', 'automata', 'automaton', 'query', 'characterise'],
#  'CS3247': ['math', 'engine', 'user', 'interface', 'game'],
#  'CS5239': ['client-server', 'queuing', 'bottleneck', 'workload', 'benchmark'],
#  'CS3249': ['multiple-user', 'multithreading', 'widget', 'gui', 'usability'],
#  'CS5240': ['well-grounded', 'multimedia', 'graphic', 'audio', 'understood'],
#  'CS3281': ['large-scaled',
#   'two-part',
#   'professor',
#   'surveillance',
#   'tourism'],
#  'CS5242': ['learning-based',
#   'cybersecurity',
#   'fintech',
#   'bioinformatics',
#   'guideline'],
#  'CS3282': ['large-scaled',
#   'two-part',
#   'professor',
#   'surveillance',
#   'tourism'],
#  'CS5322': ['credential', 'pkis', 'encrypted', 'dbms', 'peer-to-peer'],
#  'CS4215': ['linking',
#   'parameter-passing',
#   'just-in-time',
#   'modules',
#   'compilation'],
#  'CS5331': ['browser',
#   'scanner',
#   'authentication',
#   'web-based',
#   'vulnerability'],
#  'CS4218': ['root-cause', 'debugging', 'clustering', 'debug', 'fail'],
#  'CS5340': ['informatics',
#   'graphical',
#   'bayesian',
#   'bioinformatics',
#   'probabilistic'],
#  'CS4220': ['overload', 'chip', 'microarray', 'hidden', 'biologist'],
#  'CS5344': ['techonology',
#   'map-reduce',
#   'data-streaming',
#   'high-dimensional',
#   'similarity'],
#  'CS4221': ['entityrelationship',
#   'non-relational',
#   'de-normalization',
#   'multi-valued',
#   'tune'],
#  'CS5424': ['replication', 'peer-to-peer', 'query', 'adapt', 'cloud'],
#  'CS4222': ['mac',
#   'cyber-physical-system/internet-of-things',
#   'wi-fi',
#   'zigbee',
#   'rout'],
#  'CS5439': ['check', 'malicious', 'life-cycle', 'detect', 'vulnerability'],
#  'CS4225': ['apache', 'hadoop', 'high-performance', 'warehousing', 'extract'],
#  'CS6101': ['unsatisfactory', 'cs/cu', 'forum', 'satisfactory', 'grade'],
#  'CS4231': ['snapshot',
#   'wait-free',
#   'fault-tolerance',
#   'self-stabilization',
#   'synchronization'],
#  'CS6202': ['language/system',
#   'meta-programming',
#   'garbage',
#   'expressive',
#   'run-time'],
#  'CS4234R': ['1-mc', 'host', 'pertain', 'matter', 'in-depth'],
#  'CS6203': ['warehousing',
#   'heterogeneous',
#   'legacy',
#   'object-oriented',
#   'mining'],
#  'CS6210': ['meta-skills', 'answer', 'successful', 'great', 'paper'],
#  'CS4240': ['vr/ar', 'ar', 'vr', 'human-centered', 'augment'],
#  'CS6231': ['language-based',
#   'privacy-preserving',
#   'adversarial',
#   'cloud',
#   'mobile'],
#  'CS4242': ['www', 'revolutionise', 'propagate', 'disseminate', 'consume'],
#  'CS6234': ['seminar-based',
#   'randomize',
#   'algorithms',
#   'restrict',
#   'combinatorial'],
#  'CS4244': ['formalise',
#   'monotonic',
#   'non-monotonic',
#   'compilation',
#   'deduction'],
#  'CS6244': ['cleaner', 'self-driving', 'humanoid', 'amazing', 'robot'],
#  'CS4247': ['image-based', 'offline', 'radios', 'anti-aliasing', 'ray'],
#  'CS6283': ['satisfiability',
#   'boolean',
#   'compilation',
#   'constrain',
#   'counting'],
#  'CS4257': ['anonymous',
#   'privacy-preserving',
#   'countermeasure',
#   'attack',
#   'vulnerability'],
#  'CS6285': ['sampler',
#   'pseudorandomness',
#   'extractor',
#   'list-decodable',
#   'bit'],
#  'CS4268': ['deutsch-jozsa', 'simon', 'grover', 'shor', 'correction'],
#  'CS6880': ['big-scale',
#   'software-engineering',
#   'sub-disciplines',
#   'maintenance',
#   'web'],
#  'CS4347': ['pertains', 'whereas', 'post-processing', 'edit', 'retrieval'],
#  'CSA6770': ['forum',
#   'satisfactory/unsatisfactory',
#   'candidate',
#   'expect',
#   'dissertation'],
#  'CS5218': ['co-induction',
#   'programming-language',
#   'compile-time',
#   'approximate',
#   'reliable'],
#  'CSA6880': ['eminent', 'appoint', 'fellow', 'scholar', 'accord'],
#  'CS5222': ['thread-level',
#   'cost-performance-power-reliability',
#   'multiprocessor',
#   'instruction-level',
#   'subsystem'],
#  'DAO1704': ['forster', 'spreadsheet', 'stimulate', 'capture', 'rich'],
#  'CS5224': ['fulfillment', 'orchestration', 'virtual', 'assurance', 'cloud'],
#  'DAO1704X': ['forster', 'spreadsheet', 'stimulate', 'capture', 'rich'],
#  'DAO1704Y': ['forster', 'spreadsheet', 'stimulate', 'capture', 'rich'],
#  'CS5230': ['savitch', 'pspace', 'padding', 'exp', 'np'],
#  'DAO2702': ['interweave', 'cleaning', 'walk', 'python', 'experimentation'],
#  'CS5232': ['statechart',
#   'z/object-z',
#   'state-based',
#   'unambiguous',
#   'event-based'],
#  'DAO2703': ['oraganizations', 'otm', 'entrance', 'erp', 'match'],
#  'CS5233': ['parallel', 'simulate', 'package', 'execution', 'simulation'],
#  'DBA3711': ['inadequate', 'randomness', 'queue', 'characterise', 'feasible'],
#  'DBA3803': ['season', 'delphi', 'etc.this', 'front', 'excel'],
#  'CS5246': ['summarization', 'answering', 'sentiment', 'mine', 'clustering'],
#  'DE4201': ['socio-spatial',
#   'seminar-style',
#   'infrastructure',
#   'senior',
#   'school'],
#  'CS5250': ['microkernels',
#   'internet-ready',
#   'multi-core',
#   'multi-processors',
#   'ui'],
#  'DE5106': ['mandatory', 'agenda', 'suitability', 'm.sc', 'predict'],
#  'CS5272': ['reconfigurable',
#   'hand-phones',
#   'inside',
#   'component-based',
#   'hide'],
#  'DE5108': ['students-', 'm.sc', 'candidate', 'investigate', 'choice'],
#  'CS5321': ['scrubbing', 'damaging', 'denial', 'firewall', 'traffic'],
#  'DE5109': ['m.sc', 'advancement', 'candidate', 'produce', 'finding'],
#  'CS5330': ['chernoff', 'simpler', 'utilizing', 'graph/network', 'balancing'],
#  'DEP5101A': ['furnish',
#   'appropriateness',
#   'planner',
#   'reflexivity',
#   'inspection'],
#  'CS5339': ['descent', 'regularization', 'greedy', 'convex', 'gradient'],
#  'DEP5102': ['socioeconomical',
#   'plan-making',
#   'utopian',
#   'zone',
#   'neighbourhood'],
#  'CS5346': ['pedagogy', 'hierarchical', 'relational', 'temporal', 'topical'],
#  'DEP5108': ['mup', 'self-sourced', 'tutor', 'month', 'director'],
#  'CS5421': ['nonrelational',
#   'de-normalization',
#   'multi-valued',
#   'tune',
#   'nosql'],
#  'DEP5110': ['dep5110', 'precinct', 'mup', 'subgroup', 'neighbourhood'],
#  'CS5422': ['mac',
#   'cyber-physical-system/internet-of-things',
#   'wi-fi',
#   'zigbee',
#   'rout'],
#  'DI5100': ['emabark', 'implantology', 'diploma', 'dental', 'part-time'],
#  'CS5425': ['apache', 'hadoop', 'high-performance', 'warehousing', 'extract'],
#  'DOS3701': ['portal', 'b2b', 'responsiveness', 'e-business', 'inventory'],
#  'DSA1101': ['pharmacy', 'diverse', 'physic', 'biological', 'source'],
#  'CS6208': ['fuzzy', 'robotics', 'exact', 'artificial', 'genetic'],
#  'DSA2101': ['univariate',
#   'cleaning',
#   'high-dimensional',
#   'exploratory',
#   'extract'],
#  'CS6211': ['validate',
#   'confidence',
#   'validation',
#   'experimental',
#   'describe'],
#  'DSA3101': ['dsa1101',
#   'pharmaceutic',
#   'consult',
#   'partner',
#   'transportation'],
#  'CS6215': ['bottleneck', 'automate', 'debug', 'state-of-the-art', 'identify'],
#  'DSA3102': ['sub-gradient',
#   'proximal',
#   'sub-gradients',
#   'descent',
#   'accelerate'],
#  'CS6216': ['exact', 'state-of-the-art', 'completion', 'machine', 'lecturer'],
#  'DSA3312': ['16-20',
#   'technical/practical',
#   'company/institution',
#   'chance',
#   'job'],
#  'CS6280': ['datacenter', 'state-of-the', 'stack', 'cloud', 'low'],
#  'DSA4211': ['slice', 'tree-structured', 'voluminous', 'penalize', 'sure'],
#  'CS6282': ['attacker',
#   'internet-of-things',
#   'cyber-physical',
#   'compromise',
#   'furthermore'],
#  'DSC1007': ['scientifically-tested',
#   'timelier',
#   'substantiate',
#   'tomorrow',
#   'smarter'],
#  'CSA6102': ['biblical', 'gnostic', 'bible', 'christianity', 'interpretative'],
#  'DSC1007X': ['scientifically-tested',
#   'timelier',
#   'substantiate',
#   'tomorrow',
#   'smarter'],
#  'DSC2006': ['competitiveness',
#   'responsible',
#   'inventory',
#   'poisson',
#   'prerequisite'],
#  'DSC2008': ['insightful', 'huge', 'projection', 'interval', 'amount'],
#  'DSC3201': ['portal', 'b2b', 'responsiveness', 'e-business', 'inventory'],
#  'DSC3202': ['purchasing',
#   'buy',
#   'informative',
#   'application-oriented',
#   'pedagogy'],
#  'DSC3203': ['restaurant',
#   'workshift',
#   'outlet',
#   'service-oriented',
#   'vehicular'],
#  'DBA3701': ['routing', 'integer', 'optimisation', 'vehicle', 'nonlinear'],
#  'DSC3214': ['routing', 'integer', 'optimisation', 'vehicle', 'nonlinear'],
#  'DBA3702': ['summarise', 'visualize', 'convince', 'structured', 'sharing'],
#  'DSC3215': ['inadequate', 'randomness', 'queue', 'characterise', 'feasible'],
#  'DSC3216': ['season', 'delphi', 'etc.this', 'front', 'excel'],
#  'DBA3712': ['bundle', 'state-of-art', 'tactical', 'extract', 'consultant'],
#  'DSC3224': ['bundle', 'state-of-art', 'tactical', 'extract', 'consultant'],
#  'DSC3229': ['individual-based',
#   'report-writing',
#   'well-defined',
#   'ism',
#   'requisite'],
#  'DBA4811': ['stattools',
#   'polish',
#   'salary',
#   'right-sizing',
#   'knowledge-based'],
#  'DSC4213': ['stattools',
#   'polish',
#   'salary',
#   'right-sizing',
#   'knowledge-based'],
#  'DE5107': ['augmentation',
#   'participatory',
#   'suitability',
#   'intensity',
#   'availability'],
#  'DSC4216': ['overabundance',
#   'categorize',
#   'identifying',
#   'myriad',
#   'differentiate'],
#  'DSC4219': ['non-honors', 'eligible', 'acc', 'bba', 'honor'],
#  'DSC5101': ['lay', 'datasets', 'stochastic', 'price', 'competitive'],
#  'DSC5102': ['action-based', 'insightful', 'span', 'competency', 'capability'],
#  'DEP5103A': ['profession', 'argument', 'limitation', 'appreciate', 'sound'],
#  'DSC5211A': ['modeling/analysis',
#   'coordination',
#   'robust',
#   'efficient',
#   'chain'],
#  'DTS5701': ['scale', 'large', 'engineering', 'system'],
#  'DTS5702': ['c3', 'weapon', 'well', 'underlying', 'sensor'],
#  'DEP5109': ['prove', 'twofold', 'mup', 'tutor', 'specialise'],
#  'DTS5734': ['counter-measures',
#   'teaming',
#   'counter-counter-measures',
#   'uxvs',
#   'guidance/navigation'],
#  'DOS3702': ['purchasing',
#   'buy',
#   'informative',
#   'application-oriented',
#   'pedagogy'],
#  'DTS5735': ['cybersecurity',
#   'malicious',
#   'mitigate',
#   'cryptography',
#   'attack'],
#  'DOS3703': ['restaurant',
#   'workshift',
#   'outlet',
#   'service-oriented',
#   'vehicular'],
#  'DTS5736': ['unman', 'c3', 'multi-dimensional', 'cyber', 'military'],
#  'DSA2102': ['multiplication',
#   'tight',
#   'arithmetic',
#   'interpolation',
#   'square'],
#  'DY5190': ['candidature', 'attendance', 'dentistry', 'conference', 'grade'],
#  'DY5310': ['understan', 'baylor', 'endodontic', 'endodontics', 'corroborate'],
#  'DSA4212': ['data-driven', 'python', 'duality', 'ubiquitous', 'gradient'],
#  'DY5320': ['surgery', 'palate', 'cleft', 'neck', 'orthognathic'],
#  ...}

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=7, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
doc_lda = lda_model[corpus]
lda_model.print_topics()
# Out:
# [(0,
#   '0.025*"presentation" + 0.021*"perform" + 0.018*"scientific" + 0.018*"week" + 0.017*"implication" + 0.016*"science" + 0.015*"quality" + 0.015*"basis" + 0.014*"effective" + 0.013*"security"'),
#  (1,
#   '0.037*"social" + 0.017*"society" + 0.017*"contemporary" + 0.015*"cultural" + 0.014*"culture" + 0.014*"relation" + 0.014*"way" + 0.014*"history" + 0.013*"community" + 0.012*"historical"'),
#  (2,
#   '0.015*"science" + 0.013*"application" + 0.010*"target" + 0.009*"phenomenon" + 0.008*"principle" + 0.008*"cover" + 0.008*"intervention" + 0.008*"fundamental" + 0.007*"equation" + 0.007*"function"'),
#  (3,
#   '0.028*"life" + 0.025*"economic" + 0.021*"singapore" + 0.020*"explore" + 0.017*"international" + 0.017*"examine" + 0.015*"real" + 0.014*"value" + 0.012*"country" + 0.012*"law"'),
#  (4,
#   '0.024*"course" + 0.015*"analysis" + 0.014*"concept" + 0.014*"cover" + 0.012*"use" + 0.010*"problem" + 0.010*"system" + 0.010*"topic" + 0.010*"basic" + 0.009*"method"'),
#  (5,
#   '0.064*"module" + 0.044*"student" + 0.020*"study" + 0.014*"topic" + 0.014*"design" + 0.013*"major" + 0.011*"world" + 0.011*"development" + 0.011*"practice" + 0.010*"approach"'),
#  (6,
#   '0.041*"work" + 0.033*"project" + 0.029*"research" + 0.023*"student" + 0.017*"semester" + 0.015*"skill" + 0.015*"practical" + 0.014*"opportunity" + 0.014*"write" + 0.013*"base"')]

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# C:\Users\jasonyip184\Anaconda3\envs\py36\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.242612 -0.191871       1        1  31.658686
# 5     -0.281117  0.038925       2        1  27.559774
# 1      0.168332  0.077549       3        1   9.876013
# 6     -0.070070  0.310260       4        1   9.475614
# 3      0.122287 -0.103208       5        1   8.674809
# 2      0.123432 -0.166266       6        1   8.265188
# 0      0.179748  0.034613       7        1   4.489911, topic_info=     Category         Freq           Term        Total  loglift  logprob
# term
# 93    Default  3633.000000         module  3633.000000  30.0000  30.0000
# 50    Default  3072.000000        student  3072.000000  29.0000  29.0000
# 188   Default   806.000000           work   806.000000  28.0000  28.0000
# 592   Default   668.000000         social   668.000000  27.0000  27.0000
# 3     Default  1504.000000         course  1504.000000  26.0000  26.0000
# 290   Default   574.000000        project   574.000000  25.0000  25.0000
# 293   Default   749.000000       research   749.000000  24.0000  24.0000
# 481   Default   436.000000           life   436.000000  23.0000  23.0000
# 8     Default   750.000000        examine   750.000000  22.0000  22.0000
# 295   Default  1174.000000          study  1174.000000  21.0000  21.0000
# 128   Default   388.000000       economic   388.000000  20.0000  20.0000
# 57    Default   937.000000          cover   937.000000  19.0000  19.0000
# 69    Default   832.000000        concept   832.000000  18.0000  18.0000
# 33    Default   647.000000    application   647.000000  17.0000  17.0000
# 458   Default   472.000000        science   472.000000  16.0000  16.0000
# 184   Default   387.000000      singapore   387.000000  15.0000  15.0000
# 206   Default   889.000000       analysis   889.000000  14.0000  14.0000
# 195   Default   316.000000        explore   316.000000  13.0000  13.0000
# 1281  Default   313.000000        society   313.000000  12.0000  12.0000
# 70    Default   307.000000   contemporary   307.000000  11.0000  11.0000
# 605   Default   546.000000          world   546.000000  10.0000  10.0000
# 76    Default   690.000000          major   690.000000   9.0000   9.0000
# 269   Default   406.000000    opportunity   406.000000   8.0000   8.0000
# 1080  Default   291.000000       semester   291.000000   7.0000   7.0000
# 250   Default   588.000000        problem   588.000000   6.0000   6.0000
# 142   Default   324.000000          skill   324.000000   5.0000   5.0000
# 133   Default   264.000000  international   264.000000   4.0000   4.0000
# 628   Default   357.000000     experience   357.000000   3.0000   3.0000
# 535   Default   270.000000       cultural   270.000000   2.0000   2.0000
# 852   Default   200.000000   presentation   200.000000   1.0000   1.0000
# ...       ...          ...            ...          ...      ...      ...
# 751    Topic7   145.078125           week   145.930054   3.0975  -4.0256
# 158    Topic7   136.327255    implication   137.182068   3.0971  -4.0879
# 138    Topic7   124.213181        quality   125.066101   3.0965  -4.1809
# 978    Topic7   120.800850          basis   121.652573   3.0963  -4.2088
# 446    Topic7   111.827858      effective   112.679527   3.0958  -4.2859
# 170    Topic7   109.344276       security   110.196762   3.0956  -4.3084
# 1224   Topic7   106.517136           last   107.370697   3.0954  -4.3346
# 179    Topic7   103.949150   organisation   104.800270   3.0952  -4.3590
# 461    Topic7   102.203796         simple   103.057747   3.0950  -4.3759
# 743    Topic7    96.239594     internship    97.090111   3.0945  -4.4361
# 156    Topic7    96.389870      formation    97.244919   3.0945  -4.4345
# 147    Topic7    82.268570      treatment    83.122581   3.0930  -4.5929
# 1648   Topic7    81.012779         notion    81.869919   3.0928  -4.6083
# 1223   Topic7    80.157455           hour    81.009583   3.0928  -4.6189
# 1412   Topic7    80.131424     experiment    80.984749   3.0927  -4.6192
# 167    Topic7    77.744423      pertinent    78.605064   3.0923  -4.6495
# 153    Topic7    74.332664        company    75.183853   3.0920  -4.6944
# 631    Topic7    73.026764       hands-on    73.877754   3.0918  -4.7121
# 171    Topic7    65.543335          solid    66.395874   3.0904  -4.8202
# 633    Topic7    62.317783             nu    63.170773   3.0897  -4.8707
# 746    Topic7    62.221512        minimum    63.078018   3.0897  -4.8722
# 961    Topic7    61.325413        digital    62.177162   3.0895  -4.8867
# 2243   Topic7    59.552433        advisor    60.404392   3.0891  -4.9161
# 460    Topic7    55.758831          short    56.611252   3.0882  -4.9819
# 856    Topic7    54.360741      undertake    55.210800   3.0878  -5.0073
# 674    Topic7    54.350002     simulation    55.201656   3.0878  -5.0075
# 2510   Topic7    53.959763     attachment    54.810905   3.0877  -5.0147
# 458    Topic7   131.313751        science   472.542999   1.8228  -4.1253
# 628    Topic7   107.853806     experience   357.749878   1.9043  -4.3221
# 750    Topic7    62.825928  undergraduate   119.144836   2.4634  -4.8625
#
# [331 rows x 6 columns], token_table=      Topic      Freq           Term
# term
# 204       2  0.997085           able
# 307       4  0.992259       academic
# 795       1  0.998150        address
# 2243      7  0.993305        advisor
# 32        1  0.382574            aim
# 32        2  0.615273            aim
# 122       4  0.992883          allow
# 206       1  0.937732       analysis
# 206       2  0.061841       analysis
# 5848      3  0.989886   anthropology
# 33        1  0.683957    application
# 33        2  0.004632    application
# 33        6  0.310328    application
# 374       1  0.029566       approach
# 374       2  0.959053       approach
# 374       4  0.011087       approach
# 309       3  0.992269            art
# 311       3  0.569818           asia
# 311       5  0.428581           asia
# 405       3  0.991907          asian
# 1708      5  0.986916            ask
# 1032      1  0.051587     assessment
# 1032      4  0.947317     assessment
# 640       4  0.993335     assignment
# 2510      7  0.985205     attachment
# 665       4  0.997486           base
# 173       1  0.891354          basic
# 173       2  0.107901          basic
# 978       7  0.994636          basis
# 1403      6  0.990542     biological
# ...     ...       ...            ...
# 329       3  0.992835      tradition
# 1390      6  0.995102       transfer
# 147       7  0.986495      treatment
# 148       5  0.990905              u
# 750       4  0.470016  undergraduate
# 750       7  0.528768  undergraduate
# 27        1  0.999180     understand
# 28        1  0.469207  understanding
# 28        2  0.531237  understanding
# 856       7  0.978069      undertake
# 53        1  0.741413            use
# 53        2  0.257974            use
# 203       5  0.994213          value
# 1175      6  0.990459       variable
# 277       2  0.997723        variety
# 54        1  0.400642        various
# 54        2  0.599251        various
# 2737      6  0.992160         vector
# 2081      6  0.994736          visit
# 623       3  0.996859            way
# 751       7  0.993627           week
# 188       2  0.060741           work
# 188       3  0.058262           work
# 188       4  0.878881           work
# 188       7  0.001240           work
# 605       2  0.998234          world
# 1086      4  0.997027          write
# 418       4  0.997622        writing
# 704       2  0.974193              ’
# 704       4  0.023569              ’
#
# [387 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 6, 2, 7, 4, 3, 1])

# %%
pyLDAvis.save_html(vis, 'topicmodelingplot.html')
